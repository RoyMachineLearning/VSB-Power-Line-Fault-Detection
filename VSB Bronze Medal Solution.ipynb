# %% [markdown]
# Inspired from Bruno Aquino's Kernel:
# https://www.kaggle.com/braquino/5-fold-lstm-attention-fully-commented-0-694
#
# I am using early stopping on the 5 Folds Stratified K Folds.
#
# Updates : Include Early Stopping because of lower accuracy. Included Dropout and Batch Normalization

# %%
import pandas as pd
import pyarrow.parquet as pq # Used to read the data
import os 
import numpy as np
from keras.layers import * # Keras is the most friendly Neural Network library, this Kernel use a lot of layers classes
from keras.models import Model
from tqdm import tqdm # Processing time measurement
from sklearn.model_selection import train_test_split 
from keras import backend as K # The backend give us access to tensorflow operations and allow us to create the Attention class
from keras import optimizers # Allow us to access the Adam class to modify some parameters
from sklearn.model_selection import GridSearchCV, StratifiedKFold,RepeatedStratifiedKFold # Used to use Kfold to train our model
from keras.callbacks import * # This object helps the model to train in a smarter way, avoiding overfitting
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
# select how many folds will be created
N_SPLITS = 5
# it is just a constant with the measurements data size
sample_size = 800000

# %%
# It is the official metric used in this competition
# below is the declaration of a function used inside the keras model, calculation with K (keras backend / thensorflow)
def matthews_correlation(y_true, y_pred):
    '''Calculates the Matthews correlation coefficient measure for quality
    of binary classification problems.
    '''
    y_pred = tf.convert_to_tensor(y_pred, np.float32)
    y_true = tf.convert_to_tensor(y_true, np.float32)
    
    y_pred_pos = K.round(K.clip(y_pred, 0, 1))
    y_pred_neg = 1 - y_pred_pos

    y_pos = K.round(K.clip(y_true, 0, 1))
    y_neg = 1 - y_pos

    tp = K.sum(y_pos * y_pred_pos)
    tn = K.sum(y_neg * y_pred_neg)

    fp = K.sum(y_neg * y_pred_pos)
    fn = K.sum(y_pos * y_pred_neg)

    numerator = (tp * tn - fp * fn)
    denominator = K.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn))

    return numerator / (denominator + K.epsilon())

# %%
# https://www.kaggle.com/suicaokhoailang/lstm-attention-baseline-0-652-lb

class Attention(Layer):
    def __init__(self, step_dim,
                 W_regularizer=None, b_regularizer=None,
                 W_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
        self.supports_masking = True
        self.init = initializers.get('glorot_uniform')

        self.W_regularizer = regularizers.get(W_regularizer)
        self.b_regularizer = regularizers.get(b_regularizer)

        self.W_constraint = constraints.get(W_constraint)
        self.b_constraint = constraints.get(b_constraint)

        self.bias = bias
        self.step_dim = step_dim
        self.features_dim = 0
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3

        self.W = self.add_weight((input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        self.features_dim = input_shape[-1]

        if self.bias:
            self.b = self.add_weight((input_shape[1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None

        self.built = True

    def compute_mask(self, input, input_mask=None):
        return None

    def call(self, x, mask=None):
        features_dim = self.features_dim
        step_dim = self.step_dim

        eij = K.reshape(K.dot(K.reshape(x, (-1, features_dim)),
                        K.reshape(self.W, (features_dim, 1))), (-1, step_dim))

        if self.bias:
            eij += self.b

        eij = K.tanh(eij)

        a = K.exp(eij)

        if mask is not None:
            a *= K.cast(mask, K.floatx())

        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())

        a = K.expand_dims(a)
        weighted_input = x * a
        return K.sum(weighted_input, axis=1)

    def compute_output_shape(self, input_shape):
        return input_shape[0],  self.features_dim

# %%
# just load train data
df_train = pd.read_csv('../input/metadata_train.csv')
# set index, it makes the data access much faster
df_train = df_train.set_index(['id_measurement', 'phase'])
df_train.head()
# Out:
#                       signal_id  target
# id_measurement phase
# 0              0              0       0
#                1              1       0
#                2              2       0
# 1              0              3       1
#                1              4       1

# %%
# in other notebook I have extracted the min and max values from the train data, the measurements
max_num = 127
min_num = -128

# %%
# This function standardize the data from (-128 to 127) to (-1 to 1)
# Theoretically it helps in the NN Model training, but I didn't tested without it
def min_max_transformation(ts, min_data, max_data, range_needed=(-1,1)):
    if min_data < 0:
        ts_std = (ts + abs(min_data)) / (max_data + abs(min_data))
    else:
        ts_std = (ts - min_data) / (max_data - min_data)
    if range_needed[0] < 0:    
        return ts_std * (range_needed[1] + abs(range_needed[0])) + range_needed[0]
    else:
        return ts_std * (range_needed[1] - range_needed[0]) + range_needed[0]

# %%
def transform_ts(ts, n_dim=160, min_max=(-1,1)):
    # convert data into -1 to 1
    ts_std = min_max_transformation(ts, min_data=min_num, max_data=max_num)
    # bucket or chunk size, 5000 in this case (800000 / 160)
    bucket_size = int(sample_size / n_dim)
    # new_ts will be the container of the new data
    new_ts = []
    # this for iteract any chunk/bucket until reach the whole sample_size (800000)
    for i in range(0, sample_size, bucket_size):
        # cut each bucket to ts_range
        ts_range = ts_std[i:i + bucket_size]
        # calculate each feature
        mean = ts_range.mean()
        std = ts_range.std() # standard deviation
        std_top = mean + std # I have to test it more, but is is like a band
        std_bot = mean - std
        # I think that the percentiles are very important, it is like a distribuiton analysis from eath chunk
        percentil_calc = np.percentile(ts_range, [0, 1, 25, 50, 75, 99, 100]) 
        max_range = percentil_calc[-1] - percentil_calc[0] # this is the amplitude of the chunk
        relative_percentile = percentil_calc - mean # maybe it could heap to understand the asymmetry
        new_ts.append(np.concatenate([np.asarray([mean, std, std_top, std_bot, max_range]),percentil_calc, relative_percentile]))
    return np.asarray(new_ts)

# %%
# this function take a piece of data and convert using transform_ts(), but it does to each of the 3 phases
# if we would try to do in one time, could exceed the RAM Memmory
def prepare_data(start, end):

    praq_train = pq.read_pandas('../input/train.parquet', columns=[str(i) for i in range(start, end)]).to_pandas()
    X = []
    y = []
   
    for id_measurement in tqdm(df_train.index.levels[0].unique()[int(start/3):int(end/3)]):
        X_signal = []
        # for each phase of the signal
        for phase in [0,1,2]:
            # extract from df_train both signal_id and target to compose the new data sets
            signal_id, target = df_train.loc[id_measurement].loc[phase]
            # but just append the target one time, to not triplicate it
            if phase == 0:
                y.append(target)
            # extract and transform data into sets of features
            X_signal.append(transform_ts(praq_train[str(signal_id)]))
        # concatenate all the 3 phases in one matrix
        X_signal = np.concatenate(X_signal, axis=1)
        # add the data to X
        X.append(X_signal)
    X = np.asarray(X)
    y = np.asarray(y)
    return X, y

# %%
# this code is very simple, divide the total size of the df_train into two sets and process it
X = []
y = []
def load_all():
    total_size = len(df_train)
    for ini, end in [(0, int(total_size/2)), (int(total_size/2), total_size)]:
        X_temp, y_temp = prepare_data(ini, end)
        X.append(X_temp)
        y.append(y_temp)
load_all()
X = np.concatenate(X)
y = np.concatenate(y)
# Out:
# 100%|██████████| 1452/1452 [06:56<00:00,  3.13it/s]
# 100%|██████████| 1452/1452 [06:35<00:00,  3.63it/s]

# %%
print(X.shape, y.shape)
# save data into file, a numpy specific format
np.save("X.npy",X)
np.save("y.npy",y)
# Out:
# (2904, 160, 57) (2904,)

# %%
# This is NN LSTM Model creation
def model_lstm(input_shape):
    # The shape was explained above, must have this order
    inp = Input(shape=(input_shape[1], input_shape[2],))
    
    x = Bidirectional(CuDNNLSTM(128, return_sequences=True))(inp)
    x = Bidirectional(CuDNNLSTM(64, return_sequences=True))(x)
    x = Dropout(0.2)(x)
    x = BatchNormalization()(x)
    x = Attention(input_shape[1])(x)
    x = Dense(64, activation="relu")(x)
    x = Dense(1, activation="sigmoid")(x)
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[matthews_correlation])
    
    return model

# %%
# Here is where the training happens

# First, create a set of indexes of the 5 folds
splits = list(RepeatedStratifiedKFold(n_splits=N_SPLITS, n_repeats=2,random_state=42).split(X, y))
preds_val = []
y_val = []
# Then, iteract with each fold
# If you dont know, enumerate(['a', 'b', 'c']) returns [(0, 'a'), (1, 'b'), (2, 'c')]
for idx, (train_idx, val_idx) in enumerate(splits):
    K.clear_session() # I dont know what it do, but I imagine that it "clear session" :)
    print("Beginning fold {}".format(idx+1))
    train_X, train_y, val_X, val_y = X[train_idx], y[train_idx], X[val_idx], y[val_idx]
    model = model_lstm(train_X.shape)
    es = EarlyStopping(monitor='val_matthews_correlation', verbose=2, patience=15, mode='max')
    ckpt = ModelCheckpoint('weights_{}.h5'.format(idx), save_best_only=True, save_weights_only=True, verbose=1, monitor='val_matthews_correlation', mode='max')
    # Train, train, train
    model.fit(train_X, train_y, batch_size=128, epochs=50, validation_data=[val_X, val_y], callbacks=[ckpt,es])
    # loads the best weights saved by the checkpoint
    model.load_weights('weights_{}.h5'.format(idx))
    # Add the predictions of the validation to the list preds_val
    preds_val.append(model.predict(val_X, batch_size=512))
    # and the val true y
    y_val.append(val_y)

# concatenates all and prints the shape    
preds_val = np.concatenate(preds_val)[...,0]
y_val = np.concatenate(y_val)
preds_val.shape, y_val.shape
# Out:
# Beginning fold 1
# Train on 2322 samples, validate on 582 samples
# Epoch 1/50
# 2322/2322 [==============================] - 7s 3ms/step - loss: 0.2488 - matthews_correlation: 0.1574 - val_loss: 0.1778 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_0.h5
# Epoch 2/50
# 2322/2322 [==============================] - 1s 451us/step - loss: 0.1653 - matthews_correlation: 0.0903 - val_loss: 0.1388 - val_matthews_correlation: 0.0880
#
# Epoch 00002: val_matthews_correlation improved from 0.00000 to 0.08800, saving model to weights_0.h5
# Epoch 3/50
# 2322/2322 [==============================] - 1s 450us/step - loss: 0.1356 - matthews_correlation: 0.4523 - val_loss: 0.1108 - val_matthews_correlation: 0.5740
#
# Epoch 00003: val_matthews_correlation improved from 0.08800 to 0.57396, saving model to weights_0.h5
# Epoch 4/50
# 2322/2322 [==============================] - 1s 450us/step - loss: 0.1265 - matthews_correlation: 0.5632 - val_loss: 0.1261 - val_matthews_correlation: 0.5576
#
# Epoch 00004: val_matthews_correlation did not improve from 0.57396
# Epoch 5/50
# 2322/2322 [==============================] - 1s 450us/step - loss: 0.1244 - matthews_correlation: 0.4793 - val_loss: 0.1186 - val_matthews_correlation: 0.5081
#
# Epoch 00005: val_matthews_correlation did not improve from 0.57396
# Epoch 6/50
# 2322/2322 [==============================] - 1s 446us/step - loss: 0.1265 - matthews_correlation: 0.5410 - val_loss: 0.1344 - val_matthews_correlation: 0.7120
#
# Epoch 00006: val_matthews_correlation improved from 0.57396 to 0.71198, saving model to weights_0.h5
# Epoch 7/50
# 2322/2322 [==============================] - 1s 488us/step - loss: 0.1083 - matthews_correlation: 0.6611 - val_loss: 0.1517 - val_matthews_correlation: 0.3445
#
# Epoch 00007: val_matthews_correlation did not improve from 0.71198
# Epoch 8/50
# 2322/2322 [==============================] - 1s 483us/step - loss: 0.1079 - matthews_correlation: 0.6437 - val_loss: 0.0877 - val_matthews_correlation: 0.7199
#
# Epoch 00008: val_matthews_correlation improved from 0.71198 to 0.71987, saving model to weights_0.h5
# Epoch 9/50
# 2322/2322 [==============================] - 1s 483us/step - loss: 0.1080 - matthews_correlation: 0.6262 - val_loss: 0.1279 - val_matthews_correlation: 0.5507
#
# Epoch 00009: val_matthews_correlation did not improve from 0.71987
# Epoch 10/50
# 2322/2322 [==============================] - 1s 489us/step - loss: 0.1067 - matthews_correlation: 0.6204 - val_loss: 0.0922 - val_matthews_correlation: 0.7419
#
# Epoch 00010: val_matthews_correlation improved from 0.71987 to 0.74189, saving model to weights_0.h5
# Epoch 11/50
# 2322/2322 [==============================] - 1s 485us/step - loss: 0.1015 - matthews_correlation: 0.6233 - val_loss: 0.1325 - val_matthews_correlation: 0.5561
#
# Epoch 00011: val_matthews_correlation did not improve from 0.74189
# Epoch 12/50
# 2322/2322 [==============================] - 1s 484us/step - loss: 0.1009 - matthews_correlation: 0.6144 - val_loss: 0.0872 - val_matthews_correlation: 0.7218
#
# Epoch 00012: val_matthews_correlation did not improve from 0.74189
# Epoch 13/50
# 2322/2322 [==============================] - 1s 485us/step - loss: 0.0993 - matthews_correlation: 0.6455 - val_loss: 0.0937 - val_matthews_correlation: 0.7126
#
# Epoch 00013: val_matthews_correlation did not improve from 0.74189
# Epoch 14/50
# 2322/2322 [==============================] - 1s 489us/step - loss: 0.0951 - matthews_correlation: 0.6846 - val_loss: 0.0955 - val_matthews_correlation: 0.6647
#
# Epoch 00014: val_matthews_correlation did not improve from 0.74189
# Epoch 15/50
# 2322/2322 [==============================] - 1s 486us/step - loss: 0.0960 - matthews_correlation: 0.6484 - val_loss: 0.0919 - val_matthews_correlation: 0.6724
#
# Epoch 00015: val_matthews_correlation did not improve from 0.74189
# Epoch 16/50
# 2322/2322 [==============================] - 1s 486us/step - loss: 0.1012 - matthews_correlation: 0.6801 - val_loss: 0.1211 - val_matthews_correlation: 0.6897
#
# Epoch 00016: val_matthews_correlation did not improve from 0.74189
# Epoch 17/50
# 2322/2322 [==============================] - 1s 485us/step - loss: 0.1028 - matthews_correlation: 0.6615 - val_loss: 0.0831 - val_matthews_correlation: 0.7129
#
# Epoch 00017: val_matthews_correlation did not improve from 0.74189
# Epoch 18/50
# 2322/2322 [==============================] - 1s 486us/step - loss: 0.1061 - matthews_correlation: 0.5976 - val_loss: 0.0831 - val_matthews_correlation: 0.6138
#
# Epoch 00018: val_matthews_correlation did not improve from 0.74189
# Epoch 19/50
# 2322/2322 [==============================] - 1s 484us/step - loss: 0.1009 - matthews_correlation: 0.6517 - val_loss: 0.1087 - val_matthews_correlation: 0.5092
#
# Epoch 00019: val_matthews_correlation did not improve from 0.74189
# Epoch 20/50
# 2322/2322 [==============================] - 1s 483us/step - loss: 0.0990 - matthews_correlation: 0.6283 - val_loss: 0.0959 - val_matthews_correlation: 0.7375
#
# Epoch 00020: val_matthews_correlation did not improve from 0.74189
# Epoch 21/50
# 2322/2322 [==============================] - 1s 484us/step - loss: 0.1022 - matthews_correlation: 0.6462 - val_loss: 0.0841 - val_matthews_correlation: 0.7086
#
# Epoch 00021: val_matthews_correlation did not improve from 0.74189
# Epoch 22/50
# 2322/2322 [==============================] - 1s 482us/step - loss: 0.0956 - matthews_correlation: 0.6504 - val_loss: 0.0833 - val_matthews_correlation: 0.6995
#
# Epoch 00022: val_matthews_correlation did not improve from 0.74189
# Epoch 23/50
# 2322/2322 [==============================] - 1s 482us/step - loss: 0.0909 - matthews_correlation: 0.6912 - val_loss: 0.0867 - val_matthews_correlation: 0.6222
#
# Epoch 00023: val_matthews_correlation did not improve from 0.74189
# Epoch 24/50
# 2322/2322 [==============================] - 1s 487us/step - loss: 0.0961 - matthews_correlation: 0.6595 - val_loss: 0.0977 - val_matthews_correlation: 0.5930
#
# Epoch 00024: val_matthews_correlation did not improve from 0.74189
# Epoch 25/50
# 2322/2322 [==============================] - 1s 500us/step - loss: 0.0899 - matthews_correlation: 0.6470 - val_loss: 0.1041 - val_matthews_correlation: 0.7142
#
# Epoch 00025: val_matthews_correlation did not improve from 0.74189
# Epoch 00025: early stopping
# Beginning fold 2
# Train on 2323 samples, validate on 581 samples
# Epoch 1/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.3023 - matthews_correlation: 0.0313 - val_loss: 0.1779 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_1.h5
# Epoch 2/50
# 2323/2323 [==============================] - 1s 489us/step - loss: 0.1697 - matthews_correlation: 0.1712 - val_loss: 0.1220 - val_matthews_correlation: 0.5640
#
# Epoch 00002: val_matthews_correlation improved from 0.00000 to 0.56396, saving model to weights_1.h5
# Epoch 3/50
# 2323/2323 [==============================] - 1s 486us/step - loss: 0.1367 - matthews_correlation: 0.3893 - val_loss: 0.1187 - val_matthews_correlation: 0.5078
#
# Epoch 00003: val_matthews_correlation did not improve from 0.56396
# Epoch 4/50
# 2323/2323 [==============================] - 1s 492us/step - loss: 0.1191 - matthews_correlation: 0.5561 - val_loss: 0.1001 - val_matthews_correlation: 0.7051
#
# Epoch 00004: val_matthews_correlation improved from 0.56396 to 0.70506, saving model to weights_1.h5
# Epoch 5/50
# 2323/2323 [==============================] - 1s 490us/step - loss: 0.1163 - matthews_correlation: 0.4722 - val_loss: 0.0859 - val_matthews_correlation: 0.7353
#
# Epoch 00005: val_matthews_correlation improved from 0.70506 to 0.73535, saving model to weights_1.h5
# Epoch 6/50
# 2323/2323 [==============================] - 1s 486us/step - loss: 0.1113 - matthews_correlation: 0.6080 - val_loss: 0.0827 - val_matthews_correlation: 0.7913
#
# Epoch 00006: val_matthews_correlation improved from 0.73535 to 0.79125, saving model to weights_1.h5
# Epoch 7/50
# 2323/2323 [==============================] - 1s 492us/step - loss: 0.1112 - matthews_correlation: 0.5284 - val_loss: 0.1196 - val_matthews_correlation: 0.5052
#
# Epoch 00007: val_matthews_correlation did not improve from 0.79125
# Epoch 8/50
# 2323/2323 [==============================] - 1s 492us/step - loss: 0.1024 - matthews_correlation: 0.6488 - val_loss: 0.1011 - val_matthews_correlation: 0.6986
#
# Epoch 00008: val_matthews_correlation did not improve from 0.79125
# Epoch 9/50
# 2323/2323 [==============================] - 1s 487us/step - loss: 0.0987 - matthews_correlation: 0.6569 - val_loss: 0.2675 - val_matthews_correlation: 0.1344
#
# Epoch 00009: val_matthews_correlation did not improve from 0.79125
# Epoch 10/50
# 2323/2323 [==============================] - 1s 487us/step - loss: 0.1157 - matthews_correlation: 0.5422 - val_loss: 0.1524 - val_matthews_correlation: 0.6375
#
# Epoch 00010: val_matthews_correlation did not improve from 0.79125
# Epoch 11/50
# 2323/2323 [==============================] - 1s 496us/step - loss: 0.1079 - matthews_correlation: 0.5841 - val_loss: 0.0996 - val_matthews_correlation: 0.6519
#
# Epoch 00011: val_matthews_correlation did not improve from 0.79125
# Epoch 12/50
# 2323/2323 [==============================] - 1s 490us/step - loss: 0.1004 - matthews_correlation: 0.6230 - val_loss: 0.1542 - val_matthews_correlation: 0.3462
#
# Epoch 00012: val_matthews_correlation did not improve from 0.79125
# Epoch 13/50
# 2323/2323 [==============================] - 1s 493us/step - loss: 0.0991 - matthews_correlation: 0.6207 - val_loss: 0.0975 - val_matthews_correlation: 0.6446
#
# Epoch 00013: val_matthews_correlation did not improve from 0.79125
# Epoch 14/50
# 2323/2323 [==============================] - 1s 489us/step - loss: 0.0997 - matthews_correlation: 0.6162 - val_loss: 0.1213 - val_matthews_correlation: 0.5996
#
# Epoch 00014: val_matthews_correlation did not improve from 0.79125
# Epoch 15/50
# 2323/2323 [==============================] - 1s 492us/step - loss: 0.0998 - matthews_correlation: 0.6434 - val_loss: 0.1016 - val_matthews_correlation: 0.6717
#
# Epoch 00015: val_matthews_correlation did not improve from 0.79125
# Epoch 16/50
# 2323/2323 [==============================] - 1s 489us/step - loss: 0.1003 - matthews_correlation: 0.5976 - val_loss: 0.0930 - val_matthews_correlation: 0.6572
#
# Epoch 00016: val_matthews_correlation did not improve from 0.79125
# Epoch 17/50
# 2323/2323 [==============================] - 1s 487us/step - loss: 0.0957 - matthews_correlation: 0.6422 - val_loss: 0.0896 - val_matthews_correlation: 0.6954
#
# Epoch 00017: val_matthews_correlation did not improve from 0.79125
# Epoch 18/50
# 2323/2323 [==============================] - 1s 494us/step - loss: 0.0902 - matthews_correlation: 0.6918 - val_loss: 0.0961 - val_matthews_correlation: 0.6689
#
# Epoch 00018: val_matthews_correlation did not improve from 0.79125
# Epoch 19/50
# 2323/2323 [==============================] - 1s 489us/step - loss: 0.0912 - matthews_correlation: 0.6823 - val_loss: 0.1095 - val_matthews_correlation: 0.7002
#
# Epoch 00019: val_matthews_correlation did not improve from 0.79125
# Epoch 20/50
# 2323/2323 [==============================] - 1s 492us/step - loss: 0.0945 - matthews_correlation: 0.6279 - val_loss: 0.0958 - val_matthews_correlation: 0.7043
#
# Epoch 00020: val_matthews_correlation did not improve from 0.79125
# Epoch 21/50
# 2323/2323 [==============================] - 1s 489us/step - loss: 0.0916 - matthews_correlation: 0.6511 - val_loss: 0.0876 - val_matthews_correlation: 0.7252
#
# Epoch 00021: val_matthews_correlation did not improve from 0.79125
# Epoch 00021: early stopping
# Beginning fold 3
# Train on 2323 samples, validate on 581 samples
# Epoch 1/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.2318 - matthews_correlation: 0.0719 - val_loss: 0.1689 - val_matthews_correlation: 0.0517
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.05172, saving model to weights_2.h5
# Epoch 2/50
# 2323/2323 [==============================] - 1s 493us/step - loss: 0.1482 - matthews_correlation: 0.1944 - val_loss: 0.2783 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.05172
# Epoch 3/50
# 2323/2323 [==============================] - 1s 488us/step - loss: 0.1268 - matthews_correlation: 0.4355 - val_loss: 0.2085 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00003: val_matthews_correlation did not improve from 0.05172
# Epoch 4/50
# 2323/2323 [==============================] - 1s 488us/step - loss: 0.1312 - matthews_correlation: 0.5082 - val_loss: 0.1353 - val_matthews_correlation: 0.3019
#
# Epoch 00004: val_matthews_correlation improved from 0.05172 to 0.30187, saving model to weights_2.h5
# Epoch 5/50
# 2323/2323 [==============================] - 1s 491us/step - loss: 0.1128 - matthews_correlation: 0.5246 - val_loss: 0.1307 - val_matthews_correlation: 0.5965
#
# Epoch 00005: val_matthews_correlation improved from 0.30187 to 0.59654, saving model to weights_2.h5
# Epoch 6/50
# 2323/2323 [==============================] - 1s 492us/step - loss: 0.1100 - matthews_correlation: 0.6558 - val_loss: 0.1152 - val_matthews_correlation: 0.6789
#
# Epoch 00006: val_matthews_correlation improved from 0.59654 to 0.67890, saving model to weights_2.h5
# Epoch 7/50
# 2323/2323 [==============================] - 1s 490us/step - loss: 0.1014 - matthews_correlation: 0.6274 - val_loss: 0.1059 - val_matthews_correlation: 0.6519
#
# Epoch 00007: val_matthews_correlation did not improve from 0.67890
# Epoch 8/50
# 2323/2323 [==============================] - 1s 493us/step - loss: 0.1014 - matthews_correlation: 0.6090 - val_loss: 0.1458 - val_matthews_correlation: 0.4151
#
# Epoch 00008: val_matthews_correlation did not improve from 0.67890
# Epoch 9/50
# 2323/2323 [==============================] - 1s 493us/step - loss: 0.0993 - matthews_correlation: 0.6422 - val_loss: 0.1085 - val_matthews_correlation: 0.5700
#
# Epoch 00009: val_matthews_correlation did not improve from 0.67890
# Epoch 10/50
# 2323/2323 [==============================] - 1s 490us/step - loss: 0.0988 - matthews_correlation: 0.6758 - val_loss: 0.1324 - val_matthews_correlation: 0.5097
#
# Epoch 00010: val_matthews_correlation did not improve from 0.67890
# Epoch 11/50
# 2323/2323 [==============================] - 1s 495us/step - loss: 0.0979 - matthews_correlation: 0.6293 - val_loss: 0.1160 - val_matthews_correlation: 0.6165
#
# Epoch 00011: val_matthews_correlation did not improve from 0.67890
# Epoch 12/50
# 2323/2323 [==============================] - 1s 488us/step - loss: 0.0952 - matthews_correlation: 0.6743 - val_loss: 0.1523 - val_matthews_correlation: 0.4562
#
# Epoch 00012: val_matthews_correlation did not improve from 0.67890
# Epoch 13/50
# 2323/2323 [==============================] - 1s 493us/step - loss: 0.0950 - matthews_correlation: 0.6090 - val_loss: 0.1079 - val_matthews_correlation: 0.6654
#
# Epoch 00013: val_matthews_correlation did not improve from 0.67890
# Epoch 14/50
# 2323/2323 [==============================] - 1s 496us/step - loss: 0.0935 - matthews_correlation: 0.6544 - val_loss: 0.1166 - val_matthews_correlation: 0.6285
#
# Epoch 00014: val_matthews_correlation did not improve from 0.67890
# Epoch 15/50
# 2323/2323 [==============================] - 1s 487us/step - loss: 0.0931 - matthews_correlation: 0.6618 - val_loss: 0.1106 - val_matthews_correlation: 0.7788
#
# Epoch 00015: val_matthews_correlation improved from 0.67890 to 0.77875, saving model to weights_2.h5
# Epoch 16/50
# 2323/2323 [==============================] - 1s 490us/step - loss: 0.0958 - matthews_correlation: 0.6646 - val_loss: 0.1213 - val_matthews_correlation: 0.5796
#
# Epoch 00016: val_matthews_correlation did not improve from 0.77875
# Epoch 17/50
# 2323/2323 [==============================] - 1s 488us/step - loss: 0.0938 - matthews_correlation: 0.6661 - val_loss: 0.1229 - val_matthews_correlation: 0.5767
#
# Epoch 00017: val_matthews_correlation did not improve from 0.77875
# Epoch 18/50
# 2323/2323 [==============================] - 1s 494us/step - loss: 0.0926 - matthews_correlation: 0.6472 - val_loss: 0.1021 - val_matthews_correlation: 0.7487
#
# Epoch 00018: val_matthews_correlation did not improve from 0.77875
# Epoch 19/50
# 2323/2323 [==============================] - 1s 489us/step - loss: 0.0877 - matthews_correlation: 0.7352 - val_loss: 0.1179 - val_matthews_correlation: 0.6062
#
# Epoch 00019: val_matthews_correlation did not improve from 0.77875
# Epoch 20/50
# 2323/2323 [==============================] - 1s 488us/step - loss: 0.0937 - matthews_correlation: 0.6464 - val_loss: 0.1013 - val_matthews_correlation: 0.7260
#
# Epoch 00020: val_matthews_correlation did not improve from 0.77875
# Epoch 21/50
# 2323/2323 [==============================] - 1s 491us/step - loss: 0.0957 - matthews_correlation: 0.7004 - val_loss: 0.1276 - val_matthews_correlation: 0.6760
#
# Epoch 00021: val_matthews_correlation did not improve from 0.77875
# Epoch 22/50
# 2323/2323 [==============================] - 1s 489us/step - loss: 0.0879 - matthews_correlation: 0.6937 - val_loss: 0.0997 - val_matthews_correlation: 0.7174
#
# Epoch 00022: val_matthews_correlation did not improve from 0.77875
# Epoch 23/50
# 2323/2323 [==============================] - 1s 489us/step - loss: 0.1111 - matthews_correlation: 0.5957 - val_loss: 0.1698 - val_matthews_correlation: 0.6341
#
# Epoch 00023: val_matthews_correlation did not improve from 0.77875
# Epoch 24/50
# 2323/2323 [==============================] - 1s 492us/step - loss: 0.0934 - matthews_correlation: 0.6865 - val_loss: 0.1468 - val_matthews_correlation: 0.6783
#
# Epoch 00024: val_matthews_correlation did not improve from 0.77875
# Epoch 25/50
# 2323/2323 [==============================] - 1s 494us/step - loss: 0.0914 - matthews_correlation: 0.6821 - val_loss: 0.1021 - val_matthews_correlation: 0.7183
#
# Epoch 00025: val_matthews_correlation did not improve from 0.77875
# Epoch 26/50
# 2323/2323 [==============================] - 1s 489us/step - loss: 0.0851 - matthews_correlation: 0.6884 - val_loss: 0.1507 - val_matthews_correlation: 0.5697
#
# Epoch 00026: val_matthews_correlation did not improve from 0.77875
# Epoch 27/50
# 2323/2323 [==============================] - 1s 494us/step - loss: 0.0854 - matthews_correlation: 0.7158 - val_loss: 0.1061 - val_matthews_correlation: 0.7094
#
# Epoch 00027: val_matthews_correlation did not improve from 0.77875
# Epoch 28/50
# 2323/2323 [==============================] - 1s 491us/step - loss: 0.0826 - matthews_correlation: 0.7212 - val_loss: 0.1005 - val_matthews_correlation: 0.7594
#
# Epoch 00028: val_matthews_correlation did not improve from 0.77875
# Epoch 29/50
# 2323/2323 [==============================] - 1s 491us/step - loss: 0.0844 - matthews_correlation: 0.6942 - val_loss: 0.0992 - val_matthews_correlation: 0.7071
#
# Epoch 00029: val_matthews_correlation did not improve from 0.77875
# Epoch 30/50
# 2323/2323 [==============================] - 1s 495us/step - loss: 0.0865 - matthews_correlation: 0.7227 - val_loss: 0.1148 - val_matthews_correlation: 0.7406
#
# Epoch 00030: val_matthews_correlation did not improve from 0.77875
# Epoch 00030: early stopping
# Beginning fold 4
# Train on 2324 samples, validate on 580 samples
# Epoch 1/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.2671 - matthews_correlation: 0.1237 - val_loss: 0.1816 - val_matthews_correlation: 0.1397
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.13971, saving model to weights_3.h5
# Epoch 2/50
# 2324/2324 [==============================] - 1s 493us/step - loss: 0.1637 - matthews_correlation: 0.1469 - val_loss: 0.1715 - val_matthews_correlation: 0.2477
#
# Epoch 00002: val_matthews_correlation improved from 0.13971 to 0.24768, saving model to weights_3.h5
# Epoch 3/50
# 2324/2324 [==============================] - 1s 490us/step - loss: 0.1306 - matthews_correlation: 0.4850 - val_loss: 0.1676 - val_matthews_correlation: 0.3964
#
# Epoch 00003: val_matthews_correlation improved from 0.24768 to 0.39637, saving model to weights_3.h5
# Epoch 4/50
# 2324/2324 [==============================] - 1s 491us/step - loss: 0.1187 - matthews_correlation: 0.5513 - val_loss: 0.1353 - val_matthews_correlation: 0.6251
#
# Epoch 00004: val_matthews_correlation improved from 0.39637 to 0.62511, saving model to weights_3.h5
# Epoch 5/50
# 2324/2324 [==============================] - 1s 491us/step - loss: 0.1056 - matthews_correlation: 0.6447 - val_loss: 0.1218 - val_matthews_correlation: 0.4912
#
# Epoch 00005: val_matthews_correlation did not improve from 0.62511
# Epoch 6/50
# 2324/2324 [==============================] - 1s 492us/step - loss: 0.1010 - matthews_correlation: 0.6329 - val_loss: 0.1186 - val_matthews_correlation: 0.5200
#
# Epoch 00006: val_matthews_correlation did not improve from 0.62511
# Epoch 7/50
# 2324/2324 [==============================] - 1s 492us/step - loss: 0.1005 - matthews_correlation: 0.6210 - val_loss: 0.1242 - val_matthews_correlation: 0.6214
#
# Epoch 00007: val_matthews_correlation did not improve from 0.62511
# Epoch 8/50
# 2324/2324 [==============================] - 1s 492us/step - loss: 0.1041 - matthews_correlation: 0.6550 - val_loss: 0.2350 - val_matthews_correlation: 0.5022
#
# Epoch 00008: val_matthews_correlation did not improve from 0.62511
# Epoch 9/50
# 2324/2324 [==============================] - 1s 493us/step - loss: 0.1031 - matthews_correlation: 0.6259 - val_loss: 0.1223 - val_matthews_correlation: 0.5596
#
# Epoch 00009: val_matthews_correlation did not improve from 0.62511
# Epoch 10/50
# 2324/2324 [==============================] - 1s 484us/step - loss: 0.0978 - matthews_correlation: 0.6402 - val_loss: 0.1873 - val_matthews_correlation: 0.2721
#
# Epoch 00010: val_matthews_correlation did not improve from 0.62511
# Epoch 11/50
# 2324/2324 [==============================] - 1s 492us/step - loss: 0.0952 - matthews_correlation: 0.6708 - val_loss: 0.1159 - val_matthews_correlation: 0.6097
#
# Epoch 00011: val_matthews_correlation did not improve from 0.62511
# Epoch 12/50
# 2324/2324 [==============================] - 1s 496us/step - loss: 0.0908 - matthews_correlation: 0.6575 - val_loss: 0.1352 - val_matthews_correlation: 0.6106
#
# Epoch 00012: val_matthews_correlation did not improve from 0.62511
# Epoch 13/50
# 2324/2324 [==============================] - 1s 491us/step - loss: 0.0897 - matthews_correlation: 0.6858 - val_loss: 0.1168 - val_matthews_correlation: 0.5992
#
# Epoch 00013: val_matthews_correlation did not improve from 0.62511
# Epoch 14/50
# 2324/2324 [==============================] - 1s 492us/step - loss: 0.0878 - matthews_correlation: 0.6838 - val_loss: 0.1174 - val_matthews_correlation: 0.5938
#
# Epoch 00014: val_matthews_correlation did not improve from 0.62511
# Epoch 15/50
# 2324/2324 [==============================] - 1s 492us/step - loss: 0.0899 - matthews_correlation: 0.6956 - val_loss: 0.1216 - val_matthews_correlation: 0.6004
#
# Epoch 00015: val_matthews_correlation did not improve from 0.62511
# Epoch 16/50
# 2324/2324 [==============================] - 1s 493us/step - loss: 0.0919 - matthews_correlation: 0.6921 - val_loss: 0.1238 - val_matthews_correlation: 0.5320
#
# Epoch 00016: val_matthews_correlation did not improve from 0.62511
# Epoch 17/50
# 2324/2324 [==============================] - 1s 490us/step - loss: 0.0852 - matthews_correlation: 0.7191 - val_loss: 0.1808 - val_matthews_correlation: 0.2721
#
# Epoch 00017: val_matthews_correlation did not improve from 0.62511
# Epoch 18/50
# 2324/2324 [==============================] - 1s 490us/step - loss: 0.0906 - matthews_correlation: 0.6799 - val_loss: 0.1180 - val_matthews_correlation: 0.5934
#
# Epoch 00018: val_matthews_correlation did not improve from 0.62511
# Epoch 19/50
# 2324/2324 [==============================] - 1s 487us/step - loss: 0.0865 - matthews_correlation: 0.7203 - val_loss: 0.1501 - val_matthews_correlation: 0.5801
#
# Epoch 00019: val_matthews_correlation did not improve from 0.62511
# Epoch 00019: early stopping
# Beginning fold 5
# Train on 2324 samples, validate on 580 samples
# Epoch 1/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.2521 - matthews_correlation: 0.1290 - val_loss: 0.2529 - val_matthews_correlation: 0.2267
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.22671, saving model to weights_4.h5
# Epoch 2/50
# 2324/2324 [==============================] - 1s 490us/step - loss: 0.1530 - matthews_correlation: 0.2707 - val_loss: 0.1752 - val_matthews_correlation: 0.2620
#
# Epoch 00002: val_matthews_correlation improved from 0.22671 to 0.26198, saving model to weights_4.h5
# Epoch 3/50
# 2324/2324 [==============================] - 1s 491us/step - loss: 0.1137 - matthews_correlation: 0.5784 - val_loss: 0.1289 - val_matthews_correlation: 0.4234
#
# Epoch 00003: val_matthews_correlation improved from 0.26198 to 0.42342, saving model to weights_4.h5
# Epoch 4/50
# 2324/2324 [==============================] - 1s 488us/step - loss: 0.1058 - matthews_correlation: 0.5789 - val_loss: 0.2254 - val_matthews_correlation: 0.2662
#
# Epoch 00004: val_matthews_correlation did not improve from 0.42342
# Epoch 5/50
# 2324/2324 [==============================] - 1s 488us/step - loss: 0.1004 - matthews_correlation: 0.6536 - val_loss: 0.1907 - val_matthews_correlation: 0.4780
#
# Epoch 00005: val_matthews_correlation improved from 0.42342 to 0.47797, saving model to weights_4.h5
# Epoch 6/50
# 2324/2324 [==============================] - 1s 493us/step - loss: 0.1192 - matthews_correlation: 0.6184 - val_loss: 0.1979 - val_matthews_correlation: 0.3459
#
# Epoch 00006: val_matthews_correlation did not improve from 0.47797
# Epoch 7/50
# 2324/2324 [==============================] - 1s 489us/step - loss: 0.1045 - matthews_correlation: 0.6541 - val_loss: 0.1509 - val_matthews_correlation: 0.4768
#
# Epoch 00007: val_matthews_correlation did not improve from 0.47797
# Epoch 8/50
# 2324/2324 [==============================] - 1s 488us/step - loss: 0.0972 - matthews_correlation: 0.6573 - val_loss: 0.1373 - val_matthews_correlation: 0.5118
#
# Epoch 00008: val_matthews_correlation improved from 0.47797 to 0.51178, saving model to weights_4.h5
# Epoch 9/50
# 2324/2324 [==============================] - 1s 485us/step - loss: 0.1001 - matthews_correlation: 0.6287 - val_loss: 0.1239 - val_matthews_correlation: 0.5410
#
# Epoch 00009: val_matthews_correlation improved from 0.51178 to 0.54102, saving model to weights_4.h5
# Epoch 10/50
# 2324/2324 [==============================] - 1s 490us/step - loss: 0.0887 - matthews_correlation: 0.7258 - val_loss: 0.2116 - val_matthews_correlation: 0.3826
#
# Epoch 00010: val_matthews_correlation did not improve from 0.54102
# Epoch 11/50
# 2324/2324 [==============================] - 1s 488us/step - loss: 0.0957 - matthews_correlation: 0.6532 - val_loss: 0.1404 - val_matthews_correlation: 0.4297
#
# Epoch 00011: val_matthews_correlation did not improve from 0.54102
# Epoch 12/50
# 2324/2324 [==============================] - 1s 488us/step - loss: 0.0921 - matthews_correlation: 0.6731 - val_loss: 0.1332 - val_matthews_correlation: 0.4777
#
# Epoch 00012: val_matthews_correlation did not improve from 0.54102
# Epoch 13/50
# 2324/2324 [==============================] - 1s 487us/step - loss: 0.0884 - matthews_correlation: 0.7283 - val_loss: 0.1254 - val_matthews_correlation: 0.4645
#
# Epoch 00013: val_matthews_correlation did not improve from 0.54102
# Epoch 14/50
# 2324/2324 [==============================] - 1s 485us/step - loss: 0.0902 - matthews_correlation: 0.6853 - val_loss: 0.1220 - val_matthews_correlation: 0.5464
#
# Epoch 00014: val_matthews_correlation improved from 0.54102 to 0.54640, saving model to weights_4.h5
# Epoch 15/50
# 2324/2324 [==============================] - 1s 485us/step - loss: 0.0889 - matthews_correlation: 0.6837 - val_loss: 0.1337 - val_matthews_correlation: 0.6179
#
# Epoch 00015: val_matthews_correlation improved from 0.54640 to 0.61790, saving model to weights_4.h5
# Epoch 16/50
# 2324/2324 [==============================] - 1s 488us/step - loss: 0.0920 - matthews_correlation: 0.6650 - val_loss: 0.1243 - val_matthews_correlation: 0.5210
#
# Epoch 00016: val_matthews_correlation did not improve from 0.61790
# Epoch 17/50
# 2324/2324 [==============================] - 1s 487us/step - loss: 0.0890 - matthews_correlation: 0.6893 - val_loss: 0.1206 - val_matthews_correlation: 0.5455
#
# Epoch 00017: val_matthews_correlation did not improve from 0.61790
# Epoch 18/50
# 2324/2324 [==============================] - 1s 487us/step - loss: 0.0920 - matthews_correlation: 0.6672 - val_loss: 0.1430 - val_matthews_correlation: 0.4953
#
# Epoch 00018: val_matthews_correlation did not improve from 0.61790
# Epoch 19/50
# 2324/2324 [==============================] - 1s 491us/step - loss: 0.0972 - matthews_correlation: 0.6583 - val_loss: 0.1446 - val_matthews_correlation: 0.4544
#
# Epoch 00019: val_matthews_correlation did not improve from 0.61790
# Epoch 20/50
# 2324/2324 [==============================] - 1s 493us/step - loss: 0.0883 - matthews_correlation: 0.7319 - val_loss: 0.1248 - val_matthews_correlation: 0.4991
#
# Epoch 00020: val_matthews_correlation did not improve from 0.61790
# Epoch 21/50
# 2324/2324 [==============================] - 1s 491us/step - loss: 0.0871 - matthews_correlation: 0.7190 - val_loss: 0.1575 - val_matthews_correlation: 0.4078
#
# Epoch 00021: val_matthews_correlation did not improve from 0.61790
# Epoch 22/50
# 2324/2324 [==============================] - 1s 491us/step - loss: 0.0847 - matthews_correlation: 0.7094 - val_loss: 0.1256 - val_matthews_correlation: 0.5286
#
# Epoch 00022: val_matthews_correlation did not improve from 0.61790
# Epoch 23/50
# 2324/2324 [==============================] - 1s 493us/step - loss: 0.0824 - matthews_correlation: 0.6946 - val_loss: 0.1650 - val_matthews_correlation: 0.3898
#
# Epoch 00023: val_matthews_correlation did not improve from 0.61790
# Epoch 24/50
# 2324/2324 [==============================] - 1s 489us/step - loss: 0.0871 - matthews_correlation: 0.7349 - val_loss: 0.1282 - val_matthews_correlation: 0.5904
#
# Epoch 00024: val_matthews_correlation did not improve from 0.61790
# Epoch 25/50
# 2324/2324 [==============================] - 1s 491us/step - loss: 0.0815 - matthews_correlation: 0.7209 - val_loss: 0.1461 - val_matthews_correlation: 0.3930
#
# Epoch 00025: val_matthews_correlation did not improve from 0.61790
# Epoch 26/50
# 2324/2324 [==============================] - 1s 487us/step - loss: 0.0839 - matthews_correlation: 0.7145 - val_loss: 0.1553 - val_matthews_correlation: 0.4344
#
# Epoch 00026: val_matthews_correlation did not improve from 0.61790
# Epoch 27/50
# 2324/2324 [==============================] - 1s 492us/step - loss: 0.0796 - matthews_correlation: 0.7369 - val_loss: 0.1244 - val_matthews_correlation: 0.4359
#
# Epoch 00027: val_matthews_correlation did not improve from 0.61790
# Epoch 28/50
# 2324/2324 [==============================] - 1s 489us/step - loss: 0.0794 - matthews_correlation: 0.7383 - val_loss: 0.1435 - val_matthews_correlation: 0.4641
#
# Epoch 00028: val_matthews_correlation did not improve from 0.61790
# Epoch 29/50
# 2324/2324 [==============================] - 1s 494us/step - loss: 0.0785 - matthews_correlation: 0.7317 - val_loss: 0.1488 - val_matthews_correlation: 0.4659
#
# Epoch 00029: val_matthews_correlation did not improve from 0.61790
# Epoch 30/50
# 2324/2324 [==============================] - 1s 495us/step - loss: 0.0773 - matthews_correlation: 0.7009 - val_loss: 0.1324 - val_matthews_correlation: 0.5975
#
# Epoch 00030: val_matthews_correlation did not improve from 0.61790
# Epoch 00030: early stopping
# Beginning fold 6
# Train on 2322 samples, validate on 582 samples
# Epoch 1/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.3164 - matthews_correlation: 0.1123 - val_loss: 0.1841 - val_matthews_correlation: 0.2954
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.29541, saving model to weights_5.h5
# Epoch 2/50
# 2322/2322 [==============================] - 1s 454us/step - loss: 0.1513 - matthews_correlation: 0.3245 - val_loss: 0.1443 - val_matthews_correlation: 0.4034
#
# Epoch 00002: val_matthews_correlation improved from 0.29541 to 0.40343, saving model to weights_5.h5
# Epoch 3/50
# 2322/2322 [==============================] - 1s 454us/step - loss: 0.1284 - matthews_correlation: 0.4681 - val_loss: 0.1315 - val_matthews_correlation: 0.6731
#
# Epoch 00003: val_matthews_correlation improved from 0.40343 to 0.67307, saving model to weights_5.h5
# Epoch 4/50
# 2322/2322 [==============================] - 1s 453us/step - loss: 0.1041 - matthews_correlation: 0.6000 - val_loss: 0.1882 - val_matthews_correlation: 0.2986
#
# Epoch 00004: val_matthews_correlation did not improve from 0.67307
# Epoch 5/50
# 2322/2322 [==============================] - 1s 453us/step - loss: 0.1150 - matthews_correlation: 0.5581 - val_loss: 0.1251 - val_matthews_correlation: 0.5232
#
# Epoch 00005: val_matthews_correlation did not improve from 0.67307
# Epoch 6/50
# 2322/2322 [==============================] - 1s 476us/step - loss: 0.1089 - matthews_correlation: 0.6332 - val_loss: 0.1522 - val_matthews_correlation: 0.4034
#
# Epoch 00006: val_matthews_correlation did not improve from 0.67307
# Epoch 7/50
# 2322/2322 [==============================] - 1s 492us/step - loss: 0.1015 - matthews_correlation: 0.6490 - val_loss: 0.1978 - val_matthews_correlation: 0.4959
#
# Epoch 00007: val_matthews_correlation did not improve from 0.67307
# Epoch 8/50
# 2322/2322 [==============================] - 1s 496us/step - loss: 0.1014 - matthews_correlation: 0.6390 - val_loss: 0.1734 - val_matthews_correlation: 0.5718
#
# Epoch 00008: val_matthews_correlation did not improve from 0.67307
# Epoch 9/50
# 2322/2322 [==============================] - 1s 493us/step - loss: 0.0946 - matthews_correlation: 0.6551 - val_loss: 0.1049 - val_matthews_correlation: 0.6621
#
# Epoch 00009: val_matthews_correlation did not improve from 0.67307
# Epoch 10/50
# 2322/2322 [==============================] - 1s 489us/step - loss: 0.0938 - matthews_correlation: 0.6729 - val_loss: 0.1355 - val_matthews_correlation: 0.4791
#
# Epoch 00010: val_matthews_correlation did not improve from 0.67307
# Epoch 11/50
# 2322/2322 [==============================] - 1s 490us/step - loss: 0.0962 - matthews_correlation: 0.6386 - val_loss: 0.1185 - val_matthews_correlation: 0.5904
#
# Epoch 00011: val_matthews_correlation did not improve from 0.67307
# Epoch 12/50
# 2322/2322 [==============================] - 1s 492us/step - loss: 0.0983 - matthews_correlation: 0.6741 - val_loss: 0.1168 - val_matthews_correlation: 0.5746
#
# Epoch 00012: val_matthews_correlation did not improve from 0.67307
# Epoch 13/50
# 2322/2322 [==============================] - 1s 490us/step - loss: 0.0916 - matthews_correlation: 0.6584 - val_loss: 0.1174 - val_matthews_correlation: 0.5970
#
# Epoch 00013: val_matthews_correlation did not improve from 0.67307
# Epoch 14/50
# 2322/2322 [==============================] - 1s 488us/step - loss: 0.0906 - matthews_correlation: 0.6831 - val_loss: 0.1147 - val_matthews_correlation: 0.5763
#
# Epoch 00014: val_matthews_correlation did not improve from 0.67307
# Epoch 15/50
# 2322/2322 [==============================] - 1s 490us/step - loss: 0.0949 - matthews_correlation: 0.6741 - val_loss: 0.1243 - val_matthews_correlation: 0.5516
#
# Epoch 00015: val_matthews_correlation did not improve from 0.67307
# Epoch 16/50
# 2322/2322 [==============================] - 1s 491us/step - loss: 0.1030 - matthews_correlation: 0.6187 - val_loss: 0.1135 - val_matthews_correlation: 0.6323
#
# Epoch 00016: val_matthews_correlation did not improve from 0.67307
# Epoch 17/50
# 2322/2322 [==============================] - 1s 491us/step - loss: 0.0882 - matthews_correlation: 0.6800 - val_loss: 0.1080 - val_matthews_correlation: 0.6622
#
# Epoch 00017: val_matthews_correlation did not improve from 0.67307
# Epoch 18/50
# 2322/2322 [==============================] - 1s 491us/step - loss: 0.0915 - matthews_correlation: 0.6363 - val_loss: 0.1064 - val_matthews_correlation: 0.6634
#
# Epoch 00018: val_matthews_correlation did not improve from 0.67307
# Epoch 00018: early stopping
# Beginning fold 7
# Train on 2323 samples, validate on 581 samples
# Epoch 1/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.2768 - matthews_correlation: 0.1509 - val_loss: 0.2254 - val_matthews_correlation: 0.1716
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.17164, saving model to weights_6.h5
# Epoch 2/50
# 2323/2323 [==============================] - 1s 497us/step - loss: 0.1754 - matthews_correlation: 0.2097 - val_loss: 0.2047 - val_matthews_correlation: 0.1229
#
# Epoch 00002: val_matthews_correlation did not improve from 0.17164
# Epoch 3/50
# 2323/2323 [==============================] - 1s 494us/step - loss: 0.1395 - matthews_correlation: 0.4824 - val_loss: 0.2928 - val_matthews_correlation: 0.1537
#
# Epoch 00003: val_matthews_correlation did not improve from 0.17164
# Epoch 4/50
# 2323/2323 [==============================] - 1s 489us/step - loss: 0.1164 - matthews_correlation: 0.5988 - val_loss: 0.1886 - val_matthews_correlation: 0.2791
#
# Epoch 00004: val_matthews_correlation improved from 0.17164 to 0.27906, saving model to weights_6.h5
# Epoch 5/50
# 2323/2323 [==============================] - 1s 492us/step - loss: 0.1062 - matthews_correlation: 0.6042 - val_loss: 0.1383 - val_matthews_correlation: 0.3086
#
# Epoch 00005: val_matthews_correlation improved from 0.27906 to 0.30857, saving model to weights_6.h5
# Epoch 6/50
# 2323/2323 [==============================] - 1s 491us/step - loss: 0.1125 - matthews_correlation: 0.6210 - val_loss: 0.1636 - val_matthews_correlation: 0.5701
#
# Epoch 00006: val_matthews_correlation improved from 0.30857 to 0.57011, saving model to weights_6.h5
# Epoch 7/50
# 2323/2323 [==============================] - 1s 494us/step - loss: 0.1002 - matthews_correlation: 0.5918 - val_loss: 0.1292 - val_matthews_correlation: 0.4609
#
# Epoch 00007: val_matthews_correlation did not improve from 0.57011
# Epoch 8/50
# 2323/2323 [==============================] - 1s 496us/step - loss: 0.0937 - matthews_correlation: 0.6877 - val_loss: 0.1858 - val_matthews_correlation: 0.3718
#
# Epoch 00008: val_matthews_correlation did not improve from 0.57011
# Epoch 9/50
# 2323/2323 [==============================] - 1s 488us/step - loss: 0.0921 - matthews_correlation: 0.6973 - val_loss: 0.1488 - val_matthews_correlation: 0.5945
#
# Epoch 00009: val_matthews_correlation improved from 0.57011 to 0.59448, saving model to weights_6.h5
# Epoch 10/50
# 2323/2323 [==============================] - 1s 491us/step - loss: 0.0991 - matthews_correlation: 0.6743 - val_loss: 0.1523 - val_matthews_correlation: 0.3698
#
# Epoch 00010: val_matthews_correlation did not improve from 0.59448
# Epoch 11/50
# 2323/2323 [==============================] - 1s 493us/step - loss: 0.0940 - matthews_correlation: 0.6971 - val_loss: 0.1285 - val_matthews_correlation: 0.4805
#
# Epoch 00011: val_matthews_correlation did not improve from 0.59448
# Epoch 12/50
# 2323/2323 [==============================] - 1s 493us/step - loss: 0.0867 - matthews_correlation: 0.6910 - val_loss: 0.1605 - val_matthews_correlation: 0.6084
#
# Epoch 00012: val_matthews_correlation improved from 0.59448 to 0.60844, saving model to weights_6.h5
# Epoch 13/50
# 2323/2323 [==============================] - 1s 490us/step - loss: 0.0909 - matthews_correlation: 0.6880 - val_loss: 0.1666 - val_matthews_correlation: 0.4049
#
# Epoch 00013: val_matthews_correlation did not improve from 0.60844
# Epoch 14/50
# 2323/2323 [==============================] - 1s 493us/step - loss: 0.0878 - matthews_correlation: 0.7514 - val_loss: 0.1869 - val_matthews_correlation: 0.2402
#
# Epoch 00014: val_matthews_correlation did not improve from 0.60844
# Epoch 15/50
# 2323/2323 [==============================] - 1s 496us/step - loss: 0.0983 - matthews_correlation: 0.6857 - val_loss: 0.1695 - val_matthews_correlation: 0.4912
#
# Epoch 00015: val_matthews_correlation did not improve from 0.60844
# Epoch 16/50
# 2323/2323 [==============================] - 1s 492us/step - loss: 0.0965 - matthews_correlation: 0.6651 - val_loss: 0.1399 - val_matthews_correlation: 0.2849
#
# Epoch 00016: val_matthews_correlation did not improve from 0.60844
# Epoch 17/50
# 2323/2323 [==============================] - 1s 495us/step - loss: 0.0867 - matthews_correlation: 0.7254 - val_loss: 0.1381 - val_matthews_correlation: 0.4429
#
# Epoch 00017: val_matthews_correlation did not improve from 0.60844
# Epoch 18/50
# 2323/2323 [==============================] - 1s 487us/step - loss: 0.0891 - matthews_correlation: 0.6949 - val_loss: 0.1288 - val_matthews_correlation: 0.5024
#
# Epoch 00018: val_matthews_correlation did not improve from 0.60844
# Epoch 19/50
# 2323/2323 [==============================] - 1s 491us/step - loss: 0.0908 - matthews_correlation: 0.7019 - val_loss: 0.1646 - val_matthews_correlation: 0.5608
#
# Epoch 00019: val_matthews_correlation did not improve from 0.60844
# Epoch 20/50
# 2323/2323 [==============================] - 1s 492us/step - loss: 0.0852 - matthews_correlation: 0.7275 - val_loss: 0.1246 - val_matthews_correlation: 0.5421
#
# Epoch 00020: val_matthews_correlation did not improve from 0.60844
# Epoch 21/50
# 2323/2323 [==============================] - 1s 490us/step - loss: 0.0811 - matthews_correlation: 0.7472 - val_loss: 0.1687 - val_matthews_correlation: 0.5878
#
# Epoch 00021: val_matthews_correlation did not improve from 0.60844
# Epoch 22/50
# 2323/2323 [==============================] - 1s 490us/step - loss: 0.0851 - matthews_correlation: 0.7174 - val_loss: 0.1213 - val_matthews_correlation: 0.4838
#
# Epoch 00022: val_matthews_correlation did not improve from 0.60844
# Epoch 23/50
# 2323/2323 [==============================] - 1s 492us/step - loss: 0.0801 - matthews_correlation: 0.7428 - val_loss: 0.1361 - val_matthews_correlation: 0.4612
#
# Epoch 00023: val_matthews_correlation did not improve from 0.60844
# Epoch 24/50
# 2323/2323 [==============================] - 1s 491us/step - loss: 0.0810 - matthews_correlation: 0.7723 - val_loss: 0.1853 - val_matthews_correlation: 0.3344
#
# Epoch 00024: val_matthews_correlation did not improve from 0.60844
# Epoch 25/50
# 2323/2323 [==============================] - 1s 493us/step - loss: 0.1020 - matthews_correlation: 0.6317 - val_loss: 0.1577 - val_matthews_correlation: 0.4132
#
# Epoch 00025: val_matthews_correlation did not improve from 0.60844
# Epoch 26/50
# 2323/2323 [==============================] - 1s 490us/step - loss: 0.0896 - matthews_correlation: 0.6993 - val_loss: 0.1219 - val_matthews_correlation: 0.6372
#
# Epoch 00026: val_matthews_correlation improved from 0.60844 to 0.63719, saving model to weights_6.h5
# Epoch 27/50
# 2323/2323 [==============================] - 1s 490us/step - loss: 0.0819 - matthews_correlation: 0.7159 - val_loss: 0.1300 - val_matthews_correlation: 0.4665
#
# Epoch 00027: val_matthews_correlation did not improve from 0.63719
# Epoch 28/50
# 2323/2323 [==============================] - 1s 491us/step - loss: 0.0806 - matthews_correlation: 0.7709 - val_loss: 0.1153 - val_matthews_correlation: 0.6136
#
# Epoch 00028: val_matthews_correlation did not improve from 0.63719
# Epoch 29/50
# 2323/2323 [==============================] - 1s 497us/step - loss: 0.0792 - matthews_correlation: 0.7434 - val_loss: 0.1387 - val_matthews_correlation: 0.3603
#
# Epoch 00029: val_matthews_correlation did not improve from 0.63719
# Epoch 30/50
# 2323/2323 [==============================] - 1s 492us/step - loss: 0.0868 - matthews_correlation: 0.6862 - val_loss: 0.1239 - val_matthews_correlation: 0.5122
#
# Epoch 00030: val_matthews_correlation did not improve from 0.63719
# Epoch 31/50
# 2323/2323 [==============================] - 1s 494us/step - loss: 0.0850 - matthews_correlation: 0.6953 - val_loss: 0.1271 - val_matthews_correlation: 0.5361
#
# Epoch 00031: val_matthews_correlation did not improve from 0.63719
# Epoch 32/50
# 2323/2323 [==============================] - 1s 492us/step - loss: 0.0820 - matthews_correlation: 0.7159 - val_loss: 0.1457 - val_matthews_correlation: 0.4469
#
# Epoch 00032: val_matthews_correlation did not improve from 0.63719
# Epoch 33/50
# 2323/2323 [==============================] - 1s 492us/step - loss: 0.0746 - matthews_correlation: 0.7434 - val_loss: 0.1363 - val_matthews_correlation: 0.6265
#
# Epoch 00033: val_matthews_correlation did not improve from 0.63719
# Epoch 34/50
# 2323/2323 [==============================] - 1s 490us/step - loss: 0.0724 - matthews_correlation: 0.7522 - val_loss: 0.1447 - val_matthews_correlation: 0.4083
#
# Epoch 00034: val_matthews_correlation did not improve from 0.63719
# Epoch 35/50
# 2323/2323 [==============================] - 1s 491us/step - loss: 0.0704 - matthews_correlation: 0.7628 - val_loss: 0.1282 - val_matthews_correlation: 0.5460
#
# Epoch 00035: val_matthews_correlation did not improve from 0.63719
# Epoch 36/50
# 2323/2323 [==============================] - 1s 493us/step - loss: 0.0780 - matthews_correlation: 0.7141 - val_loss: 0.1450 - val_matthews_correlation: 0.6587
#
# Epoch 00036: val_matthews_correlation improved from 0.63719 to 0.65872, saving model to weights_6.h5
# Epoch 37/50
# 2323/2323 [==============================] - 1s 489us/step - loss: 0.0795 - matthews_correlation: 0.7268 - val_loss: 0.1444 - val_matthews_correlation: 0.3399
#
# Epoch 00037: val_matthews_correlation did not improve from 0.65872
# Epoch 38/50
# 2323/2323 [==============================] - 1s 494us/step - loss: 0.0775 - matthews_correlation: 0.7546 - val_loss: 0.1414 - val_matthews_correlation: 0.5009
#
# Epoch 00038: val_matthews_correlation did not improve from 0.65872
# Epoch 39/50
# 2323/2323 [==============================] - 1s 497us/step - loss: 0.0720 - matthews_correlation: 0.7671 - val_loss: 0.1550 - val_matthews_correlation: 0.5198
#
# Epoch 00039: val_matthews_correlation did not improve from 0.65872
# Epoch 40/50
# 2323/2323 [==============================] - 1s 494us/step - loss: 0.0786 - matthews_correlation: 0.7473 - val_loss: 0.1453 - val_matthews_correlation: 0.5624
#
# Epoch 00040: val_matthews_correlation did not improve from 0.65872
# Epoch 41/50
# 2323/2323 [==============================] - 1s 492us/step - loss: 0.0759 - matthews_correlation: 0.7325 - val_loss: 0.1589 - val_matthews_correlation: 0.2498
#
# Epoch 00041: val_matthews_correlation did not improve from 0.65872
# Epoch 42/50
# 2323/2323 [==============================] - 1s 494us/step - loss: 0.0754 - matthews_correlation: 0.7370 - val_loss: 0.1266 - val_matthews_correlation: 0.5664
#
# Epoch 00042: val_matthews_correlation did not improve from 0.65872
# Epoch 43/50
# 2323/2323 [==============================] - 1s 495us/step - loss: 0.0730 - matthews_correlation: 0.7794 - val_loss: 0.1339 - val_matthews_correlation: 0.5460
#
# Epoch 00043: val_matthews_correlation did not improve from 0.65872
# Epoch 44/50
# 2323/2323 [==============================] - 1s 488us/step - loss: 0.0752 - matthews_correlation: 0.7483 - val_loss: 0.1245 - val_matthews_correlation: 0.5359
#
# Epoch 00044: val_matthews_correlation did not improve from 0.65872
# Epoch 45/50
# 2323/2323 [==============================] - 1s 494us/step - loss: 0.0753 - matthews_correlation: 0.7719 - val_loss: 0.1302 - val_matthews_correlation: 0.5445
#
# Epoch 00045: val_matthews_correlation did not improve from 0.65872
# Epoch 46/50
# 2323/2323 [==============================] - 1s 492us/step - loss: 0.0729 - matthews_correlation: 0.7668 - val_loss: 0.1748 - val_matthews_correlation: 0.4340
#
# Epoch 00046: val_matthews_correlation did not improve from 0.65872
# Epoch 47/50
# 2323/2323 [==============================] - 1s 492us/step - loss: 0.0732 - matthews_correlation: 0.7494 - val_loss: 0.1301 - val_matthews_correlation: 0.5569
#
# Epoch 00047: val_matthews_correlation did not improve from 0.65872
# Epoch 48/50
# 2323/2323 [==============================] - 1s 491us/step - loss: 0.0746 - matthews_correlation: 0.7362 - val_loss: 0.1207 - val_matthews_correlation: 0.7034
#
# Epoch 00048: val_matthews_correlation improved from 0.65872 to 0.70338, saving model to weights_6.h5
# Epoch 49/50
# 2323/2323 [==============================] - 1s 492us/step - loss: 0.0682 - matthews_correlation: 0.7817 - val_loss: 0.1441 - val_matthews_correlation: 0.5291
#
# Epoch 00049: val_matthews_correlation did not improve from 0.70338
# Epoch 50/50
# 2323/2323 [==============================] - 1s 488us/step - loss: 0.0648 - matthews_correlation: 0.7829 - val_loss: 0.1361 - val_matthews_correlation: 0.5843
#
# ...
# Epoch 36/50
# 2324/2324 [==============================] - 1s 491us/step - loss: 0.0818 - matthews_correlation: 0.7418 - val_loss: 0.0837 - val_matthews_correlation: 0.8259
#
# Epoch 00036: val_matthews_correlation improved from 0.76947 to 0.82586, saving model to weights_8.h5
# Epoch 37/50
# 2324/2324 [==============================] - 1s 490us/step - loss: 0.0911 - matthews_correlation: 0.6948 - val_loss: 0.1142 - val_matthews_correlation: 0.6536
#
# Epoch 00037: val_matthews_correlation did not improve from 0.82586
# Epoch 38/50
# 2324/2324 [==============================] - 1s 496us/step - loss: 0.0852 - matthews_correlation: 0.6866 - val_loss: 0.0990 - val_matthews_correlation: 0.8082
#
# Epoch 00038: val_matthews_correlation did not improve from 0.82586
# Epoch 39/50
# 2324/2324 [==============================] - 1s 496us/step - loss: 0.0827 - matthews_correlation: 0.7151 - val_loss: 0.0894 - val_matthews_correlation: 0.7941
#
# Epoch 00039: val_matthews_correlation did not improve from 0.82586
# Epoch 40/50
# 2324/2324 [==============================] - 1s 492us/step - loss: 0.0839 - matthews_correlation: 0.7076 - val_loss: 0.1013 - val_matthews_correlation: 0.7735
#
# Epoch 00040: val_matthews_correlation did not improve from 0.82586
# Epoch 41/50
# 2324/2324 [==============================] - 1s 490us/step - loss: 0.0820 - matthews_correlation: 0.7009 - val_loss: 0.1023 - val_matthews_correlation: 0.7506
#
# Epoch 00041: val_matthews_correlation did not improve from 0.82586
# Epoch 42/50
# 2324/2324 [==============================] - 1s 490us/step - loss: 0.0793 - matthews_correlation: 0.7423 - val_loss: 0.0912 - val_matthews_correlation: 0.7506
#
# Epoch 00042: val_matthews_correlation did not improve from 0.82586
# Epoch 43/50
# 2324/2324 [==============================] - 1s 496us/step - loss: 0.0796 - matthews_correlation: 0.7183 - val_loss: 0.0916 - val_matthews_correlation: 0.7791
#
# Epoch 00043: val_matthews_correlation did not improve from 0.82586
# Epoch 44/50
# 2324/2324 [==============================] - 1s 494us/step - loss: 0.0816 - matthews_correlation: 0.6877 - val_loss: 0.0907 - val_matthews_correlation: 0.6691
#
# Epoch 00044: val_matthews_correlation did not improve from 0.82586
# Epoch 45/50
# 2324/2324 [==============================] - 1s 485us/step - loss: 0.0773 - matthews_correlation: 0.7272 - val_loss: 0.0930 - val_matthews_correlation: 0.7925
#
# Epoch 00045: val_matthews_correlation did not improve from 0.82586
# Epoch 46/50
# 2324/2324 [==============================] - 1s 491us/step - loss: 0.0791 - matthews_correlation: 0.7282 - val_loss: 0.1091 - val_matthews_correlation: 0.7539
#
# Epoch 00046: val_matthews_correlation did not improve from 0.82586
# Epoch 47/50
# 2324/2324 [==============================] - 1s 498us/step - loss: 0.1011 - matthews_correlation: 0.6926 - val_loss: 0.0950 - val_matthews_correlation: 0.7972
#
# Epoch 00047: val_matthews_correlation did not improve from 0.82586
# Epoch 48/50
# 2324/2324 [==============================] - 1s 493us/step - loss: 0.0947 - matthews_correlation: 0.6490 - val_loss: 0.0993 - val_matthews_correlation: 0.7407
#
# Epoch 00048: val_matthews_correlation did not improve from 0.82586
# Epoch 49/50
# 2324/2324 [==============================] - 1s 492us/step - loss: 0.0791 - matthews_correlation: 0.7341 - val_loss: 0.0925 - val_matthews_correlation: 0.7506
#
# Epoch 00049: val_matthews_correlation did not improve from 0.82586
# Epoch 50/50
# 2324/2324 [==============================] - 1s 490us/step - loss: 0.0765 - matthews_correlation: 0.7693 - val_loss: 0.1023 - val_matthews_correlation: 0.7239
#
# Epoch 00050: val_matthews_correlation did not improve from 0.82586
# Beginning fold 10
# Train on 2324 samples, validate on 580 samples
# Epoch 1/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.2221 - matthews_correlation: 0.1669 - val_loss: 0.1701 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_9.h5
# Epoch 2/50
# 2324/2324 [==============================] - 1s 491us/step - loss: 0.1634 - matthews_correlation: 0.1789 - val_loss: 0.1427 - val_matthews_correlation: 0.2913
#
# Epoch 00002: val_matthews_correlation improved from 0.00000 to 0.29126, saving model to weights_9.h5
# Epoch 3/50
# 2324/2324 [==============================] - 1s 491us/step - loss: 0.1288 - matthews_correlation: 0.4554 - val_loss: 0.1143 - val_matthews_correlation: 0.6064
#
# Epoch 00003: val_matthews_correlation improved from 0.29126 to 0.60641, saving model to weights_9.h5
# Epoch 4/50
# 2324/2324 [==============================] - 1s 493us/step - loss: 0.1266 - matthews_correlation: 0.5379 - val_loss: 0.1634 - val_matthews_correlation: 0.5615
#
# Epoch 00004: val_matthews_correlation did not improve from 0.60641
# Epoch 5/50
# 2324/2324 [==============================] - 1s 490us/step - loss: 0.1191 - matthews_correlation: 0.5516 - val_loss: 0.1093 - val_matthews_correlation: 0.5249
#
# Epoch 00005: val_matthews_correlation did not improve from 0.60641
# Epoch 6/50
# 2324/2324 [==============================] - 1s 489us/step - loss: 0.1049 - matthews_correlation: 0.6289 - val_loss: 0.0959 - val_matthews_correlation: 0.5460
#
# Epoch 00006: val_matthews_correlation did not improve from 0.60641
# Epoch 7/50
# 2324/2324 [==============================] - 1s 494us/step - loss: 0.1021 - matthews_correlation: 0.6293 - val_loss: 0.1982 - val_matthews_correlation: 0.2760
#
# Epoch 00007: val_matthews_correlation did not improve from 0.60641
# Epoch 8/50
# 2324/2324 [==============================] - 1s 491us/step - loss: 0.1011 - matthews_correlation: 0.6612 - val_loss: 0.1451 - val_matthews_correlation: 0.1362
#
# Epoch 00008: val_matthews_correlation did not improve from 0.60641
# Epoch 9/50
# 2324/2324 [==============================] - 1s 493us/step - loss: 0.1048 - matthews_correlation: 0.6042 - val_loss: 0.2433 - val_matthews_correlation: 0.0955
#
# Epoch 00009: val_matthews_correlation did not improve from 0.60641
# Epoch 10/50
# 2324/2324 [==============================] - 1s 489us/step - loss: 0.1035 - matthews_correlation: 0.6612 - val_loss: 0.1031 - val_matthews_correlation: 0.5327
#
# Epoch 00010: val_matthews_correlation did not improve from 0.60641
# Epoch 11/50
# 2324/2324 [==============================] - 1s 485us/step - loss: 0.0967 - matthews_correlation: 0.6145 - val_loss: 0.2180 - val_matthews_correlation: 0.1944
#
# Epoch 00011: val_matthews_correlation did not improve from 0.60641
# Epoch 12/50
# 2324/2324 [==============================] - 1s 485us/step - loss: 0.0962 - matthews_correlation: 0.6504 - val_loss: 0.1189 - val_matthews_correlation: 0.4968
#
# Epoch 00012: val_matthews_correlation did not improve from 0.60641
# Epoch 13/50
# 2324/2324 [==============================] - 1s 492us/step - loss: 0.1010 - matthews_correlation: 0.6699 - val_loss: 0.1194 - val_matthews_correlation: 0.2507
#
# Epoch 00013: val_matthews_correlation did not improve from 0.60641
# Epoch 14/50
# 2324/2324 [==============================] - 1s 492us/step - loss: 0.1016 - matthews_correlation: 0.5980 - val_loss: 0.1006 - val_matthews_correlation: 0.6673
#
# Epoch 00014: val_matthews_correlation improved from 0.60641 to 0.66726, saving model to weights_9.h5
# Epoch 15/50
# 2324/2324 [==============================] - 1s 495us/step - loss: 0.0901 - matthews_correlation: 0.6733 - val_loss: 0.1565 - val_matthews_correlation: 0.6355
#
# Epoch 00015: val_matthews_correlation did not improve from 0.66726
# Epoch 16/50
# 2324/2324 [==============================] - 1s 492us/step - loss: 0.0885 - matthews_correlation: 0.6970 - val_loss: 0.0902 - val_matthews_correlation: 0.6722
#
# Epoch 00016: val_matthews_correlation improved from 0.66726 to 0.67216, saving model to weights_9.h5
# Epoch 17/50
# 2324/2324 [==============================] - 1s 494us/step - loss: 0.0889 - matthews_correlation: 0.6755 - val_loss: 0.1026 - val_matthews_correlation: 0.6883
#
# Epoch 00017: val_matthews_correlation improved from 0.67216 to 0.68826, saving model to weights_9.h5
# Epoch 18/50
# 2324/2324 [==============================] - 1s 498us/step - loss: 0.0904 - matthews_correlation: 0.6965 - val_loss: 0.0986 - val_matthews_correlation: 0.5594
#
# Epoch 00018: val_matthews_correlation did not improve from 0.68826
# Epoch 19/50
# 2324/2324 [==============================] - 1s 491us/step - loss: 0.0909 - matthews_correlation: 0.6949 - val_loss: 0.0883 - val_matthews_correlation: 0.6378
#
# Epoch 00019: val_matthews_correlation did not improve from 0.68826
# Epoch 20/50
# 2324/2324 [==============================] - 1s 494us/step - loss: 0.0873 - matthews_correlation: 0.6720 - val_loss: 0.1005 - val_matthews_correlation: 0.5913
#
# Epoch 00020: val_matthews_correlation did not improve from 0.68826
# Epoch 21/50
# 2324/2324 [==============================] - 1s 489us/step - loss: 0.0844 - matthews_correlation: 0.6968 - val_loss: 0.1028 - val_matthews_correlation: 0.6156
#
# Epoch 00021: val_matthews_correlation did not improve from 0.68826
# Epoch 22/50
# 2324/2324 [==============================] - 1s 489us/step - loss: 0.0907 - matthews_correlation: 0.6784 - val_loss: 0.1111 - val_matthews_correlation: 0.6341
#
# Epoch 00022: val_matthews_correlation did not improve from 0.68826
# Epoch 23/50
# 2324/2324 [==============================] - 1s 492us/step - loss: 0.0889 - matthews_correlation: 0.7206 - val_loss: 0.0999 - val_matthews_correlation: 0.4980
#
# Epoch 00023: val_matthews_correlation did not improve from 0.68826
# Epoch 24/50
# 2324/2324 [==============================] - 1s 492us/step - loss: 0.0922 - matthews_correlation: 0.6920 - val_loss: 0.1004 - val_matthews_correlation: 0.5825
#
# Epoch 00024: val_matthews_correlation did not improve from 0.68826
# Epoch 25/50
# 2324/2324 [==============================] - 1s 493us/step - loss: 0.0895 - matthews_correlation: 0.6789 - val_loss: 0.0944 - val_matthews_correlation: 0.6363
#
# Epoch 00025: val_matthews_correlation did not improve from 0.68826
# Epoch 26/50
# 2324/2324 [==============================] - 1s 492us/step - loss: 0.0862 - matthews_correlation: 0.6952 - val_loss: 0.0969 - val_matthews_correlation: 0.6908
#
# Epoch 00026: val_matthews_correlation improved from 0.68826 to 0.69080, saving model to weights_9.h5
# Epoch 27/50
# 2324/2324 [==============================] - 1s 493us/step - loss: 0.0819 - matthews_correlation: 0.7267 - val_loss: 0.1043 - val_matthews_correlation: 0.6298
#
# Epoch 00027: val_matthews_correlation did not improve from 0.69080
# Epoch 28/50
# 2324/2324 [==============================] - 1s 491us/step - loss: 0.0843 - matthews_correlation: 0.7146 - val_loss: 0.1086 - val_matthews_correlation: 0.6133
#
# Epoch 00028: val_matthews_correlation did not improve from 0.69080
# Epoch 29/50
# 2324/2324 [==============================] - 1s 495us/step - loss: 0.0905 - matthews_correlation: 0.6810 - val_loss: 0.0797 - val_matthews_correlation: 0.6958
#
# Epoch 00029: val_matthews_correlation improved from 0.69080 to 0.69577, saving model to weights_9.h5
# Epoch 30/50
# 2324/2324 [==============================] - 1s 495us/step - loss: 0.0887 - matthews_correlation: 0.7035 - val_loss: 0.0960 - val_matthews_correlation: 0.6540
#
# Epoch 00030: val_matthews_correlation did not improve from 0.69577
# Epoch 31/50
# 2324/2324 [==============================] - 1s 491us/step - loss: 0.0992 - matthews_correlation: 0.7020 - val_loss: 0.0969 - val_matthews_correlation: 0.6694
#
# Epoch 00031: val_matthews_correlation did not improve from 0.69577
# Epoch 32/50
# 2324/2324 [==============================] - 1s 495us/step - loss: 0.0896 - matthews_correlation: 0.7324 - val_loss: 0.1229 - val_matthews_correlation: 0.5442
#
# Epoch 00032: val_matthews_correlation did not improve from 0.69577
# Epoch 33/50
# 2324/2324 [==============================] - 1s 493us/step - loss: 0.0846 - matthews_correlation: 0.7290 - val_loss: 0.1002 - val_matthews_correlation: 0.6969
#
# Epoch 00033: val_matthews_correlation improved from 0.69577 to 0.69694, saving model to weights_9.h5
# Epoch 34/50
# 2324/2324 [==============================] - 1s 491us/step - loss: 0.0926 - matthews_correlation: 0.6544 - val_loss: 0.1045 - val_matthews_correlation: 0.5525
#
# Epoch 00034: val_matthews_correlation did not improve from 0.69694
# Epoch 35/50
# 2324/2324 [==============================] - 1s 492us/step - loss: 0.0811 - matthews_correlation: 0.7093 - val_loss: 0.1085 - val_matthews_correlation: 0.6297
#
# Epoch 00035: val_matthews_correlation did not improve from 0.69694
# Epoch 36/50
# 2324/2324 [==============================] - 1s 493us/step - loss: 0.0806 - matthews_correlation: 0.7011 - val_loss: 0.1092 - val_matthews_correlation: 0.5570
#
# Epoch 00036: val_matthews_correlation did not improve from 0.69694
# Epoch 37/50
# 2324/2324 [==============================] - 1s 501us/step - loss: 0.0818 - matthews_correlation: 0.7134 - val_loss: 0.0965 - val_matthews_correlation: 0.6529
#
# Epoch 00037: val_matthews_correlation did not improve from 0.69694
# Epoch 38/50
# 2324/2324 [==============================] - 1s 489us/step - loss: 0.0812 - matthews_correlation: 0.7096 - val_loss: 0.1042 - val_matthews_correlation: 0.6033
#
# Epoch 00038: val_matthews_correlation did not improve from 0.69694
# Epoch 39/50
# 2324/2324 [==============================] - 1s 492us/step - loss: 0.0807 - matthews_correlation: 0.7092 - val_loss: 0.1075 - val_matthews_correlation: 0.6039
#
# Epoch 00039: val_matthews_correlation did not improve from 0.69694
# Epoch 40/50
# 2324/2324 [==============================] - 1s 489us/step - loss: 0.0770 - matthews_correlation: 0.7539 - val_loss: 0.1018 - val_matthews_correlation: 0.6244
#
# Epoch 00040: val_matthews_correlation did not improve from 0.69694
# Epoch 41/50
# 2324/2324 [==============================] - 1s 490us/step - loss: 0.0754 - matthews_correlation: 0.7287 - val_loss: 0.1025 - val_matthews_correlation: 0.6357
#
# Epoch 00041: val_matthews_correlation did not improve from 0.69694
# Epoch 42/50
# 2324/2324 [==============================] - 1s 491us/step - loss: 0.0718 - matthews_correlation: 0.7645 - val_loss: 0.0954 - val_matthews_correlation: 0.6203
#
# Epoch 00042: val_matthews_correlation did not improve from 0.69694
# Epoch 43/50
# 2324/2324 [==============================] - 1s 494us/step - loss: 0.0762 - matthews_correlation: 0.7225 - val_loss: 0.1076 - val_matthews_correlation: 0.5845
#
# Epoch 00043: val_matthews_correlation did not improve from 0.69694
# Epoch 44/50
# 2324/2324 [==============================] - 1s 495us/step - loss: 0.0801 - matthews_correlation: 0.7524 - val_loss: 0.0824 - val_matthews_correlation: 0.5845
#
# Epoch 00044: val_matthews_correlation did not improve from 0.69694
# Epoch 45/50
# 2324/2324 [==============================] - 1s 496us/step - loss: 0.0822 - matthews_correlation: 0.6936 - val_loss: 0.1348 - val_matthews_correlation: 0.4410
#
# Epoch 00045: val_matthews_correlation did not improve from 0.69694
# Epoch 46/50
# 2324/2324 [==============================] - 1s 489us/step - loss: 0.0782 - matthews_correlation: 0.7164 - val_loss: 0.1433 - val_matthews_correlation: 0.6192
#
# Epoch 00046: val_matthews_correlation did not improve from 0.69694
# Epoch 47/50
# 2324/2324 [==============================] - 1s 492us/step - loss: 0.0829 - matthews_correlation: 0.7219 - val_loss: 0.0932 - val_matthews_correlation: 0.6084
#
# Epoch 00047: val_matthews_correlation did not improve from 0.69694
# Epoch 48/50
# 2324/2324 [==============================] - 1s 486us/step - loss: 0.0766 - matthews_correlation: 0.7582 - val_loss: 0.0988 - val_matthews_correlation: 0.7215
#
# Epoch 00048: val_matthews_correlation improved from 0.69694 to 0.72154, saving model to weights_9.h5
# Epoch 49/50
# 2324/2324 [==============================] - 1s 492us/step - loss: 0.0747 - matthews_correlation: 0.7559 - val_loss: 0.1302 - val_matthews_correlation: 0.5710
#
# Epoch 00049: val_matthews_correlation did not improve from 0.72154
# Epoch 50/50
# 2324/2324 [==============================] - 1s 495us/step - loss: 0.0782 - matthews_correlation: 0.7347 - val_loss: 0.1031 - val_matthews_correlation: 0.6787
#
# Epoch 00050: val_matthews_correlation did not improve from 0.72154
# ((5808,), (5808,))

# %%
import tensorflow as tf

def threshold_search(y_true, y_proba):
    best_threshold = 0
    best_score = 0
    for threshold in tqdm([i * 0.01 for i in range(100)]):
        score = K.eval(matthews_correlation(y_true.astype(np.float64), (y_proba > threshold).astype(np.float64)))
        if score > best_score:
            best_threshold = threshold
            best_score = score
    search_result = {'threshold': best_threshold, 'matthews_correlation': best_score}
    return search_result

# %%
best_threshold = threshold_search(y_val, preds_val)['threshold']
# Out:
# 100%|██████████| 100/100 [00:19<00:00,  3.16it/s]

# %%
best_threshold
# Out:
# 0.5

# %%
meta_test = pd.read_csv('../input/metadata_test.csv')

# %%
meta_test = meta_test.set_index(['signal_id'])
meta_test.head()
# Out:
#            id_measurement  phase
# signal_id
# 8712                 2904      0
# 8713                 2904      1
# 8714                 2904      2
# 8715                 2905      0
# 8716                 2905      1

# %%
first_sig = meta_test.index[0]
n_parts = 10
max_line = len(meta_test)
part_size = int(max_line / n_parts)
last_part = max_line % n_parts
print(first_sig, n_parts, max_line, part_size, last_part, n_parts * part_size + last_part)
# Here we create a list of lists with start index and end index for each of the 10 parts and one for the last partial part
start_end = [[x, x+part_size] for x in range(first_sig, max_line + first_sig, part_size)]
start_end = start_end[:-1] + [[start_end[-1][0], start_end[-1][0] + last_part]]
print(start_end)
X_test = []
# now, very like we did above with the train data, we convert the test data part by part
# transforming the 3 phases 800000 measurement in matrix (160,57)
for start, end in start_end:
    subset_test = pq.read_pandas('../input/test.parquet', columns=[str(i) for i in range(start, end)]).to_pandas()
    for i in tqdm(subset_test.columns):
        id_measurement, phase = meta_test.loc[int(i)]
        subset_test_col = subset_test[i]
        subset_trans = transform_ts(subset_test_col)
        X_test.append([i, id_measurement, phase, subset_trans])
# Out:
# 8712 10 20337 2033 7 20337
# [[8712, 10745], [10745, 12778], [12778, 14811], [14811, 16844], [16844, 18877], [18877, 20910], [20910, 22943], [22943, 24976], [24976, 27009], [27009, 29042], [29042, 29049]]
# 100%|██████████| 2033/2033 [02:52<00:00, 11.65it/s]
# 100%|██████████| 2033/2033 [02:54<00:00, 11.61it/s]
# 100%|██████████| 2033/2033 [02:57<00:00, 11.26it/s]
# 100%|██████████| 2033/2033 [03:01<00:00, 11.47it/s]
# 100%|██████████| 2033/2033 [02:58<00:00, 11.40it/s]
# 100%|██████████| 2033/2033 [03:00<00:00, 11.27it/s]
# 100%|██████████| 2033/2033 [03:00<00:00, 11.66it/s]
# 100%|██████████| 2033/2033 [02:58<00:00, 11.38it/s]
# 100%|██████████| 2033/2033 [02:58<00:00, 11.33it/s]
# 100%|██████████| 2033/2033 [03:00<00:00, 11.43it/s]
# 100%|██████████| 7/7 [00:00<00:00,  9.48it/s]

# %%
X_test_input = np.asarray([np.concatenate([X_test[i][3],X_test[i+1][3], X_test[i+2][3]], axis=1) for i in range(0,len(X_test), 3)])
np.save("X_test.npy",X_test_input)
X_test_input.shape
# Out:
# (6779, 160, 57)

# %%
submission = pd.read_csv('../input/sample_submission.csv')
print(len(submission))
submission.head()
# Out:
# 20337
#    signal_id  target
# 0       8712       0
# 1       8713       0
# 2       8714       0
# 3       8715       0
# 4       8716       0

# %%
preds_test = []
for i in range(N_SPLITS):
    model.load_weights('weights_{}.h5'.format(i))
    pred = model.predict(X_test_input, batch_size=300, verbose=1)
    pred_3 = []
    for pred_scalar in pred:
        for i in range(3):
            pred_3.append(pred_scalar)
    preds_test.append(pred_3)
# Out:
# 6779/6779 [==============================] - 1s 138us/step
# 6779/6779 [==============================] - 1s 134us/step
# 6779/6779 [==============================] - 1s 134us/step
# 6779/6779 [==============================] - 1s 134us/step
# 6779/6779 [==============================] - 1s 134us/step

# %%
preds_test = (np.squeeze(np.mean(preds_test, axis=0)) > best_threshold).astype(np.int)
preds_test.shape
# Out:
# (20337,)

# %%
submission['target'] = preds_test
submission.to_csv('submission.csv', index=False)
submission.head()
# Out:
#    signal_id  target
# 0       8712       0
# 1       8713       0
# 2       8714       0
# 3       8715       0
# 4       8716       0
