# %% [markdown]
# Inspired from Bruno Aquino's Kernel:
# https://www.kaggle.com/braquino/5-fold-lstm-attention-fully-commented-0-694

# %%
import pandas as pd
import pyarrow.parquet as pq # Used to read the data
import os 
import numpy as np
from keras.layers import * # Keras is the most friendly Neural Network library, this Kernel use a lot of layers classes
from keras.models import Model
from tqdm import tqdm # Processing time measurement
from sklearn.model_selection import train_test_split 
from keras import backend as K # The backend give us access to tensorflow operations and allow us to create the Attention class
from keras import optimizers # Allow us to access the Adam class to modify some parameters
from sklearn.model_selection import GridSearchCV, StratifiedKFold # Used to use Kfold to train our model
from keras.callbacks import * # This object helps the model to train in a smarter way, avoiding overfitting
# Out:
# Using TensorFlow backend.

# %%
# select how many folds will be created
N_SPLITS = 5
# it is just a constant with the measurements data size
sample_size = 800000

# %%
# It is the official metric used in this competition
# below is the declaration of a function used inside the keras model, calculation with K (keras backend / thensorflow)
def matthews_correlation(y_true, y_pred):
    '''Calculates the Matthews correlation coefficient measure for quality
    of binary classification problems.
    '''
    y_pred_pos = K.round(K.clip(y_pred, 0, 1))
    y_pred_neg = 1 - y_pred_pos

    y_pos = K.round(K.clip(y_true, 0, 1))
    y_neg = 1 - y_pos

    tp = K.sum(y_pos * y_pred_pos)
    tn = K.sum(y_neg * y_pred_neg)

    fp = K.sum(y_neg * y_pred_pos)
    fn = K.sum(y_pos * y_pred_neg)

    numerator = (tp * tn - fp * fn)
    denominator = K.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn))

    return numerator / (denominator + K.epsilon())

# %%
# https://www.kaggle.com/suicaokhoailang/lstm-attention-baseline-0-652-lb

class Attention(Layer):
    def __init__(self, step_dim,
                 W_regularizer=None, b_regularizer=None,
                 W_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
        self.supports_masking = True
        self.init = initializers.get('glorot_uniform')

        self.W_regularizer = regularizers.get(W_regularizer)
        self.b_regularizer = regularizers.get(b_regularizer)

        self.W_constraint = constraints.get(W_constraint)
        self.b_constraint = constraints.get(b_constraint)

        self.bias = bias
        self.step_dim = step_dim
        self.features_dim = 0
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3

        self.W = self.add_weight((input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        self.features_dim = input_shape[-1]

        if self.bias:
            self.b = self.add_weight((input_shape[1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None

        self.built = True

    def compute_mask(self, input, input_mask=None):
        return None

    def call(self, x, mask=None):
        features_dim = self.features_dim
        step_dim = self.step_dim

        eij = K.reshape(K.dot(K.reshape(x, (-1, features_dim)),
                        K.reshape(self.W, (features_dim, 1))), (-1, step_dim))

        if self.bias:
            eij += self.b

        eij = K.tanh(eij)

        a = K.exp(eij)

        if mask is not None:
            a *= K.cast(mask, K.floatx())

        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())

        a = K.expand_dims(a)
        weighted_input = x * a
        return K.sum(weighted_input, axis=1)

    def compute_output_shape(self, input_shape):
        return input_shape[0],  self.features_dim

# %%
# just load train data
df_train = pd.read_csv('../input/metadata_train.csv')
# set index, it makes the data access much faster
df_train = df_train.set_index(['id_measurement', 'phase'])
df_train.head()
# Out:
#                       signal_id  target
# id_measurement phase
# 0              0              0       0
#                1              1       0
#                2              2       0
# 1              0              3       1
#                1              4       1

# %%
# in other notebook I have extracted the min and max values from the train data, the measurements
max_num = 127
min_num = -128

# %%
# This function standardize the data from (-128 to 127) to (-1 to 1)
# Theoretically it helps in the NN Model training, but I didn't tested without it
def min_max_transf(ts, min_data, max_data, range_needed=(-1,1)):
    if min_data < 0:
        ts_std = (ts + abs(min_data)) / (max_data + abs(min_data))
    else:
        ts_std = (ts - min_data) / (max_data - min_data)
    if range_needed[0] < 0:    
        return ts_std * (range_needed[1] + abs(range_needed[0])) + range_needed[0]
    else:
        return ts_std * (range_needed[1] - range_needed[0]) + range_needed[0]

# %%
def transform_ts(ts, n_dim=160, min_max=(-1,1)):
    # convert data into -1 to 1
    ts_std = min_max_transf(ts, min_data=min_num, max_data=max_num)
    # bucket or chunk size, 5000 in this case (800000 / 160)
    bucket_size = int(sample_size / n_dim)
    # new_ts will be the container of the new data
    new_ts = []
    # this for iteract any chunk/bucket until reach the whole sample_size (800000)
    for i in range(0, sample_size, bucket_size):
        # cut each bucket to ts_range
        ts_range = ts_std[i:i + bucket_size]
        # calculate each feature
        mean = ts_range.mean()
        std = ts_range.std() # standard deviation
        std_top = mean + std # I have to test it more, but is is like a band
        std_bot = mean - std
        # I think that the percentiles are very important, it is like a distribuiton analysis from eath chunk
        percentil_calc = np.percentile(ts_range, [0, 1, 25, 50, 75, 99, 100]) 
        max_range = percentil_calc[-1] - percentil_calc[0] # this is the amplitude of the chunk
        relative_percentile = percentil_calc - mean # maybe it could heap to understand the asymmetry
        new_ts.append(np.concatenate([np.asarray([mean, std, std_top, std_bot, max_range]),percentil_calc, relative_percentile]))
    return np.asarray(new_ts)

# %%
# this function take a piece of data and convert using transform_ts(), but it does to each of the 3 phases
# if we would try to do in one time, could exceed the RAM Memmory
def prep_data(start, end):

    praq_train = pq.read_pandas('../input/train.parquet', columns=[str(i) for i in range(start, end)]).to_pandas()
    X = []
    y = []
   
    for id_measurement in tqdm(df_train.index.levels[0].unique()[int(start/3):int(end/3)]):
        X_signal = []
        # for each phase of the signal
        for phase in [0,1,2]:
            # extract from df_train both signal_id and target to compose the new data sets
            signal_id, target = df_train.loc[id_measurement].loc[phase]
            # but just append the target one time, to not triplicate it
            if phase == 0:
                y.append(target)
            # extract and transform data into sets of features
            X_signal.append(transform_ts(praq_train[str(signal_id)]))
        # concatenate all the 3 phases in one matrix
        X_signal = np.concatenate(X_signal, axis=1)
        # add the data to X
        X.append(X_signal)
    X = np.asarray(X)
    y = np.asarray(y)
    return X, y

# %%
# this code is very simple, divide the total size of the df_train into two sets and process it
X = []
y = []
def load_all():
    total_size = len(df_train)
    for ini, end in [(0, int(total_size/2)), (int(total_size/2), total_size)]:
        X_temp, y_temp = prep_data(ini, end)
        X.append(X_temp)
        y.append(y_temp)
load_all()
X = np.concatenate(X)
y = np.concatenate(y)
# Out:
# 100%|██████████| 1452/1452 [07:18<00:00,  3.16it/s]
# 100%|██████████| 1452/1452 [07:20<00:00,  3.33it/s]

# %%
print(X.shape, y.shape)
# save data into file, a numpy specific format
np.save("X.npy",X)
np.save("y.npy",y)
# Out:
# (2904, 160, 57) (2904,)

# %%
# This is NN LSTM Model creation
def model_lstm(input_shape):
    # The shape was explained above, must have this order
    inp = Input(shape=(input_shape[1], input_shape[2],))
    
    x = Bidirectional(CuDNNLSTM(128, return_sequences=True))(inp)
    x = Bidirectional(CuDNNLSTM(64, return_sequences=True))(x)
    x = Attention(input_shape[1])(x)
    x = Dense(64, activation="relu")(x)
    x = Dropout(0.25) (x)
    x = Dense(1, activation="sigmoid")(x)
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[matthews_correlation])
    
    return model

# %%
# Here is where the training happens

# First, create a set of indexes of the 5 folds
splits = list(StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=2019).split(X, y))
preds_val = []
y_val = []
# Then, iteract with each fold
# If you dont know, enumerate(['a', 'b', 'c']) returns [(0, 'a'), (1, 'b'), (2, 'c')]
for idx, (train_idx, val_idx) in enumerate(splits):
    K.clear_session() # I dont know what it do, but I imagine that it "clear session" :)
    print("Beginning fold {}".format(idx+1))
    train_X, train_y, val_X, val_y = X[train_idx], y[train_idx], X[val_idx], y[val_idx]
    model = model_lstm(train_X.shape)
    es = EarlyStopping(monitor='val_matthews_correlation', verbose=2, patience=25)
    ckpt = ModelCheckpoint('weights_{}.h5'.format(idx), save_best_only=True, save_weights_only=True, verbose=1, monitor='val_matthews_correlation', mode='max')
    # Train, train, train
    model.fit(train_X, train_y, batch_size=128, epochs=50, validation_data=[val_X, val_y], callbacks=[ckpt,es])
    # loads the best weights saved by the checkpoint
    model.load_weights('weights_{}.h5'.format(idx))
    # Add the predictions of the validation to the list preds_val
    preds_val.append(model.predict(val_X, batch_size=512))
    # and the val true y
    y_val.append(val_y)

# concatenates all and prints the shape    
preds_val = np.concatenate(preds_val)[...,0]
y_val = np.concatenate(y_val)
preds_val.shape, y_val.shape
# Out:
# Beginning fold 1
# Train on 2322 samples, validate on 582 samples
# Epoch 1/50
# 2322/2322 [==============================] - 9s 4ms/step - loss: 0.3687 - matthews_correlation: -0.0046 - val_loss: 0.2286 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_0.h5
# Epoch 2/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.2368 - matthews_correlation: 0.0000e+00 - val_loss: 0.2194 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.2226 - matthews_correlation: -0.0012 - val_loss: 0.2144 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00003: val_matthews_correlation did not improve from 0.00000
# Epoch 4/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.2145 - matthews_correlation: -0.0024 - val_loss: 0.2082 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00004: val_matthews_correlation did not improve from 0.00000
# Epoch 5/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.2028 - matthews_correlation: 0.1490 - val_loss: 0.1733 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00005: val_matthews_correlation did not improve from 0.00000
# Epoch 6/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.1823 - matthews_correlation: 0.1542 - val_loss: 0.1479 - val_matthews_correlation: 0.3209
#
# Epoch 00006: val_matthews_correlation improved from 0.00000 to 0.32087, saving model to weights_0.h5
# Epoch 7/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.1694 - matthews_correlation: 0.3829 - val_loss: 0.1536 - val_matthews_correlation: 0.1759
#
# Epoch 00007: val_matthews_correlation did not improve from 0.32087
# Epoch 8/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.1441 - matthews_correlation: 0.3786 - val_loss: 0.1034 - val_matthews_correlation: 0.5662
#
# Epoch 00008: val_matthews_correlation improved from 0.32087 to 0.56618, saving model to weights_0.h5
# Epoch 9/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.1178 - matthews_correlation: 0.6108 - val_loss: 0.0833 - val_matthews_correlation: 0.7883
#
# Epoch 00009: val_matthews_correlation improved from 0.56618 to 0.78828, saving model to weights_0.h5
# Epoch 10/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.1202 - matthews_correlation: 0.6216 - val_loss: 0.0992 - val_matthews_correlation: 0.7282
#
# Epoch 00010: val_matthews_correlation did not improve from 0.78828
# Epoch 11/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.1160 - matthews_correlation: 0.6223 - val_loss: 0.0830 - val_matthews_correlation: 0.7237
#
# Epoch 00011: val_matthews_correlation did not improve from 0.78828
# Epoch 12/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.1052 - matthews_correlation: 0.7053 - val_loss: 0.0881 - val_matthews_correlation: 0.7574
#
# Epoch 00012: val_matthews_correlation did not improve from 0.78828
# Epoch 13/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.1026 - matthews_correlation: 0.6593 - val_loss: 0.0891 - val_matthews_correlation: 0.6793
#
# Epoch 00013: val_matthews_correlation did not improve from 0.78828
# Epoch 14/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.1103 - matthews_correlation: 0.6397 - val_loss: 0.0804 - val_matthews_correlation: 0.6904
#
# Epoch 00014: val_matthews_correlation did not improve from 0.78828
# Epoch 15/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.1046 - matthews_correlation: 0.6809 - val_loss: 0.0755 - val_matthews_correlation: 0.7660
#
# Epoch 00015: val_matthews_correlation did not improve from 0.78828
# Epoch 16/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.1033 - matthews_correlation: 0.6581 - val_loss: 0.0867 - val_matthews_correlation: 0.7613
#
# Epoch 00016: val_matthews_correlation did not improve from 0.78828
# Epoch 17/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.1116 - matthews_correlation: 0.6517 - val_loss: 0.0839 - val_matthews_correlation: 0.8171
#
# Epoch 00017: val_matthews_correlation improved from 0.78828 to 0.81711, saving model to weights_0.h5
# Epoch 18/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.1027 - matthews_correlation: 0.6203 - val_loss: 0.0866 - val_matthews_correlation: 0.7194
#
# Epoch 00018: val_matthews_correlation did not improve from 0.81711
# Epoch 19/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.1072 - matthews_correlation: 0.6468 - val_loss: 0.0791 - val_matthews_correlation: 0.6904
#
# Epoch 00019: val_matthews_correlation did not improve from 0.81711
# Epoch 20/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.1048 - matthews_correlation: 0.6644 - val_loss: 0.1044 - val_matthews_correlation: 0.7294
#
# Epoch 00020: val_matthews_correlation did not improve from 0.81711
# Epoch 21/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.1036 - matthews_correlation: 0.6547 - val_loss: 0.0829 - val_matthews_correlation: 0.7788
#
# Epoch 00021: val_matthews_correlation did not improve from 0.81711
# Epoch 22/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.1195 - matthews_correlation: 0.5318 - val_loss: 0.1138 - val_matthews_correlation: 0.7151
#
# Epoch 00022: val_matthews_correlation did not improve from 0.81711
# Epoch 23/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.1108 - matthews_correlation: 0.6054 - val_loss: 0.0879 - val_matthews_correlation: 0.8050
#
# Epoch 00023: val_matthews_correlation did not improve from 0.81711
# Epoch 24/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.0943 - matthews_correlation: 0.6849 - val_loss: 0.0750 - val_matthews_correlation: 0.7846
#
# Epoch 00024: val_matthews_correlation did not improve from 0.81711
# Epoch 25/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.0942 - matthews_correlation: 0.6855 - val_loss: 0.0768 - val_matthews_correlation: 0.7379
#
# Epoch 00025: val_matthews_correlation did not improve from 0.81711
# Epoch 26/50
# 2322/2322 [==============================] - 3s 1ms/step - loss: 0.0954 - matthews_correlation: 0.6899 - val_loss: 0.1208 - val_matthews_correlation: 0.6922
#
# Epoch 00026: val_matthews_correlation did not improve from 0.81711
# Epoch 00026: early stopping
# Beginning fold 2
# Train on 2323 samples, validate on 581 samples
# Epoch 1/50
# 2323/2323 [==============================] - 4s 2ms/step - loss: 0.3693 - matthews_correlation: 0.0020 - val_loss: 0.2358 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_1.h5
# Epoch 2/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.2363 - matthews_correlation: 0.0000e+00 - val_loss: 0.2282 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.2231 - matthews_correlation: 0.0000e+00 - val_loss: 0.2153 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00003: val_matthews_correlation did not improve from 0.00000
# Epoch 4/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.2055 - matthews_correlation: 0.0374 - val_loss: 0.2108 - val_matthews_correlation: 0.0595
#
# Epoch 00004: val_matthews_correlation improved from 0.00000 to 0.05947, saving model to weights_1.h5
# Epoch 5/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1874 - matthews_correlation: 0.2053 - val_loss: 0.1999 - val_matthews_correlation: -0.0215
#
# Epoch 00005: val_matthews_correlation did not improve from 0.05947
# Epoch 6/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1922 - matthews_correlation: 0.2540 - val_loss: 0.1912 - val_matthews_correlation: 0.1045
#
# Epoch 00006: val_matthews_correlation improved from 0.05947 to 0.10453, saving model to weights_1.h5
# Epoch 7/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1702 - matthews_correlation: 0.2524 - val_loss: 0.1711 - val_matthews_correlation: 0.0510
#
# Epoch 00007: val_matthews_correlation did not improve from 0.10453
# Epoch 8/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1652 - matthews_correlation: 0.2475 - val_loss: 0.1678 - val_matthews_correlation: 0.1045
#
# Epoch 00008: val_matthews_correlation did not improve from 0.10453
# Epoch 9/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1523 - matthews_correlation: 0.3899 - val_loss: 0.1340 - val_matthews_correlation: 0.1932
#
# Epoch 00009: val_matthews_correlation improved from 0.10453 to 0.19321, saving model to weights_1.h5
# Epoch 10/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1196 - matthews_correlation: 0.4735 - val_loss: 0.1260 - val_matthews_correlation: 0.6197
#
# Epoch 00010: val_matthews_correlation improved from 0.19321 to 0.61971, saving model to weights_1.h5
# Epoch 11/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1111 - matthews_correlation: 0.6875 - val_loss: 0.1654 - val_matthews_correlation: 0.5195
#
# Epoch 00011: val_matthews_correlation did not improve from 0.61971
# Epoch 12/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1289 - matthews_correlation: 0.5383 - val_loss: 0.1248 - val_matthews_correlation: 0.6553
#
# Epoch 00012: val_matthews_correlation improved from 0.61971 to 0.65533, saving model to weights_1.h5
# Epoch 13/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1062 - matthews_correlation: 0.6149 - val_loss: 0.1161 - val_matthews_correlation: 0.6396
#
# Epoch 00013: val_matthews_correlation did not improve from 0.65533
# Epoch 14/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1075 - matthews_correlation: 0.6524 - val_loss: 0.1113 - val_matthews_correlation: 0.6163
#
# Epoch 00014: val_matthews_correlation did not improve from 0.65533
# Epoch 15/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1106 - matthews_correlation: 0.6057 - val_loss: 0.1112 - val_matthews_correlation: 0.6281
#
# Epoch 00015: val_matthews_correlation did not improve from 0.65533
# Epoch 16/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1044 - matthews_correlation: 0.6646 - val_loss: 0.1170 - val_matthews_correlation: 0.6163
#
# Epoch 00016: val_matthews_correlation did not improve from 0.65533
# Epoch 17/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1060 - matthews_correlation: 0.6320 - val_loss: 0.1107 - val_matthews_correlation: 0.6392
#
# Epoch 00017: val_matthews_correlation did not improve from 0.65533
# Epoch 18/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1054 - matthews_correlation: 0.6578 - val_loss: 0.1146 - val_matthews_correlation: 0.6805
#
# Epoch 00018: val_matthews_correlation improved from 0.65533 to 0.68046, saving model to weights_1.h5
# Epoch 19/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0996 - matthews_correlation: 0.7031 - val_loss: 0.1134 - val_matthews_correlation: 0.6554
#
# Epoch 00019: val_matthews_correlation did not improve from 0.68046
# Epoch 20/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0995 - matthews_correlation: 0.6858 - val_loss: 0.1138 - val_matthews_correlation: 0.6115
#
# Epoch 00020: val_matthews_correlation did not improve from 0.68046
# Epoch 21/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0973 - matthews_correlation: 0.6993 - val_loss: 0.1556 - val_matthews_correlation: 0.5674
#
# Epoch 00021: val_matthews_correlation did not improve from 0.68046
# Epoch 22/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1199 - matthews_correlation: 0.5763 - val_loss: 0.1082 - val_matthews_correlation: 0.6396
#
# Epoch 00022: val_matthews_correlation did not improve from 0.68046
# Epoch 23/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1017 - matthews_correlation: 0.6780 - val_loss: 0.1104 - val_matthews_correlation: 0.6197
#
# Epoch 00023: val_matthews_correlation did not improve from 0.68046
# Epoch 24/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1001 - matthews_correlation: 0.7036 - val_loss: 0.1099 - val_matthews_correlation: 0.6345
#
# Epoch 00024: val_matthews_correlation did not improve from 0.68046
# Epoch 25/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0970 - matthews_correlation: 0.7110 - val_loss: 0.1112 - val_matthews_correlation: 0.6554
#
# Epoch 00025: val_matthews_correlation did not improve from 0.68046
# Epoch 26/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0968 - matthews_correlation: 0.6991 - val_loss: 0.1099 - val_matthews_correlation: 0.6216
#
# Epoch 00026: val_matthews_correlation did not improve from 0.68046
# Epoch 27/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0967 - matthews_correlation: 0.6819 - val_loss: 0.1123 - val_matthews_correlation: 0.6489
#
# Epoch 00027: val_matthews_correlation did not improve from 0.68046
# Epoch 28/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0919 - matthews_correlation: 0.7077 - val_loss: 0.1299 - val_matthews_correlation: 0.5799
#
# Epoch 00028: val_matthews_correlation did not improve from 0.68046
# Epoch 29/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1096 - matthews_correlation: 0.6048 - val_loss: 0.1090 - val_matthews_correlation: 0.6554
#
# Epoch 00029: val_matthews_correlation did not improve from 0.68046
# Epoch 30/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0989 - matthews_correlation: 0.6876 - val_loss: 0.1124 - val_matthews_correlation: 0.6180
#
# Epoch 00030: val_matthews_correlation did not improve from 0.68046
# Epoch 00030: early stopping
# Beginning fold 3
# Train on 2323 samples, validate on 581 samples
# Epoch 1/50
# 2323/2323 [==============================] - 4s 2ms/step - loss: 0.3630 - matthews_correlation: 0.0039 - val_loss: 0.2335 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_2.h5
# Epoch 2/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.2342 - matthews_correlation: 0.0000e+00 - val_loss: 0.2208 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.2237 - matthews_correlation: 0.0000e+00 - val_loss: 0.2028 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00003: val_matthews_correlation did not improve from 0.00000
# Epoch 4/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.2054 - matthews_correlation: 0.0220 - val_loss: 0.2129 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00004: val_matthews_correlation did not improve from 0.00000
# Epoch 5/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.2162 - matthews_correlation: 0.0494 - val_loss: 0.1993 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00005: val_matthews_correlation did not improve from 0.00000
# Epoch 6/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1993 - matthews_correlation: 0.0456 - val_loss: 0.1894 - val_matthews_correlation: 0.3119
#
# Epoch 00006: val_matthews_correlation improved from 0.00000 to 0.31186, saving model to weights_2.h5
# Epoch 7/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1840 - matthews_correlation: 0.1262 - val_loss: 0.1747 - val_matthews_correlation: 0.3119
#
# Epoch 00007: val_matthews_correlation did not improve from 0.31186
# Epoch 8/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1553 - matthews_correlation: 0.4139 - val_loss: 0.1481 - val_matthews_correlation: 0.3800
#
# Epoch 00008: val_matthews_correlation improved from 0.31186 to 0.37995, saving model to weights_2.h5
# Epoch 9/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1265 - matthews_correlation: 0.5214 - val_loss: 0.1345 - val_matthews_correlation: 0.3122
#
# Epoch 00009: val_matthews_correlation did not improve from 0.37995
# Epoch 10/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1519 - matthews_correlation: 0.4792 - val_loss: 0.1282 - val_matthews_correlation: 0.4073
#
# Epoch 00010: val_matthews_correlation improved from 0.37995 to 0.40727, saving model to weights_2.h5
# Epoch 11/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1141 - matthews_correlation: 0.5164 - val_loss: 0.1241 - val_matthews_correlation: 0.3479
#
# Epoch 00011: val_matthews_correlation did not improve from 0.40727
# Epoch 12/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1119 - matthews_correlation: 0.6256 - val_loss: 0.1254 - val_matthews_correlation: 0.5414
#
# Epoch 00012: val_matthews_correlation improved from 0.40727 to 0.54142, saving model to weights_2.h5
# Epoch 13/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1045 - matthews_correlation: 0.6405 - val_loss: 0.1354 - val_matthews_correlation: 0.4511
#
# Epoch 00013: val_matthews_correlation did not improve from 0.54142
# Epoch 14/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1104 - matthews_correlation: 0.6079 - val_loss: 0.1310 - val_matthews_correlation: 0.5675
#
# Epoch 00014: val_matthews_correlation improved from 0.54142 to 0.56746, saving model to weights_2.h5
# Epoch 15/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1163 - matthews_correlation: 0.5945 - val_loss: 0.1379 - val_matthews_correlation: 0.4329
#
# Epoch 00015: val_matthews_correlation did not improve from 0.56746
# Epoch 16/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1002 - matthews_correlation: 0.6049 - val_loss: 0.1339 - val_matthews_correlation: 0.5109
#
# Epoch 00016: val_matthews_correlation did not improve from 0.56746
# Epoch 17/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1027 - matthews_correlation: 0.6319 - val_loss: 0.1326 - val_matthews_correlation: 0.5471
#
# Epoch 00017: val_matthews_correlation did not improve from 0.56746
# Epoch 18/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1089 - matthews_correlation: 0.6325 - val_loss: 0.1499 - val_matthews_correlation: 0.3231
#
# Epoch 00018: val_matthews_correlation did not improve from 0.56746
# Epoch 19/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1010 - matthews_correlation: 0.6412 - val_loss: 0.1198 - val_matthews_correlation: 0.3379
#
# Epoch 00019: val_matthews_correlation did not improve from 0.56746
# Epoch 20/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0951 - matthews_correlation: 0.6760 - val_loss: 0.1276 - val_matthews_correlation: 0.4218
#
# Epoch 00020: val_matthews_correlation did not improve from 0.56746
# Epoch 21/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0910 - matthews_correlation: 0.6723 - val_loss: 0.1216 - val_matthews_correlation: 0.5985
#
# Epoch 00021: val_matthews_correlation improved from 0.56746 to 0.59853, saving model to weights_2.h5
# Epoch 22/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1054 - matthews_correlation: 0.5830 - val_loss: 0.1311 - val_matthews_correlation: 0.4919
#
# Epoch 00022: val_matthews_correlation did not improve from 0.59853
# Epoch 23/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.1101 - matthews_correlation: 0.5912 - val_loss: 0.1249 - val_matthews_correlation: 0.2267
#
# Epoch 00023: val_matthews_correlation did not improve from 0.59853
# Epoch 24/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0963 - matthews_correlation: 0.6321 - val_loss: 0.1179 - val_matthews_correlation: 0.6276
#
# Epoch 00024: val_matthews_correlation improved from 0.59853 to 0.62759, saving model to weights_2.h5
# Epoch 25/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0937 - matthews_correlation: 0.6964 - val_loss: 0.1261 - val_matthews_correlation: 0.4406
#
# Epoch 00025: val_matthews_correlation did not improve from 0.62759
# Epoch 26/50
# 2323/2323 [==============================] - 3s 1ms/step - loss: 0.0923 - matthews_correlation: 0.7366 - val_loss: 0.1165 - val_matthews_correlation: 0.5815
#
# Epoch 00026: val_matthews_correlation did not improve from 0.62759
# Epoch 00026: early stopping
# Beginning fold 4
# Train on 2324 samples, validate on 580 samples
# Epoch 1/50
# 2324/2324 [==============================] - 4s 2ms/step - loss: 0.3535 - matthews_correlation: -0.0040 - val_loss: 0.2486 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_3.h5
# Epoch 2/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.2386 - matthews_correlation: 0.0000e+00 - val_loss: 0.2223 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.2249 - matthews_correlation: 0.0000e+00 - val_loss: 0.2116 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00003: val_matthews_correlation did not improve from 0.00000
# Epoch 4/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.2124 - matthews_correlation: 0.0000e+00 - val_loss: 0.2075 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00004: val_matthews_correlation did not improve from 0.00000
# Epoch 5/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.2076 - matthews_correlation: 0.0000e+00 - val_loss: 0.1994 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00005: val_matthews_correlation did not improve from 0.00000
# Epoch 6/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1852 - matthews_correlation: 0.0678 - val_loss: 0.2092 - val_matthews_correlation: 0.1810
#
# Epoch 00006: val_matthews_correlation improved from 0.00000 to 0.18097, saving model to weights_3.h5
# Epoch 7/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1938 - matthews_correlation: 0.0253 - val_loss: 0.1605 - val_matthews_correlation: 0.1298
#
# Epoch 00007: val_matthews_correlation did not improve from 0.18097
# Epoch 8/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1460 - matthews_correlation: 0.2836 - val_loss: 0.1200 - val_matthews_correlation: 0.5966
#
# Epoch 00008: val_matthews_correlation improved from 0.18097 to 0.59656, saving model to weights_3.h5
# Epoch 9/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1202 - matthews_correlation: 0.5429 - val_loss: 0.1164 - val_matthews_correlation: 0.5295
#
# Epoch 00009: val_matthews_correlation did not improve from 0.59656
# Epoch 10/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1204 - matthews_correlation: 0.6192 - val_loss: 0.1346 - val_matthews_correlation: 0.5151
#
# Epoch 00010: val_matthews_correlation did not improve from 0.59656
# Epoch 11/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1123 - matthews_correlation: 0.6579 - val_loss: 0.1148 - val_matthews_correlation: 0.6217
#
# Epoch 00011: val_matthews_correlation improved from 0.59656 to 0.62169, saving model to weights_3.h5
# Epoch 12/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1290 - matthews_correlation: 0.3914 - val_loss: 0.1153 - val_matthews_correlation: 0.5408
#
# Epoch 00012: val_matthews_correlation did not improve from 0.62169
# Epoch 13/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1137 - matthews_correlation: 0.6168 - val_loss: 0.1190 - val_matthews_correlation: 0.4186
#
# Epoch 00013: val_matthews_correlation did not improve from 0.62169
# Epoch 14/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1084 - matthews_correlation: 0.6081 - val_loss: 0.1134 - val_matthews_correlation: 0.4576
#
# Epoch 00014: val_matthews_correlation did not improve from 0.62169
# Epoch 15/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0985 - matthews_correlation: 0.5880 - val_loss: 0.1081 - val_matthews_correlation: 0.5548
#
# Epoch 00015: val_matthews_correlation did not improve from 0.62169
# Epoch 16/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0977 - matthews_correlation: 0.6327 - val_loss: 0.1138 - val_matthews_correlation: 0.6016
#
# Epoch 00016: val_matthews_correlation did not improve from 0.62169
# Epoch 17/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0948 - matthews_correlation: 0.6190 - val_loss: 0.1124 - val_matthews_correlation: 0.4529
#
# Epoch 00017: val_matthews_correlation did not improve from 0.62169
# Epoch 18/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0945 - matthews_correlation: 0.6626 - val_loss: 0.1108 - val_matthews_correlation: 0.5466
#
# Epoch 00018: val_matthews_correlation did not improve from 0.62169
# Epoch 19/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0974 - matthews_correlation: 0.6365 - val_loss: 0.1034 - val_matthews_correlation: 0.6414
#
# Epoch 00019: val_matthews_correlation improved from 0.62169 to 0.64138, saving model to weights_3.h5
# Epoch 20/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0956 - matthews_correlation: 0.6128 - val_loss: 0.1069 - val_matthews_correlation: 0.6610
#
# Epoch 00020: val_matthews_correlation improved from 0.64138 to 0.66104, saving model to weights_3.h5
# Epoch 21/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0940 - matthews_correlation: 0.6796 - val_loss: 0.1182 - val_matthews_correlation: 0.4927
#
# Epoch 00021: val_matthews_correlation did not improve from 0.66104
# Epoch 22/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0946 - matthews_correlation: 0.6553 - val_loss: 0.1055 - val_matthews_correlation: 0.6455
#
# Epoch 00022: val_matthews_correlation did not improve from 0.66104
# Epoch 23/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0998 - matthews_correlation: 0.6574 - val_loss: 0.1066 - val_matthews_correlation: 0.5571
#
# Epoch 00023: val_matthews_correlation did not improve from 0.66104
# Epoch 24/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0953 - matthews_correlation: 0.6732 - val_loss: 0.1086 - val_matthews_correlation: 0.4850
#
# Epoch 00024: val_matthews_correlation did not improve from 0.66104
# Epoch 25/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0937 - matthews_correlation: 0.6719 - val_loss: 0.1345 - val_matthews_correlation: 0.4077
#
# Epoch 00025: val_matthews_correlation did not improve from 0.66104
# Epoch 26/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0980 - matthews_correlation: 0.5747 - val_loss: 0.1214 - val_matthews_correlation: 0.4575
#
# Epoch 00026: val_matthews_correlation did not improve from 0.66104
# Epoch 00026: early stopping
# Beginning fold 5
# Train on 2324 samples, validate on 580 samples
# Epoch 1/50
# 2324/2324 [==============================] - 4s 2ms/step - loss: 0.3988 - matthews_correlation: 0.0377 - val_loss: 0.2332 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_4.h5
# Epoch 2/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.2361 - matthews_correlation: 0.0000e+00 - val_loss: 0.2250 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.2377 - matthews_correlation: 0.0000e+00 - val_loss: 0.2182 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00003: val_matthews_correlation did not improve from 0.00000
# Epoch 4/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.2284 - matthews_correlation: 0.0000e+00 - val_loss: 0.2038 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00004: val_matthews_correlation did not improve from 0.00000
# Epoch 5/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.2107 - matthews_correlation: 0.0291 - val_loss: 0.2018 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00005: val_matthews_correlation did not improve from 0.00000
# Epoch 6/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1897 - matthews_correlation: 0.0673 - val_loss: 0.1722 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00006: val_matthews_correlation did not improve from 0.00000
# Epoch 7/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1719 - matthews_correlation: 0.0835 - val_loss: 0.1844 - val_matthews_correlation: 0.4175
#
# Epoch 00007: val_matthews_correlation improved from 0.00000 to 0.41752, saving model to weights_4.h5
# Epoch 8/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1398 - matthews_correlation: 0.3909 - val_loss: 0.1360 - val_matthews_correlation: 0.6127
#
# Epoch 00008: val_matthews_correlation improved from 0.41752 to 0.61268, saving model to weights_4.h5
# Epoch 9/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1137 - matthews_correlation: 0.5759 - val_loss: 0.1297 - val_matthews_correlation: 0.4073
#
# Epoch 00009: val_matthews_correlation did not improve from 0.61268
# Epoch 10/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1167 - matthews_correlation: 0.5555 - val_loss: 0.1241 - val_matthews_correlation: 0.6286
#
# Epoch 00010: val_matthews_correlation improved from 0.61268 to 0.62856, saving model to weights_4.h5
# Epoch 11/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1120 - matthews_correlation: 0.6635 - val_loss: 0.1339 - val_matthews_correlation: 0.5115
#
# Epoch 00011: val_matthews_correlation did not improve from 0.62856
# Epoch 12/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1168 - matthews_correlation: 0.5411 - val_loss: 0.1249 - val_matthews_correlation: 0.6062
#
# Epoch 00012: val_matthews_correlation did not improve from 0.62856
# Epoch 13/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1122 - matthews_correlation: 0.6659 - val_loss: 0.1142 - val_matthews_correlation: 0.5304
#
# Epoch 00013: val_matthews_correlation did not improve from 0.62856
# Epoch 14/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0976 - matthews_correlation: 0.6925 - val_loss: 0.1152 - val_matthews_correlation: 0.6013
#
# Epoch 00014: val_matthews_correlation did not improve from 0.62856
# Epoch 15/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1034 - matthews_correlation: 0.6553 - val_loss: 0.1283 - val_matthews_correlation: 0.3977
#
# Epoch 00015: val_matthews_correlation did not improve from 0.62856
# Epoch 16/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0976 - matthews_correlation: 0.6537 - val_loss: 0.1072 - val_matthews_correlation: 0.6366
#
# Epoch 00016: val_matthews_correlation improved from 0.62856 to 0.63664, saving model to weights_4.h5
# Epoch 17/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0975 - matthews_correlation: 0.6822 - val_loss: 0.1252 - val_matthews_correlation: 0.5132
#
# Epoch 00017: val_matthews_correlation did not improve from 0.63664
# Epoch 18/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0970 - matthews_correlation: 0.7080 - val_loss: 0.1147 - val_matthews_correlation: 0.5456
#
# Epoch 00018: val_matthews_correlation did not improve from 0.63664
# Epoch 19/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0939 - matthews_correlation: 0.6398 - val_loss: 0.1143 - val_matthews_correlation: 0.4269
#
# Epoch 00019: val_matthews_correlation did not improve from 0.63664
# Epoch 20/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1001 - matthews_correlation: 0.6477 - val_loss: 0.1167 - val_matthews_correlation: 0.5887
#
# Epoch 00020: val_matthews_correlation did not improve from 0.63664
# Epoch 21/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0920 - matthews_correlation: 0.6859 - val_loss: 0.1117 - val_matthews_correlation: 0.5118
#
# Epoch 00021: val_matthews_correlation did not improve from 0.63664
# Epoch 22/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0926 - matthews_correlation: 0.6981 - val_loss: 0.1135 - val_matthews_correlation: 0.6139
#
# Epoch 00022: val_matthews_correlation did not improve from 0.63664
# Epoch 23/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1015 - matthews_correlation: 0.6651 - val_loss: 0.1393 - val_matthews_correlation: 0.4395
#
# Epoch 00023: val_matthews_correlation did not improve from 0.63664
# Epoch 24/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.1019 - matthews_correlation: 0.6060 - val_loss: 0.1182 - val_matthews_correlation: 0.5466
#
# Epoch 00024: val_matthews_correlation did not improve from 0.63664
# Epoch 25/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0932 - matthews_correlation: 0.6941 - val_loss: 0.1277 - val_matthews_correlation: 0.3716
#
# Epoch 00025: val_matthews_correlation did not improve from 0.63664
# Epoch 26/50
# 2324/2324 [==============================] - 3s 1ms/step - loss: 0.0906 - matthews_correlation: 0.6604 - val_loss: 0.1135 - val_matthews_correlation: 0.5502
#
# Epoch 00026: val_matthews_correlation did not improve from 0.63664
# Epoch 00026: early stopping
# ((2904,), (2904,))

# %%
def threshold_search(y_true, y_proba):
    best_threshold = 0
    best_score = 0
    y_true_1 = K.variable(y_true)
    y_proba_1 = K.variable(y_proba)
    for threshold in tqdm([i * 0.01 for i in range(100)]):
        score = K.eval(matthews_correlation(y_true_1,y_proba_1))
        if score > best_score:
            best_threshold = threshold
            best_score = score
    search_result = {'threshold': best_threshold, 'matthews_correlation': best_score}
    return search_result

# %%
best_threshold = threshold_search(y_val, preds_val)['threshold']
# Out:
# 100%|██████████| 100/100 [00:23<00:00,  2.84it/s]

# %%
meta_test = pd.read_csv('../input/metadata_test.csv')

# %%
meta_test = meta_test.set_index(['signal_id'])
meta_test.head()
# Out:
#            id_measurement  phase
# signal_id
# 8712                 2904      0
# 8713                 2904      1
# 8714                 2904      2
# 8715                 2905      0
# 8716                 2905      1

# %%
first_sig = meta_test.index[0]
n_parts = 10
max_line = len(meta_test)
part_size = int(max_line / n_parts)
last_part = max_line % n_parts
print(first_sig, n_parts, max_line, part_size, last_part, n_parts * part_size + last_part)
# Here we create a list of lists with start index and end index for each of the 10 parts and one for the last partial part
start_end = [[x, x+part_size] for x in range(first_sig, max_line + first_sig, part_size)]
start_end = start_end[:-1] + [[start_end[-1][0], start_end[-1][0] + last_part]]
print(start_end)
X_test = []
# now, very like we did above with the train data, we convert the test data part by part
# transforming the 3 phases 800000 measurement in matrix (160,57)
for start, end in start_end:
    subset_test = pq.read_pandas('../input/test.parquet', columns=[str(i) for i in range(start, end)]).to_pandas()
    for i in tqdm(subset_test.columns):
        id_measurement, phase = meta_test.loc[int(i)]
        subset_test_col = subset_test[i]
        subset_trans = transform_ts(subset_test_col)
        X_test.append([i, id_measurement, phase, subset_trans])
# Out:
# 8712 10 20337 2033 7 20337
# [[8712, 10745], [10745, 12778], [12778, 14811], [14811, 16844], [16844, 18877], [18877, 20910], [20910, 22943], [22943, 24976], [24976, 27009], [27009, 29042], [29042, 29049]]
# 100%|██████████| 2033/2033 [03:12<00:00, 10.28it/s]
# 100%|██████████| 2033/2033 [03:13<00:00, 10.37it/s]
# 100%|██████████| 2033/2033 [03:15<00:00, 10.41it/s]
# 100%|██████████| 2033/2033 [03:15<00:00, 10.49it/s]
# 100%|██████████| 2033/2033 [03:18<00:00, 10.19it/s]
# 100%|██████████| 2033/2033 [03:16<00:00, 10.34it/s]
# 100%|██████████| 2033/2033 [03:16<00:00, 10.37it/s]
# 100%|██████████| 2033/2033 [03:15<00:00, 10.42it/s]
# 100%|██████████| 2033/2033 [03:15<00:00, 10.62it/s]
# 100%|██████████| 2033/2033 [03:14<00:00, 10.45it/s]
# 100%|██████████| 7/7 [00:00<00:00,  8.87it/s]

# %%
X_test_input = np.asarray([np.concatenate([X_test[i][3],X_test[i+1][3], X_test[i+2][3]], axis=1) for i in range(0,len(X_test), 3)])
np.save("X_test.npy",X_test_input)
X_test_input.shape
# Out:
# (6779, 160, 57)

# %%
submission = pd.read_csv('../input/sample_submission.csv')
print(len(submission))
submission.head()
# Out:
# 20337
#    signal_id  target
# 0       8712       0
# 1       8713       0
# 2       8714       0
# 3       8715       0
# 4       8716       0

# %%
preds_test = []
for i in range(N_SPLITS):
    model.load_weights('weights_{}.h5'.format(i))
    pred = model.predict(X_test_input, batch_size=300, verbose=1)
    pred_3 = []
    for pred_scalar in pred:
        for i in range(3):
            pred_3.append(pred_scalar)
    preds_test.append(pred_3)
# Out:
# 6779/6779 [==============================] - 2s 298us/step
# 6779/6779 [==============================] - 2s 268us/step
# 6779/6779 [==============================] - 2s 266us/step
# 6779/6779 [==============================] - 2s 265us/step
# 6779/6779 [==============================] - 2s 265us/step

# %%
preds_test = (np.squeeze(np.mean(preds_test, axis=0))).astype(np.int)
preds_test.shape
# Out:
# (20337,)

# %%
submission['target'] = preds_test
submission.to_csv('submission.csv', index=False)
submission.head()
# Out:
#    signal_id  target
# 0       8712       0
# 1       8713       0
# 2       8714       0
# 3       8715       0
# 4       8716       0
