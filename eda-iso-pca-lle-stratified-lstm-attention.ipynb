# %% [markdown]
# <h4><center><font size="6">VSB Power Line Fault Detection</center></font></h4>
# <br>
# <b>Faults in electric transmission lines can lead to a destructive phenomenon called partial discharge. If left alone, partial discharges can damage equipment to the point that it stops functioning entirely. Your challenge is to detect partial discharges so that repairs can be made before any lasting harm occurs. Each signal contains 800,000 measurements of a power line's voltage, taken over 20 milliseconds. As the underlying electric grid operates at 50 Hz, this means each signal covers a single complete grid cycle. The grid itself operates on a 3-phase power scheme, and all three phases are measured simultaneously.
# <br><br>
# The Challenge is to detect partial discharge patterns in signals acquired from these power lines with a new meter designed at the ENET Centre at VSB. Effective classifiers using this data will make it possible to continuously monitor power lines for faults.</b>
#
# <pre><b>Inspired from Bruno Aquino's Kernel:
# https://www.kaggle.com/braquino/5-fold-lstm-attention-fully-commented-0-694</b></pre>
#
# <pre><b>
# <a id = "#">Content</a>
# - <a href = "#1"> Import Library</a>
# - <a href = "#2"> Define Matthews Correlation</a>
# - <a href = "#3"> Create Attention Layer</a>
# - <a href = "#4"> Import Data</a>
# - <a href = "#5"> Define Transformations</a>
# - <a href = "#6"> Prepare Training Data</a>
# - <a href = "#7"> Data Exploration</a>
#     - <a href = "#71">Distribution of mean values per rows</a>
#     - <a href = "#72">Distribution of mean values per columns</a>
#     - <a href = "#73">Distribution of S.D values per rows</a>
#     - <a href = "#74">Distribution of S.D values per columns</a>
#     - <a href = "#75">Distribution of Skewness values per rows</a>
#     - <a href = "#76">Distribution of Skewness values per columns</a>
#     - <a href = "#77">Distribution of Kurtosis values per rows</a>
#     - <a href = "#78">Distribution of Kurtosis values per columns</a>
# - <a href = "#8">Applying TSNE Transformation</a>
# - <a href = "#9">Applying PCA Transformation></a>
# - <a href = "#19">Applying ISO Transformation</a>
# - <a href = "#10">Applying LLE Transformation></a>
# - <a href = "#11">Building the RNN Model Architecture</a>
# - <a href ="#12">Applying Stratified K Fold Technique</a>
# - <a href ="#13">Identify the Best Threshold</a>
# - <a href = "#14">Create Submission File</a>
# </b></pre>

# %% [markdown]
# <a id=1><pre><b>Import Library</b></pre></a>

# %%
import pandas as pd
import pyarrow.parquet as pq # Used to read the data
import os 
import numpy as np
from keras.layers import * # Keras is the most friendly Neural Network library, this Kernel use a lot of layers classes
from keras.models import Model
from tqdm import tqdm # Processing time measurement
from sklearn.model_selection import train_test_split 
from keras import backend as K # The backend give us access to tensorflow operations and allow us to create the Attention class
from keras import optimizers # Allow us to access the Adam class to modify some parameters
from sklearn.model_selection import GridSearchCV, StratifiedKFold,RepeatedStratifiedKFold # Used to use Kfold to train our model
from keras.callbacks import * # This object helps the model to train in a smarter way, avoiding overfitting
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
# select how many folds will be created
N_SPLITS = 5
# it is just a constant with the measurements data size
sample_size = 800000

# %% [markdown]
# <a id=2><pre><b>Define Matthews Correlation</b></pre></a>

# %%
# It is the official metric used in this competition
# below is the declaration of a function used inside the keras model, calculation with K (keras backend / thensorflow)
def matthews_correlation(y_true, y_pred):
    '''Calculates the Matthews correlation coefficient measure for quality
    of binary classification problems.
    '''
    y_pred = tf.convert_to_tensor(y_pred, np.float32)
    y_true = tf.convert_to_tensor(y_true, np.float32)
    
    y_pred_pos = K.round(K.clip(y_pred, 0, 1))
    y_pred_neg = 1 - y_pred_pos

    y_pos = K.round(K.clip(y_true, 0, 1))
    y_neg = 1 - y_pos

    tp = K.sum(y_pos * y_pred_pos)
    tn = K.sum(y_neg * y_pred_neg)

    fp = K.sum(y_neg * y_pred_pos)
    fn = K.sum(y_pos * y_pred_neg)

    numerator = (tp * tn - fp * fn)
    denominator = K.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn))

    return numerator / (denominator + K.epsilon())

# %% [markdown]
# <pre><a id = 3><b>Create Attention Layer</b></a></pre>

# %%
# https://www.kaggle.com/suicaokhoailang/lstm-attention-baseline-0-652-lb

class Attention(Layer):
    def __init__(self, step_dim,
                 W_regularizer=None, b_regularizer=None,
                 W_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
        self.supports_masking = True
        self.init = initializers.get('glorot_uniform')

        self.W_regularizer = regularizers.get(W_regularizer)
        self.b_regularizer = regularizers.get(b_regularizer)

        self.W_constraint = constraints.get(W_constraint)
        self.b_constraint = constraints.get(b_constraint)

        self.bias = bias
        self.step_dim = step_dim
        self.features_dim = 0
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3

        self.W = self.add_weight((input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        self.features_dim = input_shape[-1]

        if self.bias:
            self.b = self.add_weight((input_shape[1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None

        self.built = True

    def compute_mask(self, input, input_mask=None):
        return None

    def call(self, x, mask=None):
        features_dim = self.features_dim
        step_dim = self.step_dim

        eij = K.reshape(K.dot(K.reshape(x, (-1, features_dim)),
                        K.reshape(self.W, (features_dim, 1))), (-1, step_dim))

        if self.bias:
            eij += self.b

        eij = K.tanh(eij)

        a = K.exp(eij)

        if mask is not None:
            a *= K.cast(mask, K.floatx())

        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())

        a = K.expand_dims(a)
        weighted_input = x * a
        return K.sum(weighted_input, axis=1)

    def compute_output_shape(self, input_shape):
        return input_shape[0],  self.features_dim

# %% [markdown]
# <pre><a id = 4><b>Import Data</b></a></pre>

# %%
# just load train data
df_train = pd.read_csv('../input/metadata_train.csv')
# set index, it makes the data access much faster
df_train = df_train.set_index(['id_measurement', 'phase'])
df_train.head()
# Out:
#                       signal_id  target
# id_measurement phase
# 0              0              0       0
#                1              1       0
#                2              2       0
# 1              0              3       1
#                1              4       1

# %%
# in other notebook I have extracted the min and max values from the train data, the measurements
max_num = 127
min_num = -128

# %% [markdown]
# <pre><a id = 5><b>Define Transformations</b></a></pre>

# %%
# This function standardize the data from (-128 to 127) to (-1 to 1)
# Theoretically it helps in the NN Model training, but I didn't tested without it
def min_max_transformation(ts, min_data, max_data, range_needed=(-1,1)):
    if min_data < 0:
        ts_std = (ts + abs(min_data)) / (max_data + abs(min_data))
    else:
        ts_std = (ts - min_data) / (max_data - min_data)
    if range_needed[0] < 0:    
        return ts_std * (range_needed[1] + abs(range_needed[0])) + range_needed[0]
    else:
        return ts_std * (range_needed[1] - range_needed[0]) + range_needed[0]

# %%
def transform_ts(ts, n_dim=160, min_max=(-1,1)):
    # convert data into -1 to 1
    ts_std = min_max_transformation(ts, min_data=min_num, max_data=max_num)
    # bucket or chunk size, 5000 in this case (800000 / 160)
    bucket_size = int(sample_size / n_dim)
    # new_ts will be the container of the new data
    new_ts = []
    # this for iteract any chunk/bucket until reach the whole sample_size (800000)
    for i in range(0, sample_size, bucket_size):
        # cut each bucket to ts_range
        ts_range = ts_std[i:i + bucket_size]
        # calculate each feature
        mean = ts_range.mean()
        std = ts_range.std() # standard deviation
        std_top = mean + std # I have to test it more, but is is like a band
        std_bot = mean - std
        # I think that the percentiles are very important, it is like a distribuiton analysis from eath chunk
        percentil_calc = np.percentile(ts_range, [0, 1, 25, 50, 75, 99, 100]) 
        max_range = percentil_calc[-1] - percentil_calc[0] # this is the amplitude of the chunk
        relative_percentile = percentil_calc - mean # maybe it could heap to understand the asymmetry
        new_ts.append(np.concatenate([np.asarray([mean, std, std_top, std_bot, max_range]),percentil_calc, relative_percentile]))
    return np.asarray(new_ts)

# %% [markdown]
# <pre><a id = 6><b>Prepare Training Data</b></a></pre>

# %%
# this function take a piece of data and convert using transform_ts(), but it does to each of the 3 phases
# if we would try to do in one time, could exceed the RAM Memmory
def prepare_data(start, end):

    praq_train = pq.read_pandas('../input/train.parquet', columns=[str(i) for i in range(start, end)]).to_pandas()
    X = []
    y = []
   
    for id_measurement in tqdm(df_train.index.levels[0].unique()[int(start/3):int(end/3)]):
        X_signal = []
        # for each phase of the signal
        for phase in [0,1,2]:
            # extract from df_train both signal_id and target to compose the new data sets
            signal_id, target = df_train.loc[id_measurement].loc[phase]
            # but just append the target one time, to not triplicate it
            if phase == 0:
                y.append(target)
            # extract and transform data into sets of features
            X_signal.append(transform_ts(praq_train[str(signal_id)]))
        # concatenate all the 3 phases in one matrix
        X_signal = np.concatenate(X_signal, axis=1)
        # add the data to X
        X.append(X_signal)
    X = np.asarray(X)
    y = np.asarray(y)
    return X, y

# %%
# this code is very simple, divide the total size of the df_train into two sets and process it
X = []
y = []
def load_all():
    total_size = len(df_train)
    for ini, end in [(0, int(total_size/2)), (int(total_size/2), total_size)]:
        X_temp, y_temp = prepare_data(ini, end)
        X.append(X_temp)
        y.append(y_temp)
load_all()
X = np.concatenate(X)
y = np.concatenate(y)
# Out:
# 100%|██████████| 1452/1452 [05:44<00:00,  4.28it/s]
# 100%|██████████| 1452/1452 [05:37<00:00,  4.43it/s]

# %%
print(X.shape, y.shape)
# save data into file, a numpy specific format
np.save("X.npy",X)
np.save("y.npy",y)
# Out:
# (2904, 160, 57) (2904,)

# %% [markdown]
# <pre><a id = 7><b>Data Exploration</b></a></pre>

# %% [markdown]
# <pre><b> I used Panel to convert the X and Y into Data Frames</b></pre>

# %%
warnings.filterwarnings('ignore')

pan = pd.Panel(X)
df = pan.swapaxes(1, 2).to_frame()
df.index = df.index.droplevel('major')
df.index = df.index+1

# %%
df.shape
# Out:
# (9120, 2904)

# %%
df_y = pd.DataFrame(y.reshape(1,-1))

# %%
df_y.shape
# Out:
# (1, 2904)

# %% [markdown]
# <pre><b>Lets check the Explorations for Mean, Standard Deviation, Skewness and Kurtosis on the Data generated</b></pre>

# %% [markdown]
# <pre><a id = 71><b>Distribution of mean values per row in the training set</b></a></pre>

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use('seaborn')
from scipy.stats import norm, skew

plt.figure(figsize=(16,6))
plt.title("Distribution of mean values per row in the training set")
sns.distplot(df.mean(axis=0),color="red", kde=True,bins=120, label='train')
plt.legend()
plt.show()

# %% [markdown]
# <pre><a id = 72><b>Distribution of mean values per column in the training set</b></a></pre>

# %%
plt.figure(figsize=(16,6))
plt.title("Distribution of mean values per column in the train and test set")
sns.distplot(df.mean(axis=1),color="red", kde=True,bins=120, label='train')
plt.legend()
plt.show()

# %% [markdown]
# <pre><a id = 73><b>Distribution of S.D values per row in the training set</b></a></pre>

# %%
plt.figure(figsize=(16,6))
plt.title("Distribution of Standard Deviation values per row in the training set")
sns.distplot(df.std(axis=0),color="blue", kde=True,bins=120, label='train')
plt.legend()
plt.show()

# %% [markdown]
# <pre><a id = 74><b>Distribution of S.D values per column in the training set</b></a></pre>

# %%
plt.figure(figsize=(16,6))
plt.title("Distribution of Standard Deviation values per column in the training set")
sns.distplot(df.std(axis=1),color="blue", kde=True,bins=120, label='train')
plt.legend()
plt.show()

# %% [markdown]
# <pre><a id = 75><b>Distribution of Skewness values per rows in the training set</b></a></pre>

# %%
plt.figure(figsize=(16,6))
plt.title("Skewness Distribution per row in the training set")
sns.distplot(df.skew(axis=0),color="red", kde=True,bins=120, label='train')
plt.legend()
plt.show()

# %% [markdown]
# <pre><a id = 76><b>Distribution of Skewness values per column in the training set</b></a></pre>

# %%
plt.figure(figsize=(16,6))
plt.title("Skewness Distribution per column in the training set")
sns.distplot(df.skew(axis=1),color="red", kde=True,bins=120, label='train')
plt.legend()
plt.show()

# %% [markdown]
# <pre><b>What we understand now, is the reason behind the BIModal behavior. Since the power line fault is detected in a very few cases, there is a presence of class imbalance in the dataset, which is valid for this kind of data.</pre></b>

# %% [markdown]
# <pre><a id = 77><b>Distribution of Kurtosis values per rows in the training set</b></a></pre>

# %%
plt.figure(figsize=(16,6))
plt.title("Kurtosis Distribution per row in the training set")
sns.distplot(df.kurtosis(axis=0),color="red", kde=True,bins=120, label='train')
plt.legend()
plt.show()

# %% [markdown]
# <pre><b>The distribution is Platokurtic.</b></pre>

# %% [markdown]
# <pre><a id = 78><b>Distribution of Kurtosis values per columns in the training set</b></a></pre>

# %%
plt.figure(figsize=(16,6))
plt.title("Kurtosis Distribution per row in the training set")
sns.distplot(df.kurtosis(axis=1),color="red", kde=True,bins=120, label='train')
plt.legend()
plt.show()

# %% [markdown]
# <pre><b>Now Lets perform TSNE to see if the distribution is well seperated?</b></pre>

# %%
df.shape
# Out:
# (9120, 2904)

# %%
df_y.shape
# Out:
# (1, 2904)

# %% [markdown]
# <pre><b>Please note that since y's shape is different than X, i cant really use Y's for the color bar.  I am using a customized function for the color bar.</b></pre>

# %% [markdown]
# <pre><a id = 8><b>Applying TSNE Transformation</b></a></pre>

# %%
#Now let's use t-SNE to reduce dimensionality down to 2D so we can plot the dataset:
from sklearn.manifold import TSNE

tsne = TSNE(n_components=2, random_state=42, verbose = 2)
TSNE_X = tsne.fit_transform(df)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 9120 samples in 1.919s...
# [t-SNE] Computed neighbors for 9120 samples in 185.334s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 9120
# [t-SNE] Computed conditional probabilities for sample 2000 / 9120
# [t-SNE] Computed conditional probabilities for sample 3000 / 9120
# [t-SNE] Computed conditional probabilities for sample 4000 / 9120
# [t-SNE] Computed conditional probabilities for sample 5000 / 9120
# [t-SNE] Computed conditional probabilities for sample 6000 / 9120
# [t-SNE] Computed conditional probabilities for sample 7000 / 9120
# [t-SNE] Computed conditional probabilities for sample 8000 / 9120
# [t-SNE] Computed conditional probabilities for sample 9000 / 9120
# [t-SNE] Computed conditional probabilities for sample 9120 / 9120
# [t-SNE] Mean sigma: 0.068844
# [t-SNE] Computed conditional probabilities in 0.606s
# [t-SNE] Iteration 50: error = 94.9312592, gradient norm = 0.0144839 (50 iterations in 7.054s)
# [t-SNE] Iteration 100: error = 80.6700592, gradient norm = 0.0110079 (50 iterations in 3.610s)
# [t-SNE] Iteration 150: error = 78.2996292, gradient norm = 0.0179448 (50 iterations in 3.346s)
# [t-SNE] Iteration 200: error = 77.4927216, gradient norm = 0.0111039 (50 iterations in 3.056s)
# [t-SNE] Iteration 250: error = 77.1087036, gradient norm = 0.0044572 (50 iterations in 2.822s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 77.108704
# [t-SNE] Iteration 300: error = 2.5753088, gradient norm = 0.0014132 (50 iterations in 2.814s)
# [t-SNE] Iteration 350: error = 2.0216591, gradient norm = 0.0006141 (50 iterations in 2.885s)
# [t-SNE] Iteration 400: error = 1.7608404, gradient norm = 0.0003696 (50 iterations in 2.917s)
# [t-SNE] Iteration 450: error = 1.6070615, gradient norm = 0.0002546 (50 iterations in 3.406s)
# [t-SNE] Iteration 500: error = 1.5048186, gradient norm = 0.0001953 (50 iterations in 3.423s)
# [t-SNE] Iteration 550: error = 1.4326038, gradient norm = 0.0001515 (50 iterations in 3.458s)
# [t-SNE] Iteration 600: error = 1.3801576, gradient norm = 0.0001257 (50 iterations in 2.859s)
# [t-SNE] Iteration 650: error = 1.3402059, gradient norm = 0.0001104 (50 iterations in 2.821s)
# [t-SNE] Iteration 700: error = 1.3084787, gradient norm = 0.0000980 (50 iterations in 2.801s)
# [t-SNE] Iteration 750: error = 1.2830820, gradient norm = 0.0000906 (50 iterations in 2.788s)
# [t-SNE] Iteration 800: error = 1.2621857, gradient norm = 0.0000883 (50 iterations in 2.828s)
# [t-SNE] Iteration 850: error = 1.2455403, gradient norm = 0.0000801 (50 iterations in 2.787s)
# [t-SNE] Iteration 900: error = 1.2326373, gradient norm = 0.0000734 (50 iterations in 2.781s)
# [t-SNE] Iteration 950: error = 1.2221737, gradient norm = 0.0000695 (50 iterations in 2.811s)
# [t-SNE] Iteration 1000: error = 1.2135839, gradient norm = 0.0000675 (50 iterations in 3.247s)
# [t-SNE] KL divergence after 1000 iterations: 1.213584

# %%
import matplotlib as mpl
min, max = (-40, 30)
step = 10

# Setting up a colormap that's a simple transtion
mymap = mpl.colors.LinearSegmentedColormap.from_list('mycolors',['green','yellow','red'])

# Using contourf to provide my colorbar info, then clearing the figure
Z = [[0,0],[0,0]]
levels = range(min,max+step,step)
CS3 = plt.contourf(Z, levels, cmap=mymap)
plt.clf()

# %%
plt.figure(figsize=(13,10))
cm = plt.cm.get_cmap('RdYlGn_r')
colors=[cm(1*i) for i in [75,145,255]]
xy = range(3)
colorlist=[colors[x] for x in xy]
plt.scatter(TSNE_X[:, 0], TSNE_X[:, 1], c=colorlist, cmap=cm)
plt.colorbar(CS3)
plt.axis('off')
plt.show()

# %% [markdown]
# <pre><a id = 19><b>Applying ISO Transformation</b></a></pre>

# %%
from sklearn.manifold import Isomap

isomap = Isomap(n_components=200)
df_reduced = isomap.fit_transform(df)

# %%
plt.scatter(df_reduced[:, 0], df_reduced[:, 1], c=colorlist, cmap=plt.cm.hot)
plt.axis('off')
plt.colorbar(CS3)
plt.grid(True)

# %% [markdown]
# <pre><b>Now Lets perform PCA to see if the distribution is well seperated?</pre></b>

# %% [markdown]
# <pre><a id = 9><b>Applying PCA Transformation</b></a></pre>

# %%
from sklearn.decomposition import PCA

PCA_train_x = PCA(n_components=2, random_state=42).fit_transform(df)
plt.scatter(PCA_train_x[:, 0], PCA_train_x[:, 1], c=colorlist, cmap=cm)
plt.axis('off')
plt.colorbar(CS3)
plt.show()

# %%
from sklearn.decomposition import KernelPCA

lin_pca = KernelPCA(n_components = 2, kernel="linear", fit_inverse_transform=True)
rbf_pca = KernelPCA(n_components = 2, kernel="rbf", gamma=0.0433, fit_inverse_transform=True)
sig_pca = KernelPCA(n_components = 2, kernel="sigmoid", gamma=0.001, coef0=1, fit_inverse_transform=True)

plt.figure(figsize=(11, 4))
for subplot, pca, title in ((131, lin_pca, "Linear kernel"), (132, rbf_pca, "RBF kernel, $\gamma=0.04$"), (133, sig_pca, "Sigmoid kernel, $\gamma=10^{-3}, r=1$")):
    X_reduced = pca.fit_transform(df)
    if subplot == 132:
        X_reduced_rbf = X_reduced
    
    plt.subplot(subplot)
    plt.title(title, fontsize=14)
    plt.scatter(X_reduced[:, 0], X_reduced[:, 1], c=colorlist, cmap=plt.cm.hot)
    plt.xlabel("$z_1$", fontsize=18)
    if subplot == 131:
        plt.ylabel("$z_2$", fontsize=18, rotation=0)
    plt.grid(True)

# %% [markdown]
# <pre><b>After seeing the PCA model, I am eager to use Local Linear Embedding, as I do see the curve is resembling similar to a swiss roll.</b></pre>

# %% [markdown]
# <pre><a id = 10><b>Applying LLE Transformation</b></a></pre>

# %%
from sklearn.manifold import LocallyLinearEmbedding

lle = LocallyLinearEmbedding(n_components=2, n_neighbors=10, random_state=42)
lle_X = lle.fit_transform(df)

# %%
plt.title("Unrolling PCA graph using LLE", fontsize=14)
plt.scatter(lle_X[:, 0], lle_X[:, 1], c= colorlist, cmap=plt.cm.hot)
plt.xlabel("$z_1$", fontsize=18)
plt.ylabel("$z_2$", fontsize=18)
plt.colorbar(CS3)
plt.grid(True)
plt.show()

# %% [markdown]
# <pre><a id = 11><b>Building the RNN Model Architecture</b></a></pre>

# %%
# This is NN LSTM Model creation
def model_lstm(input_shape):
    # The shape was explained above, must have this order
    inp = Input(shape=(input_shape[1], input_shape[2],))
    
    x = Bidirectional(CuDNNLSTM(128, return_sequences=True))(inp)
    x = Bidirectional(CuDNNLSTM(64, return_sequences=True))(x)
    
    x = Attention(input_shape[1])(x)
    
    x = Dense(64, activation="relu")(x)
    x = Dense(1, activation="sigmoid")(x)
    model = Model(inputs=inp, outputs=x)
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=[matthews_correlation])
    
    return model

# %% [markdown]
# <pre><a id = 12><b>Applying Stratified K Fold Technique</b></a></pre>

# %%
# First, create a set of indexes of the 5 folds
splits = list(StratifiedKFold(n_splits=N_SPLITS,random_state=42).split(X, y))
preds_val = []
y_val = []
# Then, iteract with each fold
# If you dont know, enumerate(['a', 'b', 'c']) returns [(0, 'a'), (1, 'b'), (2, 'c')]
for idx, (train_idx, val_idx) in enumerate(splits):
    K.clear_session() # I dont know what it do, but I imagine that it "clear session" :)
    print("Beginning fold {}".format(idx+1))
    train_X, train_y, val_X, val_y = X[train_idx], y[train_idx], X[val_idx], y[val_idx]
    model = model_lstm(train_X.shape)
    #es = EarlyStopping(monitor='val_matthews_correlation', verbose=2, patience=50, mode='max')
    ckpt = ModelCheckpoint('weights_{}.h5'.format(idx), save_best_only=True, save_weights_only=True, verbose=1, monitor='val_matthews_correlation', mode='max')
    # Train, train, train
    model.fit(train_X, train_y, batch_size=128, epochs=50, validation_data=[val_X, val_y], callbacks=[ckpt])
    # loads the best weights saved by the checkpoint
    model.load_weights('weights_{}.h5'.format(idx))
    # Add the predictions of the validation to the list preds_val
    preds_val.append(model.predict(val_X, batch_size=512))
    # and the val true y
    y_val.append(val_y)

# concatenates all and prints the shape    
preds_val = np.concatenate(preds_val)[...,0]
y_val = np.concatenate(y_val)
preds_val.shape, y_val.shape
# Out:
# Beginning fold 1
# Train on 2322 samples, validate on 582 samples
# Epoch 1/50
# 2322/2322 [==============================] - 4s 2ms/step - loss: 0.3851 - matthews_correlation: 0.0000e+00 - val_loss: 0.2374 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_0.h5
# Epoch 2/50
# 2322/2322 [==============================] - 1s 443us/step - loss: 0.2291 - matthews_correlation: 0.0000e+00 - val_loss: 0.2279 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2322/2322 [==============================] - 1s 440us/step - loss: 0.2254 - matthews_correlation: 0.0000e+00 - val_loss: 0.2170 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00003: val_matthews_correlation did not improve from 0.00000
# Epoch 4/50
# 2322/2322 [==============================] - 1s 442us/step - loss: 0.2160 - matthews_correlation: 0.0000e+00 - val_loss: 0.2072 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00004: val_matthews_correlation did not improve from 0.00000
# Epoch 5/50
# 2322/2322 [==============================] - 1s 447us/step - loss: 0.2049 - matthews_correlation: -0.0035 - val_loss: 0.1988 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00005: val_matthews_correlation did not improve from 0.00000
# Epoch 6/50
# 2322/2322 [==============================] - 1s 445us/step - loss: 0.1929 - matthews_correlation: 0.2024 - val_loss: 0.1834 - val_matthews_correlation: 0.1110
#
# Epoch 00006: val_matthews_correlation improved from 0.00000 to 0.11104, saving model to weights_0.h5
# Epoch 7/50
# 2322/2322 [==============================] - 1s 449us/step - loss: 0.1757 - matthews_correlation: 0.1834 - val_loss: 0.1808 - val_matthews_correlation: 0.0534
#
# Epoch 00007: val_matthews_correlation did not improve from 0.11104
# Epoch 8/50
# 2322/2322 [==============================] - 1s 450us/step - loss: 0.1766 - matthews_correlation: 0.1263 - val_loss: 0.1821 - val_matthews_correlation: 0.2791
#
# Epoch 00008: val_matthews_correlation improved from 0.11104 to 0.27913, saving model to weights_0.h5
# Epoch 9/50
# 2322/2322 [==============================] - 1s 453us/step - loss: 0.1430 - matthews_correlation: 0.4165 - val_loss: 0.1441 - val_matthews_correlation: 0.2833
#
# Epoch 00009: val_matthews_correlation improved from 0.27913 to 0.28329, saving model to weights_0.h5
# Epoch 10/50
# 2322/2322 [==============================] - 1s 451us/step - loss: 0.1205 - matthews_correlation: 0.4619 - val_loss: 0.1049 - val_matthews_correlation: 0.5626
#
# Epoch 00010: val_matthews_correlation improved from 0.28329 to 0.56258, saving model to weights_0.h5
# Epoch 11/50
# 2322/2322 [==============================] - 1s 453us/step - loss: 0.1149 - matthews_correlation: 0.6612 - val_loss: 0.1125 - val_matthews_correlation: 0.5203
#
# Epoch 00011: val_matthews_correlation did not improve from 0.56258
# Epoch 12/50
# 2322/2322 [==============================] - 1s 452us/step - loss: 0.1216 - matthews_correlation: 0.6092 - val_loss: 0.1217 - val_matthews_correlation: 0.4795
#
# Epoch 00012: val_matthews_correlation did not improve from 0.56258
# Epoch 13/50
# 2322/2322 [==============================] - 1s 453us/step - loss: 0.1045 - matthews_correlation: 0.5974 - val_loss: 0.1388 - val_matthews_correlation: 0.5217
#
# Epoch 00013: val_matthews_correlation did not improve from 0.56258
# Epoch 14/50
# 2322/2322 [==============================] - 1s 451us/step - loss: 0.1228 - matthews_correlation: 0.5745 - val_loss: 0.1134 - val_matthews_correlation: 0.5231
#
# Epoch 00014: val_matthews_correlation did not improve from 0.56258
# Epoch 15/50
# 2322/2322 [==============================] - 1s 452us/step - loss: 0.1008 - matthews_correlation: 0.6329 - val_loss: 0.1559 - val_matthews_correlation: 0.5265
#
# Epoch 00015: val_matthews_correlation did not improve from 0.56258
# Epoch 16/50
# 2322/2322 [==============================] - 1s 452us/step - loss: 0.1151 - matthews_correlation: 0.6077 - val_loss: 0.1083 - val_matthews_correlation: 0.5213
#
# Epoch 00016: val_matthews_correlation did not improve from 0.56258
# Epoch 17/50
# 2322/2322 [==============================] - 1s 453us/step - loss: 0.1025 - matthews_correlation: 0.6693 - val_loss: 0.1055 - val_matthews_correlation: 0.5572
#
# Epoch 00017: val_matthews_correlation did not improve from 0.56258
# Epoch 18/50
# 2322/2322 [==============================] - 1s 451us/step - loss: 0.0990 - matthews_correlation: 0.6809 - val_loss: 0.1273 - val_matthews_correlation: 0.4978
#
# Epoch 00018: val_matthews_correlation did not improve from 0.56258
# Epoch 19/50
# 2322/2322 [==============================] - 1s 452us/step - loss: 0.0980 - matthews_correlation: 0.6853 - val_loss: 0.1051 - val_matthews_correlation: 0.5186
#
# Epoch 00019: val_matthews_correlation did not improve from 0.56258
# Epoch 20/50
# 2322/2322 [==============================] - 1s 451us/step - loss: 0.0980 - matthews_correlation: 0.6865 - val_loss: 0.1033 - val_matthews_correlation: 0.5267
#
# Epoch 00020: val_matthews_correlation did not improve from 0.56258
# Epoch 21/50
# 2322/2322 [==============================] - 1s 456us/step - loss: 0.0963 - matthews_correlation: 0.7128 - val_loss: 0.1138 - val_matthews_correlation: 0.5569
#
# Epoch 00021: val_matthews_correlation did not improve from 0.56258
# Epoch 22/50
# 2322/2322 [==============================] - 1s 449us/step - loss: 0.0924 - matthews_correlation: 0.6624 - val_loss: 0.1035 - val_matthews_correlation: 0.5816
#
# Epoch 00022: val_matthews_correlation improved from 0.56258 to 0.58164, saving model to weights_0.h5
# Epoch 23/50
# 2322/2322 [==============================] - 1s 454us/step - loss: 0.0901 - matthews_correlation: 0.7074 - val_loss: 0.1155 - val_matthews_correlation: 0.4717
#
# Epoch 00023: val_matthews_correlation did not improve from 0.58164
# Epoch 24/50
# 2322/2322 [==============================] - 1s 449us/step - loss: 0.1002 - matthews_correlation: 0.5642 - val_loss: 0.1154 - val_matthews_correlation: 0.5152
#
# Epoch 00024: val_matthews_correlation did not improve from 0.58164
# Epoch 25/50
# 2322/2322 [==============================] - 1s 451us/step - loss: 0.0928 - matthews_correlation: 0.7146 - val_loss: 0.1109 - val_matthews_correlation: 0.5267
#
# Epoch 00025: val_matthews_correlation did not improve from 0.58164
# Epoch 26/50
# 2322/2322 [==============================] - 1s 448us/step - loss: 0.0893 - matthews_correlation: 0.6527 - val_loss: 0.1056 - val_matthews_correlation: 0.5144
#
# Epoch 00026: val_matthews_correlation did not improve from 0.58164
# Epoch 27/50
# 2322/2322 [==============================] - 1s 450us/step - loss: 0.1016 - matthews_correlation: 0.6756 - val_loss: 0.1066 - val_matthews_correlation: 0.5333
#
# Epoch 00027: val_matthews_correlation did not improve from 0.58164
# Epoch 28/50
# 2322/2322 [==============================] - 1s 451us/step - loss: 0.0947 - matthews_correlation: 0.6453 - val_loss: 0.1168 - val_matthews_correlation: 0.5639
#
# Epoch 00028: val_matthews_correlation did not improve from 0.58164
# Epoch 29/50
# 2322/2322 [==============================] - 1s 453us/step - loss: 0.0939 - matthews_correlation: 0.6771 - val_loss: 0.1056 - val_matthews_correlation: 0.5263
#
# Epoch 00029: val_matthews_correlation did not improve from 0.58164
# Epoch 30/50
# 2322/2322 [==============================] - 1s 450us/step - loss: 0.0898 - matthews_correlation: 0.6696 - val_loss: 0.1129 - val_matthews_correlation: 0.5361
#
# Epoch 00030: val_matthews_correlation did not improve from 0.58164
# Epoch 31/50
# 2322/2322 [==============================] - 1s 452us/step - loss: 0.0862 - matthews_correlation: 0.7176 - val_loss: 0.1123 - val_matthews_correlation: 0.5554
#
# Epoch 00031: val_matthews_correlation did not improve from 0.58164
# Epoch 32/50
# 2322/2322 [==============================] - 1s 454us/step - loss: 0.0888 - matthews_correlation: 0.6885 - val_loss: 0.1073 - val_matthews_correlation: 0.5528
#
# Epoch 00032: val_matthews_correlation did not improve from 0.58164
# Epoch 33/50
# 2322/2322 [==============================] - 1s 454us/step - loss: 0.0915 - matthews_correlation: 0.7000 - val_loss: 0.1112 - val_matthews_correlation: 0.4961
#
# Epoch 00033: val_matthews_correlation did not improve from 0.58164
# Epoch 34/50
# 2322/2322 [==============================] - 1s 452us/step - loss: 0.0902 - matthews_correlation: 0.6580 - val_loss: 0.1071 - val_matthews_correlation: 0.5169
#
# Epoch 00034: val_matthews_correlation did not improve from 0.58164
# Epoch 35/50
# 2322/2322 [==============================] - 1s 456us/step - loss: 0.0859 - matthews_correlation: 0.6826 - val_loss: 0.1130 - val_matthews_correlation: 0.5597
#
# Epoch 00035: val_matthews_correlation did not improve from 0.58164
# Epoch 36/50
# 2322/2322 [==============================] - 1s 456us/step - loss: 0.0938 - matthews_correlation: 0.6479 - val_loss: 0.1051 - val_matthews_correlation: 0.5453
#
# Epoch 00036: val_matthews_correlation did not improve from 0.58164
# Epoch 37/50
# 2322/2322 [==============================] - 1s 455us/step - loss: 0.0865 - matthews_correlation: 0.7341 - val_loss: 0.1076 - val_matthews_correlation: 0.5462
#
# Epoch 00037: val_matthews_correlation did not improve from 0.58164
# Epoch 38/50
# 2322/2322 [==============================] - 1s 454us/step - loss: 0.0857 - matthews_correlation: 0.6882 - val_loss: 0.1033 - val_matthews_correlation: 0.5911
#
# Epoch 00038: val_matthews_correlation improved from 0.58164 to 0.59111, saving model to weights_0.h5
# Epoch 39/50
# 2322/2322 [==============================] - 1s 458us/step - loss: 0.0865 - matthews_correlation: 0.6748 - val_loss: 0.1070 - val_matthews_correlation: 0.5107
#
# Epoch 00039: val_matthews_correlation did not improve from 0.59111
# Epoch 40/50
# 2322/2322 [==============================] - 1s 454us/step - loss: 0.0855 - matthews_correlation: 0.7449 - val_loss: 0.1080 - val_matthews_correlation: 0.5278
#
# Epoch 00040: val_matthews_correlation did not improve from 0.59111
# Epoch 41/50
# 2322/2322 [==============================] - 1s 458us/step - loss: 0.0944 - matthews_correlation: 0.6181 - val_loss: 0.1069 - val_matthews_correlation: 0.5369
#
# Epoch 00041: val_matthews_correlation did not improve from 0.59111
# Epoch 42/50
# 2322/2322 [==============================] - 1s 454us/step - loss: 0.0894 - matthews_correlation: 0.6510 - val_loss: 0.1167 - val_matthews_correlation: 0.5597
#
# Epoch 00042: val_matthews_correlation did not improve from 0.59111
# Epoch 43/50
# 2322/2322 [==============================] - 1s 455us/step - loss: 0.0939 - matthews_correlation: 0.6775 - val_loss: 0.1066 - val_matthews_correlation: 0.5389
#
# Epoch 00043: val_matthews_correlation did not improve from 0.59111
# Epoch 44/50
# 2322/2322 [==============================] - 1s 455us/step - loss: 0.0821 - matthews_correlation: 0.7566 - val_loss: 0.1117 - val_matthews_correlation: 0.5437
#
# Epoch 00044: val_matthews_correlation did not improve from 0.59111
# Epoch 45/50
# 2322/2322 [==============================] - 1s 457us/step - loss: 0.0837 - matthews_correlation: 0.6754 - val_loss: 0.1161 - val_matthews_correlation: 0.5224
#
# Epoch 00045: val_matthews_correlation did not improve from 0.59111
# Epoch 46/50
# 2322/2322 [==============================] - 1s 453us/step - loss: 0.0791 - matthews_correlation: 0.7422 - val_loss: 0.1093 - val_matthews_correlation: 0.5725
#
# Epoch 00046: val_matthews_correlation did not improve from 0.59111
# Epoch 47/50
# 2322/2322 [==============================] - 1s 455us/step - loss: 0.0785 - matthews_correlation: 0.7033 - val_loss: 0.1177 - val_matthews_correlation: 0.5437
#
# Epoch 00047: val_matthews_correlation did not improve from 0.59111
# Epoch 48/50
# 2322/2322 [==============================] - 1s 453us/step - loss: 0.0831 - matthews_correlation: 0.6702 - val_loss: 0.1105 - val_matthews_correlation: 0.5366
#
# Epoch 00048: val_matthews_correlation did not improve from 0.59111
# Epoch 49/50
# 2322/2322 [==============================] - 1s 447us/step - loss: 0.0801 - matthews_correlation: 0.7423 - val_loss: 0.1119 - val_matthews_correlation: 0.5422
#
# Epoch 00049: val_matthews_correlation did not improve from 0.59111
# Epoch 50/50
# 2322/2322 [==============================] - 1s 446us/step - loss: 0.0857 - matthews_correlation: 0.6997 - val_loss: 0.1059 - val_matthews_correlation: 0.5686
#
# Epoch 00050: val_matthews_correlation did not improve from 0.59111
# Beginning fold 2
# Train on 2323 samples, validate on 581 samples
# Epoch 1/50
# 2323/2323 [==============================] - 2s 958us/step - loss: 0.3529 - matthews_correlation: 0.0076 - val_loss: 0.2459 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_1.h5
# Epoch 2/50
# 2323/2323 [==============================] - 1s 452us/step - loss: 0.2278 - matthews_correlation: 0.0000e+00 - val_loss: 0.2207 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2323/2323 [==============================] - 1s 451us/step - loss: 0.2108 - matthews_correlation: 0.0000e+00 - val_loss: 0.2084 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00003: val_matthews_correlation did not improve from 0.00000
# Epoch 4/50
# 2323/2323 [==============================] - 1s 451us/step - loss: 0.2021 - matthews_correlation: 0.1278 - val_loss: 0.2011 - val_matthews_correlation: 0.2608
#
# Epoch 00004: val_matthews_correlation improved from 0.00000 to 0.26079, saving model to weights_1.h5
# Epoch 5/50
# 2323/2323 [==============================] - 1s 457us/step - loss: 0.1832 - matthews_correlation: 0.2092 - val_loss: 0.2027 - val_matthews_correlation: 0.3248
#
# Epoch 00005: val_matthews_correlation improved from 0.26079 to 0.32485, saving model to weights_1.h5
# Epoch 6/50
# 2323/2323 [==============================] - 1s 462us/step - loss: 0.1694 - matthews_correlation: 0.3520 - val_loss: 0.1678 - val_matthews_correlation: 0.3520
#
# Epoch 00006: val_matthews_correlation improved from 0.32485 to 0.35196, saving model to weights_1.h5
# Epoch 7/50
# 2323/2323 [==============================] - 1s 456us/step - loss: 0.1234 - matthews_correlation: 0.4876 - val_loss: 0.1487 - val_matthews_correlation: 0.4618
#
# Epoch 00007: val_matthews_correlation improved from 0.35196 to 0.46175, saving model to weights_1.h5
# Epoch 8/50
# 2323/2323 [==============================] - 1s 458us/step - loss: 0.1154 - matthews_correlation: 0.5812 - val_loss: 0.1401 - val_matthews_correlation: 0.4647
#
# Epoch 00008: val_matthews_correlation improved from 0.46175 to 0.46474, saving model to weights_1.h5
# Epoch 9/50
# 2323/2323 [==============================] - 1s 457us/step - loss: 0.1045 - matthews_correlation: 0.6548 - val_loss: 0.1303 - val_matthews_correlation: 0.4631
#
# Epoch 00009: val_matthews_correlation did not improve from 0.46474
# Epoch 10/50
# 2323/2323 [==============================] - 1s 459us/step - loss: 0.1001 - matthews_correlation: 0.7064 - val_loss: 0.1267 - val_matthews_correlation: 0.5433
#
# Epoch 00010: val_matthews_correlation improved from 0.46474 to 0.54326, saving model to weights_1.h5
# Epoch 11/50
# 2323/2323 [==============================] - 1s 458us/step - loss: 0.1083 - matthews_correlation: 0.6417 - val_loss: 0.1510 - val_matthews_correlation: 0.5655
#
# Epoch 00011: val_matthews_correlation improved from 0.54326 to 0.56553, saving model to weights_1.h5
# Epoch 12/50
# 2323/2323 [==============================] - 1s 459us/step - loss: 0.0976 - matthews_correlation: 0.6921 - val_loss: 0.1305 - val_matthews_correlation: 0.5418
#
# Epoch 00012: val_matthews_correlation did not improve from 0.56553
# Epoch 13/50
# 2323/2323 [==============================] - 1s 457us/step - loss: 0.0981 - matthews_correlation: 0.6396 - val_loss: 0.1248 - val_matthews_correlation: 0.6357
#
# Epoch 00013: val_matthews_correlation improved from 0.56553 to 0.63570, saving model to weights_1.h5
# Epoch 14/50
# 2323/2323 [==============================] - 1s 458us/step - loss: 0.0941 - matthews_correlation: 0.6568 - val_loss: 0.1253 - val_matthews_correlation: 0.5151
#
# Epoch 00014: val_matthews_correlation did not improve from 0.63570
# Epoch 15/50
# 2323/2323 [==============================] - 1s 457us/step - loss: 0.0978 - matthews_correlation: 0.6977 - val_loss: 0.1269 - val_matthews_correlation: 0.5066
#
# Epoch 00015: val_matthews_correlation did not improve from 0.63570
# Epoch 16/50
# 2323/2323 [==============================] - 1s 458us/step - loss: 0.0921 - matthews_correlation: 0.7188 - val_loss: 0.1297 - val_matthews_correlation: 0.5680
#
# Epoch 00016: val_matthews_correlation did not improve from 0.63570
# Epoch 17/50
# 2323/2323 [==============================] - 1s 455us/step - loss: 0.0914 - matthews_correlation: 0.6872 - val_loss: 0.1299 - val_matthews_correlation: 0.4936
#
# Epoch 00017: val_matthews_correlation did not improve from 0.63570
# Epoch 18/50
# 2323/2323 [==============================] - 1s 459us/step - loss: 0.0918 - matthews_correlation: 0.7275 - val_loss: 0.1331 - val_matthews_correlation: 0.5276
#
# Epoch 00018: val_matthews_correlation did not improve from 0.63570
# Epoch 19/50
# 2323/2323 [==============================] - 1s 458us/step - loss: 0.0895 - matthews_correlation: 0.6470 - val_loss: 0.1294 - val_matthews_correlation: 0.5474
#
# Epoch 00019: val_matthews_correlation did not improve from 0.63570
# Epoch 20/50
# 2323/2323 [==============================] - 1s 456us/step - loss: 0.0901 - matthews_correlation: 0.7000 - val_loss: 0.1516 - val_matthews_correlation: 0.3119
#
# Epoch 00020: val_matthews_correlation did not improve from 0.63570
# Epoch 21/50
# 2323/2323 [==============================] - 1s 460us/step - loss: 0.0939 - matthews_correlation: 0.7086 - val_loss: 0.1238 - val_matthews_correlation: 0.4706
#
# Epoch 00021: val_matthews_correlation did not improve from 0.63570
# Epoch 22/50
# 2323/2323 [==============================] - 1s 457us/step - loss: 0.0846 - matthews_correlation: 0.6659 - val_loss: 0.1321 - val_matthews_correlation: 0.4733
#
# Epoch 00022: val_matthews_correlation did not improve from 0.63570
# Epoch 23/50
# 2323/2323 [==============================] - 1s 458us/step - loss: 0.0911 - matthews_correlation: 0.6932 - val_loss: 0.1270 - val_matthews_correlation: 0.5684
#
# Epoch 00023: val_matthews_correlation did not improve from 0.63570
# Epoch 24/50
# 2323/2323 [==============================] - 1s 459us/step - loss: 0.0923 - matthews_correlation: 0.6767 - val_loss: 0.1311 - val_matthews_correlation: 0.4961
#
# Epoch 00024: val_matthews_correlation did not improve from 0.63570
# Epoch 25/50
# 2323/2323 [==============================] - 1s 461us/step - loss: 0.0885 - matthews_correlation: 0.6976 - val_loss: 0.1240 - val_matthews_correlation: 0.4751
#
# Epoch 00025: val_matthews_correlation did not improve from 0.63570
# Epoch 26/50
# 2323/2323 [==============================] - 1s 458us/step - loss: 0.0845 - matthews_correlation: 0.6826 - val_loss: 0.1442 - val_matthews_correlation: 0.4344
#
# Epoch 00026: val_matthews_correlation did not improve from 0.63570
# Epoch 27/50
# 2323/2323 [==============================] - 1s 457us/step - loss: 0.0873 - matthews_correlation: 0.7281 - val_loss: 0.1236 - val_matthews_correlation: 0.5065
#
# Epoch 00027: val_matthews_correlation did not improve from 0.63570
# Epoch 28/50
# 2323/2323 [==============================] - 1s 459us/step - loss: 0.0805 - matthews_correlation: 0.7229 - val_loss: 0.1273 - val_matthews_correlation: 0.4335
#
# Epoch 00028: val_matthews_correlation did not improve from 0.63570
# Epoch 29/50
# 2323/2323 [==============================] - 1s 458us/step - loss: 0.0840 - matthews_correlation: 0.7109 - val_loss: 0.1281 - val_matthews_correlation: 0.5931
#
# Epoch 00029: val_matthews_correlation did not improve from 0.63570
# Epoch 30/50
# 2323/2323 [==============================] - 1s 457us/step - loss: 0.0794 - matthews_correlation: 0.7406 - val_loss: 0.1366 - val_matthews_correlation: 0.3502
#
# Epoch 00030: val_matthews_correlation did not improve from 0.63570
# Epoch 31/50
# 2323/2323 [==============================] - 1s 455us/step - loss: 0.0871 - matthews_correlation: 0.6510 - val_loss: 0.1319 - val_matthews_correlation: 0.6027
#
# Epoch 00031: val_matthews_correlation did not improve from 0.63570
# Epoch 32/50
# 2323/2323 [==============================] - 1s 459us/step - loss: 0.0781 - matthews_correlation: 0.7382 - val_loss: 0.1250 - val_matthews_correlation: 0.5829
#
# Epoch 00032: val_matthews_correlation did not improve from 0.63570
# Epoch 33/50
# 2323/2323 [==============================] - 1s 455us/step - loss: 0.0775 - matthews_correlation: 0.7262 - val_loss: 0.1420 - val_matthews_correlation: 0.4607
#
# Epoch 00033: val_matthews_correlation did not improve from 0.63570
# Epoch 34/50
# 2323/2323 [==============================] - 1s 462us/step - loss: 0.0735 - matthews_correlation: 0.6910 - val_loss: 0.1436 - val_matthews_correlation: 0.4797
#
# Epoch 00034: val_matthews_correlation did not improve from 0.63570
# Epoch 35/50
# 2323/2323 [==============================] - 1s 455us/step - loss: 0.0968 - matthews_correlation: 0.7387 - val_loss: 0.1256 - val_matthews_correlation: 0.4794
#
# Epoch 00035: val_matthews_correlation did not improve from 0.63570
# Epoch 36/50
# 2323/2323 [==============================] - 1s 460us/step - loss: 0.0844 - matthews_correlation: 0.7318 - val_loss: 0.1250 - val_matthews_correlation: 0.4852
#
# Epoch 00036: val_matthews_correlation did not improve from 0.63570
# Epoch 37/50
# 2323/2323 [==============================] - 1s 456us/step - loss: 0.0757 - matthews_correlation: 0.7444 - val_loss: 0.1306 - val_matthews_correlation: 0.4209
#
# Epoch 00037: val_matthews_correlation did not improve from 0.63570
# Epoch 38/50
# 2323/2323 [==============================] - 1s 454us/step - loss: 0.0800 - matthews_correlation: 0.7503 - val_loss: 0.1282 - val_matthews_correlation: 0.3765
#
# Epoch 00038: val_matthews_correlation did not improve from 0.63570
# Epoch 39/50
# 2323/2323 [==============================] - 1s 457us/step - loss: 0.0789 - matthews_correlation: 0.6764 - val_loss: 0.1544 - val_matthews_correlation: 0.4154
#
# Epoch 00039: val_matthews_correlation did not improve from 0.63570
# Epoch 40/50
# 2323/2323 [==============================] - 1s 457us/step - loss: 0.0821 - matthews_correlation: 0.7147 - val_loss: 0.1328 - val_matthews_correlation: 0.4885
#
# Epoch 00040: val_matthews_correlation did not improve from 0.63570
# Epoch 41/50
# 2323/2323 [==============================] - 1s 457us/step - loss: 0.0786 - matthews_correlation: 0.7396 - val_loss: 0.1315 - val_matthews_correlation: 0.4822
#
# Epoch 00041: val_matthews_correlation did not improve from 0.63570
# Epoch 42/50
# 2323/2323 [==============================] - 1s 455us/step - loss: 0.0726 - matthews_correlation: 0.7244 - val_loss: 0.1307 - val_matthews_correlation: 0.4747
#
# Epoch 00042: val_matthews_correlation did not improve from 0.63570
# Epoch 43/50
# 2323/2323 [==============================] - 1s 459us/step - loss: 0.0732 - matthews_correlation: 0.7498 - val_loss: 0.1465 - val_matthews_correlation: 0.4744
#
# Epoch 00043: val_matthews_correlation did not improve from 0.63570
# Epoch 44/50
# 2323/2323 [==============================] - 1s 458us/step - loss: 0.0751 - matthews_correlation: 0.7304 - val_loss: 0.1325 - val_matthews_correlation: 0.4728
#
# Epoch 00044: val_matthews_correlation did not improve from 0.63570
# Epoch 45/50
# 2323/2323 [==============================] - 1s 457us/step - loss: 0.0686 - matthews_correlation: 0.7558 - val_loss: 0.1344 - val_matthews_correlation: 0.5043
#
# Epoch 00045: val_matthews_correlation did not improve from 0.63570
# Epoch 46/50
# 2323/2323 [==============================] - 1s 458us/step - loss: 0.0696 - matthews_correlation: 0.7809 - val_loss: 0.1323 - val_matthews_correlation: 0.4534
#
# Epoch 00046: val_matthews_correlation did not improve from 0.63570
# Epoch 47/50
# 2323/2323 [==============================] - 1s 456us/step - loss: 0.0822 - matthews_correlation: 0.7079 - val_loss: 0.1420 - val_matthews_correlation: 0.3698
#
# Epoch 00047: val_matthews_correlation did not improve from 0.63570
# Epoch 48/50
# 2323/2323 [==============================] - 1s 457us/step - loss: 0.0903 - matthews_correlation: 0.7053 - val_loss: 0.1298 - val_matthews_correlation: 0.4214
#
# Epoch 00048: val_matthews_correlation did not improve from 0.63570
# Epoch 49/50
# 2323/2323 [==============================] - 1s 459us/step - loss: 0.0801 - matthews_correlation: 0.7266 - val_loss: 0.1317 - val_matthews_correlation: 0.5298
#
# Epoch 00049: val_matthews_correlation did not improve from 0.63570
# Epoch 50/50
# 2323/2323 [==============================] - 1s 461us/step - loss: 0.0735 - matthews_correlation: 0.7597 - val_loss: 0.1353 - val_matthews_correlation: 0.4721
#
# Epoch 00050: val_matthews_correlation did not improve from 0.63570
# Beginning fold 3
# Train on 2323 samples, validate on 581 samples
# Epoch 1/50
# 2323/2323 [==============================] - 2s 918us/step - loss: 0.3568 - matthews_correlation: -0.0149 - val_loss: 0.2444 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_2.h5
# Epoch 2/50
# 2323/2323 [==============================] - 1s 457us/step - loss: 0.2318 - matthews_correlation: 0.0000e+00 - val_loss: 0.2310 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2323/2323 [==============================] - 1s 456us/step - loss: 0.2278 - matthews_correlation: 0.0000e+00 - val_loss: 0.2274 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00003: val_matthews_correlation did not improve from 0.00000
# Epoch 4/50
# 2323/2323 [==============================] - 1s 456us/step - loss: 0.2200 - matthews_correlation: 0.0000e+00 - val_loss: 0.2117 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00004: val_matthews_correlation did not improve from 0.00000
# Epoch 5/50
# 2323/2323 [==============================] - 1s 458us/step - loss: 0.2150 - matthews_correlation: 0.0000e+00 - val_loss: 0.2147 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00005: val_matthews_correlation did not improve from 0.00000
# Epoch 6/50
# 2323/2323 [==============================] - 1s 454us/step - loss: 0.2001 - matthews_correlation: -0.0027 - val_loss: 0.1802 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00006: val_matthews_correlation did not improve from 0.00000
# Epoch 7/50
# 2323/2323 [==============================] - 1s 456us/step - loss: 0.1778 - matthews_correlation: 0.1915 - val_loss: 0.1933 - val_matthews_correlation: 0.1968
#
# Epoch 00007: val_matthews_correlation improved from 0.00000 to 0.19682, saving model to weights_2.h5
# Epoch 8/50
# 2323/2323 [==============================] - 1s 456us/step - loss: 0.1761 - matthews_correlation: 0.2553 - val_loss: 0.1337 - val_matthews_correlation: 0.1813
#
# Epoch 00008: val_matthews_correlation did not improve from 0.19682
# Epoch 9/50
# 2323/2323 [==============================] - 1s 459us/step - loss: 0.1282 - matthews_correlation: 0.4543 - val_loss: 0.0932 - val_matthews_correlation: 0.6283
#
# Epoch 00009: val_matthews_correlation improved from 0.19682 to 0.62828, saving model to weights_2.h5
# Epoch 10/50
# 2323/2323 [==============================] - 1s 455us/step - loss: 0.1234 - matthews_correlation: 0.5036 - val_loss: 0.0976 - val_matthews_correlation: 0.5991
#
# Epoch 00010: val_matthews_correlation did not improve from 0.62828
# Epoch 11/50
# 2323/2323 [==============================] - 1s 453us/step - loss: 0.1152 - matthews_correlation: 0.5724 - val_loss: 0.0859 - val_matthews_correlation: 0.6619
#
# Epoch 00011: val_matthews_correlation improved from 0.62828 to 0.66187, saving model to weights_2.h5
# Epoch 12/50
# 2323/2323 [==============================] - 1s 453us/step - loss: 0.1141 - matthews_correlation: 0.5934 - val_loss: 0.0869 - val_matthews_correlation: 0.6679
#
# Epoch 00012: val_matthews_correlation improved from 0.66187 to 0.66792, saving model to weights_2.h5
# Epoch 13/50
# 2323/2323 [==============================] - 1s 458us/step - loss: 0.1145 - matthews_correlation: 0.5593 - val_loss: 0.0878 - val_matthews_correlation: 0.5891
#
# Epoch 00013: val_matthews_correlation did not improve from 0.66792
# Epoch 14/50
# 2323/2323 [==============================] - 1s 453us/step - loss: 0.1047 - matthews_correlation: 0.6197 - val_loss: 0.0796 - val_matthews_correlation: 0.6881
#
# Epoch 00014: val_matthews_correlation improved from 0.66792 to 0.68811, saving model to weights_2.h5
# Epoch 15/50
# 2323/2323 [==============================] - 1s 454us/step - loss: 0.1055 - matthews_correlation: 0.5910 - val_loss: 0.0876 - val_matthews_correlation: 0.6335
#
# Epoch 00015: val_matthews_correlation did not improve from 0.68811
# Epoch 16/50
# 2323/2323 [==============================] - 1s 455us/step - loss: 0.1204 - matthews_correlation: 0.6074 - val_loss: 0.0932 - val_matthews_correlation: 0.6521
#
# Epoch 00016: val_matthews_correlation did not improve from 0.68811
# Epoch 17/50
# 2323/2323 [==============================] - 1s 449us/step - loss: 0.1040 - matthews_correlation: 0.6168 - val_loss: 0.0857 - val_matthews_correlation: 0.6512
#
# Epoch 00017: val_matthews_correlation did not improve from 0.68811
# Epoch 18/50
# 2323/2323 [==============================] - 1s 441us/step - loss: 0.1007 - matthews_correlation: 0.6492 - val_loss: 0.0825 - val_matthews_correlation: 0.6512
#
# Epoch 00018: val_matthews_correlation did not improve from 0.68811
# Epoch 19/50
# 2323/2323 [==============================] - 1s 444us/step - loss: 0.0982 - matthews_correlation: 0.6448 - val_loss: 0.0801 - val_matthews_correlation: 0.6679
#
# Epoch 00019: val_matthews_correlation did not improve from 0.68811
# Epoch 20/50
# 2323/2323 [==============================] - 1s 449us/step - loss: 0.0958 - matthews_correlation: 0.6968 - val_loss: 0.0800 - val_matthews_correlation: 0.6371
#
# Epoch 00020: val_matthews_correlation did not improve from 0.68811
# Epoch 21/50
# 2323/2323 [==============================] - 1s 448us/step - loss: 0.0981 - matthews_correlation: 0.6208 - val_loss: 0.0850 - val_matthews_correlation: 0.6520
#
# Epoch 00021: val_matthews_correlation did not improve from 0.68811
# Epoch 22/50
# 2323/2323 [==============================] - 1s 446us/step - loss: 0.0964 - matthews_correlation: 0.6436 - val_loss: 0.0770 - val_matthews_correlation: 0.6674
#
# Epoch 00022: val_matthews_correlation did not improve from 0.68811
# Epoch 23/50
# 2323/2323 [==============================] - 1s 443us/step - loss: 0.0954 - matthews_correlation: 0.6791 - val_loss: 0.0796 - val_matthews_correlation: 0.6711
#
# Epoch 00023: val_matthews_correlation did not improve from 0.68811
# Epoch 24/50
# 2323/2323 [==============================] - 1s 444us/step - loss: 0.0945 - matthews_correlation: 0.6475 - val_loss: 0.0827 - val_matthews_correlation: 0.6532
#
# Epoch 00024: val_matthews_correlation did not improve from 0.68811
# Epoch 25/50
# 2323/2323 [==============================] - 1s 449us/step - loss: 0.0913 - matthews_correlation: 0.6580 - val_loss: 0.0951 - val_matthews_correlation: 0.6452
#
# Epoch 00025: val_matthews_correlation did not improve from 0.68811
# Epoch 26/50
# 2323/2323 [==============================] - 1s 444us/step - loss: 0.1001 - matthews_correlation: 0.5698 - val_loss: 0.0910 - val_matthews_correlation: 0.5884
#
# Epoch 00026: val_matthews_correlation did not improve from 0.68811
# Epoch 27/50
# 2323/2323 [==============================] - 1s 452us/step - loss: 0.0955 - matthews_correlation: 0.5949 - val_loss: 0.0812 - val_matthews_correlation: 0.6897
#
# Epoch 00027: val_matthews_correlation improved from 0.68811 to 0.68973, saving model to weights_2.h5
# Epoch 28/50
# 2323/2323 [==============================] - 1s 457us/step - loss: 0.0909 - matthews_correlation: 0.6911 - val_loss: 0.0803 - val_matthews_correlation: 0.6423
#
# Epoch 00028: val_matthews_correlation did not improve from 0.68973
# Epoch 29/50
# 2323/2323 [==============================] - 1s 457us/step - loss: 0.0876 - matthews_correlation: 0.6725 - val_loss: 0.0907 - val_matthews_correlation: 0.6299
#
# Epoch 00029: val_matthews_correlation did not improve from 0.68973
# Epoch 30/50
# 2323/2323 [==============================] - 1s 455us/step - loss: 0.0879 - matthews_correlation: 0.6901 - val_loss: 0.0883 - val_matthews_correlation: 0.5953
#
# Epoch 00030: val_matthews_correlation did not improve from 0.68973
# Epoch 31/50
# 2323/2323 [==============================] - 1s 456us/step - loss: 0.0876 - matthews_correlation: 0.6753 - val_loss: 0.0799 - val_matthews_correlation: 0.6723
#
# Epoch 00031: val_matthews_correlation did not improve from 0.68973
# Epoch 32/50
# 2323/2323 [==============================] - 1s 455us/step - loss: 0.0914 - matthews_correlation: 0.6491 - val_loss: 0.0865 - val_matthews_correlation: 0.6619
#
# Epoch 00032: val_matthews_correlation did not improve from 0.68973
# Epoch 33/50
# 2323/2323 [==============================] - 1s 456us/step - loss: 0.0914 - matthews_correlation: 0.6764 - val_loss: 0.0789 - val_matthews_correlation: 0.6257
#
# Epoch 00033: val_matthews_correlation did not improve from 0.68973
# Epoch 34/50
# 2323/2323 [==============================] - 1s 461us/step - loss: 0.0868 - matthews_correlation: 0.7198 - val_loss: 0.0936 - val_matthews_correlation: 0.5970
#
# Epoch 00034: val_matthews_correlation did not improve from 0.68973
# Epoch 35/50
# 2323/2323 [==============================] - 1s 454us/step - loss: 0.0891 - matthews_correlation: 0.6698 - val_loss: 0.0876 - val_matthews_correlation: 0.6136
#
# Epoch 00035: val_matthews_correlation did not improve from 0.68973
# Epoch 36/50
# 2323/2323 [==============================] - 1s 454us/step - loss: 0.0887 - matthews_correlation: 0.6383 - val_loss: 0.0772 - val_matthews_correlation: 0.6440
#
# Epoch 00036: val_matthews_correlation did not improve from 0.68973
# Epoch 37/50
# 2323/2323 [==============================] - 1s 456us/step - loss: 0.0956 - matthews_correlation: 0.5846 - val_loss: 0.0812 - val_matthews_correlation: 0.6423
#
# Epoch 00037: val_matthews_correlation did not improve from 0.68973
# Epoch 38/50
# 2323/2323 [==============================] - 1s 455us/step - loss: 0.0897 - matthews_correlation: 0.6982 - val_loss: 0.0830 - val_matthews_correlation: 0.6031
#
# Epoch 00038: val_matthews_correlation did not improve from 0.68973
# Epoch 39/50
# 2323/2323 [==============================] - 1s 453us/step - loss: 0.0876 - matthews_correlation: 0.6228 - val_loss: 0.0832 - val_matthews_correlation: 0.6202
#
# Epoch 00039: val_matthews_correlation did not improve from 0.68973
# Epoch 40/50
# 2323/2323 [==============================] - 1s 454us/step - loss: 0.0818 - matthews_correlation: 0.6537 - val_loss: 0.0857 - val_matthews_correlation: 0.6476
#
# Epoch 00040: val_matthews_correlation did not improve from 0.68973
# Epoch 41/50
# 2323/2323 [==============================] - 1s 457us/step - loss: 0.0809 - matthews_correlation: 0.7398 - val_loss: 0.0856 - val_matthews_correlation: 0.6593
#
# Epoch 00041: val_matthews_correlation did not improve from 0.68973
# Epoch 42/50
# 2323/2323 [==============================] - 1s 457us/step - loss: 0.0864 - matthews_correlation: 0.6630 - val_loss: 0.0780 - val_matthews_correlation: 0.6974
#
# Epoch 00042: val_matthews_correlation improved from 0.68973 to 0.69737, saving model to weights_2.h5
# Epoch 43/50
# 2323/2323 [==============================] - 1s 455us/step - loss: 0.0875 - matthews_correlation: 0.6839 - val_loss: 0.0896 - val_matthews_correlation: 0.5582
#
# Epoch 00043: val_matthews_correlation did not improve from 0.69737
# Epoch 44/50
# 2323/2323 [==============================] - 1s 453us/step - loss: 0.0901 - matthews_correlation: 0.6182 - val_loss: 0.0915 - val_matthews_correlation: 0.6150
#
# Epoch 00044: val_matthews_correlation did not improve from 0.69737
# Epoch 45/50
# 2323/2323 [==============================] - 1s 456us/step - loss: 0.0974 - matthews_correlation: 0.5983 - val_loss: 0.0755 - val_matthews_correlation: 0.6681
#
# Epoch 00045: val_matthews_correlation did not improve from 0.69737
# Epoch 46/50
# 2323/2323 [==============================] - 1s 456us/step - loss: 0.0798 - matthews_correlation: 0.7042 - val_loss: 0.0838 - val_matthews_correlation: 0.6539
#
# Epoch 00046: val_matthews_correlation did not improve from 0.69737
# Epoch 47/50
# 2323/2323 [==============================] - 1s 457us/step - loss: 0.0830 - matthews_correlation: 0.6661 - val_loss: 0.0809 - val_matthews_correlation: 0.6584
#
# Epoch 00047: val_matthews_correlation did not improve from 0.69737
# Epoch 48/50
# 2323/2323 [==============================] - 1s 456us/step - loss: 0.0809 - matthews_correlation: 0.7075 - val_loss: 0.0870 - val_matthews_correlation: 0.6159
#
# Epoch 00048: val_matthews_correlation did not improve from 0.69737
# Epoch 49/50
# 2323/2323 [==============================] - 1s 457us/step - loss: 0.0802 - matthews_correlation: 0.6753 - val_loss: 0.0947 - val_matthews_correlation: 0.5751
#
# Epoch 00049: val_matthews_correlation did not improve from 0.69737
# Epoch 50/50
# 2323/2323 [==============================] - 1s 457us/step - loss: 0.0919 - matthews_correlation: 0.6100 - val_loss: 0.0870 - val_matthews_correlation: 0.6255
#
# Epoch 00050: val_matthews_correlation did not improve from 0.69737
# Beginning fold 4
# Train on 2324 samples, validate on 580 samples
# Epoch 1/50
# 2324/2324 [==============================] - 2s 912us/step - loss: 0.3471 - matthews_correlation: -0.0057 - val_loss: 0.2303 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_3.h5
# Epoch 2/50
# 2324/2324 [==============================] - 1s 457us/step - loss: 0.2369 - matthews_correlation: 0.0000e+00 - val_loss: 0.2245 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2324/2324 [==============================] - 1s 453us/step - loss: 0.2305 - matthews_correlation: 0.0000e+00 - val_loss: 0.2183 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00003: val_matthews_correlation did not improve from 0.00000
# Epoch 4/50
# 2324/2324 [==============================] - 1s 452us/step - loss: 0.2210 - matthews_correlation: 0.0000e+00 - val_loss: 0.2030 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00004: val_matthews_correlation did not improve from 0.00000
# Epoch 5/50
# 2324/2324 [==============================] - 1s 452us/step - loss: 0.2174 - matthews_correlation: 0.0000e+00 - val_loss: 0.1901 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00005: val_matthews_correlation did not improve from 0.00000
# Epoch 6/50
# 2324/2324 [==============================] - 1s 452us/step - loss: 0.1966 - matthews_correlation: 0.0000e+00 - val_loss: 0.1681 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00006: val_matthews_correlation did not improve from 0.00000
# Epoch 7/50
# 2324/2324 [==============================] - 1s 452us/step - loss: 0.1653 - matthews_correlation: 0.0187 - val_loss: 0.1428 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00007: val_matthews_correlation did not improve from 0.00000
# Epoch 8/50
# 2324/2324 [==============================] - 1s 452us/step - loss: 0.1299 - matthews_correlation: 0.3224 - val_loss: 0.1255 - val_matthews_correlation: 0.3069
#
# Epoch 00008: val_matthews_correlation improved from 0.00000 to 0.30694, saving model to weights_3.h5
# Epoch 9/50
# 2324/2324 [==============================] - 1s 453us/step - loss: 0.1195 - matthews_correlation: 0.5714 - val_loss: 0.1272 - val_matthews_correlation: 0.3343
#
# Epoch 00009: val_matthews_correlation improved from 0.30694 to 0.33433, saving model to weights_3.h5
# Epoch 10/50
# 2324/2324 [==============================] - 1s 459us/step - loss: 0.1073 - matthews_correlation: 0.6161 - val_loss: 0.1194 - val_matthews_correlation: 0.3421
#
# Epoch 00010: val_matthews_correlation improved from 0.33433 to 0.34209, saving model to weights_3.h5
# Epoch 11/50
# 2324/2324 [==============================] - 1s 451us/step - loss: 0.1134 - matthews_correlation: 0.5482 - val_loss: 0.1227 - val_matthews_correlation: 0.2564
#
# Epoch 00011: val_matthews_correlation did not improve from 0.34209
# Epoch 12/50
# 2324/2324 [==============================] - 1s 454us/step - loss: 0.1172 - matthews_correlation: 0.6370 - val_loss: 0.1098 - val_matthews_correlation: 0.5021
#
# Epoch 00012: val_matthews_correlation improved from 0.34209 to 0.50207, saving model to weights_3.h5
# Epoch 13/50
# 2324/2324 [==============================] - 1s 453us/step - loss: 0.1090 - matthews_correlation: 0.6554 - val_loss: 0.1103 - val_matthews_correlation: 0.5453
#
# Epoch 00013: val_matthews_correlation improved from 0.50207 to 0.54532, saving model to weights_3.h5
# Epoch 14/50
# 2324/2324 [==============================] - 1s 456us/step - loss: 0.1038 - matthews_correlation: 0.6424 - val_loss: 0.1160 - val_matthews_correlation: 0.3843
#
# Epoch 00014: val_matthews_correlation did not improve from 0.54532
# Epoch 15/50
# 2324/2324 [==============================] - 1s 450us/step - loss: 0.1003 - matthews_correlation: 0.6809 - val_loss: 0.1103 - val_matthews_correlation: 0.3902
#
# Epoch 00015: val_matthews_correlation did not improve from 0.54532
# Epoch 16/50
# 2324/2324 [==============================] - 1s 454us/step - loss: 0.1000 - matthews_correlation: 0.6247 - val_loss: 0.1031 - val_matthews_correlation: 0.4322
#
# Epoch 00016: val_matthews_correlation did not improve from 0.54532
# Epoch 17/50
# 2324/2324 [==============================] - 1s 451us/step - loss: 0.0938 - matthews_correlation: 0.7008 - val_loss: 0.1086 - val_matthews_correlation: 0.3594
#
# Epoch 00017: val_matthews_correlation did not improve from 0.54532
# Epoch 18/50
# 2324/2324 [==============================] - 1s 455us/step - loss: 0.0989 - matthews_correlation: 0.6483 - val_loss: 0.1041 - val_matthews_correlation: 0.4270
#
# Epoch 00018: val_matthews_correlation did not improve from 0.54532
# Epoch 19/50
# 2324/2324 [==============================] - 1s 451us/step - loss: 0.0920 - matthews_correlation: 0.6800 - val_loss: 0.1017 - val_matthews_correlation: 0.4528
#
# Epoch 00019: val_matthews_correlation did not improve from 0.54532
# Epoch 20/50
# 2324/2324 [==============================] - 1s 452us/step - loss: 0.0932 - matthews_correlation: 0.6992 - val_loss: 0.1054 - val_matthews_correlation: 0.4866
#
# Epoch 00020: val_matthews_correlation did not improve from 0.54532
# Epoch 21/50
# 2324/2324 [==============================] - 1s 453us/step - loss: 0.0951 - matthews_correlation: 0.6867 - val_loss: 0.1037 - val_matthews_correlation: 0.5365
#
# Epoch 00021: val_matthews_correlation did not improve from 0.54532
# Epoch 22/50
# 2324/2324 [==============================] - 1s 457us/step - loss: 0.0939 - matthews_correlation: 0.6819 - val_loss: 0.1075 - val_matthews_correlation: 0.4933
#
# Epoch 00022: val_matthews_correlation did not improve from 0.54532
# Epoch 23/50
# 2324/2324 [==============================] - 1s 452us/step - loss: 0.0941 - matthews_correlation: 0.6703 - val_loss: 0.1039 - val_matthews_correlation: 0.4993
#
# Epoch 00023: val_matthews_correlation did not improve from 0.54532
# Epoch 24/50
# 2324/2324 [==============================] - 1s 449us/step - loss: 0.0878 - matthews_correlation: 0.6692 - val_loss: 0.1080 - val_matthews_correlation: 0.3877
#
# Epoch 00024: val_matthews_correlation did not improve from 0.54532
# Epoch 25/50
# 2324/2324 [==============================] - 1s 451us/step - loss: 0.0976 - matthews_correlation: 0.6606 - val_loss: 0.1171 - val_matthews_correlation: 0.3206
#
# Epoch 00025: val_matthews_correlation did not improve from 0.54532
# Epoch 26/50
# 2324/2324 [==============================] - 1s 450us/step - loss: 0.0972 - matthews_correlation: 0.6408 - val_loss: 0.1148 - val_matthews_correlation: 0.4194
#
# Epoch 00026: val_matthews_correlation did not improve from 0.54532
# Epoch 27/50
# 2324/2324 [==============================] - 1s 451us/step - loss: 0.0960 - matthews_correlation: 0.6841 - val_loss: 0.1126 - val_matthews_correlation: 0.4297
#
# Epoch 00027: val_matthews_correlation did not improve from 0.54532
# Epoch 28/50
# 2324/2324 [==============================] - 1s 451us/step - loss: 0.0883 - matthews_correlation: 0.6900 - val_loss: 0.1092 - val_matthews_correlation: 0.3869
#
# Epoch 00028: val_matthews_correlation did not improve from 0.54532
# Epoch 29/50
# 2324/2324 [==============================] - 1s 452us/step - loss: 0.0900 - matthews_correlation: 0.7179 - val_loss: 0.1072 - val_matthews_correlation: 0.4797
#
# Epoch 00029: val_matthews_correlation did not improve from 0.54532
# Epoch 30/50
# 2324/2324 [==============================] - 1s 452us/step - loss: 0.0962 - matthews_correlation: 0.6732 - val_loss: 0.1112 - val_matthews_correlation: 0.4952
#
# Epoch 00030: val_matthews_correlation did not improve from 0.54532
# Epoch 31/50
# 2324/2324 [==============================] - 1s 453us/step - loss: 0.0940 - matthews_correlation: 0.7069 - val_loss: 0.1120 - val_matthews_correlation: 0.4395
#
# Epoch 00031: val_matthews_correlation did not improve from 0.54532
# Epoch 32/50
# 2324/2324 [==============================] - 1s 449us/step - loss: 0.0896 - matthews_correlation: 0.6611 - val_loss: 0.1087 - val_matthews_correlation: 0.5213
#
# Epoch 00032: val_matthews_correlation did not improve from 0.54532
# Epoch 33/50
# 2324/2324 [==============================] - 1s 454us/step - loss: 0.0886 - matthews_correlation: 0.6926 - val_loss: 0.1114 - val_matthews_correlation: 0.5054
#
# Epoch 00033: val_matthews_correlation did not improve from 0.54532
# Epoch 34/50
# 2324/2324 [==============================] - 1s 453us/step - loss: 0.0889 - matthews_correlation: 0.7168 - val_loss: 0.1108 - val_matthews_correlation: 0.3251
#
# Epoch 00034: val_matthews_correlation did not improve from 0.54532
# Epoch 35/50
# 2324/2324 [==============================] - 1s 453us/step - loss: 0.1027 - matthews_correlation: 0.6217 - val_loss: 0.1205 - val_matthews_correlation: 0.4943
#
# Epoch 00035: val_matthews_correlation did not improve from 0.54532
# Epoch 36/50
# 2324/2324 [==============================] - 1s 451us/step - loss: 0.0928 - matthews_correlation: 0.6631 - val_loss: 0.1152 - val_matthews_correlation: 0.4528
#
# Epoch 00036: val_matthews_correlation did not improve from 0.54532
# Epoch 37/50
# 2324/2324 [==============================] - 1s 455us/step - loss: 0.0909 - matthews_correlation: 0.7136 - val_loss: 0.1120 - val_matthews_correlation: 0.4153
#
# Epoch 00037: val_matthews_correlation did not improve from 0.54532
# Epoch 38/50
# 2324/2324 [==============================] - 1s 453us/step - loss: 0.0955 - matthews_correlation: 0.6535 - val_loss: 0.1059 - val_matthews_correlation: 0.4952
#
# Epoch 00038: val_matthews_correlation did not improve from 0.54532
# Epoch 39/50
# 2324/2324 [==============================] - 1s 453us/step - loss: 0.0859 - matthews_correlation: 0.7011 - val_loss: 0.1104 - val_matthews_correlation: 0.4600
#
# Epoch 00039: val_matthews_correlation did not improve from 0.54532
# Epoch 40/50
# 2324/2324 [==============================] - 1s 447us/step - loss: 0.0847 - matthews_correlation: 0.7298 - val_loss: 0.1199 - val_matthews_correlation: 0.4948
#
# Epoch 00040: val_matthews_correlation did not improve from 0.54532
# Epoch 41/50
# 2324/2324 [==============================] - 1s 444us/step - loss: 0.0834 - matthews_correlation: 0.7156 - val_loss: 0.1086 - val_matthews_correlation: 0.4650
#
# Epoch 00041: val_matthews_correlation did not improve from 0.54532
# Epoch 42/50
# 2324/2324 [==============================] - 1s 439us/step - loss: 0.0793 - matthews_correlation: 0.7214 - val_loss: 0.1054 - val_matthews_correlation: 0.5365
#
# Epoch 00042: val_matthews_correlation did not improve from 0.54532
# Epoch 43/50
# 2324/2324 [==============================] - 1s 438us/step - loss: 0.0803 - matthews_correlation: 0.7467 - val_loss: 0.1215 - val_matthews_correlation: 0.3910
#
# Epoch 00043: val_matthews_correlation did not improve from 0.54532
# Epoch 44/50
# 2324/2324 [==============================] - 1s 441us/step - loss: 0.0973 - matthews_correlation: 0.6491 - val_loss: 0.1189 - val_matthews_correlation: 0.5140
#
# Epoch 00044: val_matthews_correlation did not improve from 0.54532
# Epoch 45/50
# 2324/2324 [==============================] - 1s 443us/step - loss: 0.0987 - matthews_correlation: 0.6519 - val_loss: 0.1223 - val_matthews_correlation: 0.4265
#
# Epoch 00045: val_matthews_correlation did not improve from 0.54532
# Epoch 46/50
# 2324/2324 [==============================] - 1s 438us/step - loss: 0.0933 - matthews_correlation: 0.6485 - val_loss: 0.1317 - val_matthews_correlation: 0.3927
#
# Epoch 00046: val_matthews_correlation did not improve from 0.54532
# Epoch 47/50
# 2324/2324 [==============================] - 1s 439us/step - loss: 0.0845 - matthews_correlation: 0.7386 - val_loss: 0.1058 - val_matthews_correlation: 0.4535
#
# Epoch 00047: val_matthews_correlation did not improve from 0.54532
# Epoch 48/50
# 2324/2324 [==============================] - 1s 439us/step - loss: 0.0836 - matthews_correlation: 0.6867 - val_loss: 0.1129 - val_matthews_correlation: 0.5149
#
# Epoch 00048: val_matthews_correlation did not improve from 0.54532
# Epoch 49/50
# 2324/2324 [==============================] - 1s 442us/step - loss: 0.0878 - matthews_correlation: 0.7245 - val_loss: 0.1265 - val_matthews_correlation: 0.3691
#
# Epoch 00049: val_matthews_correlation did not improve from 0.54532
# Epoch 50/50
# 2324/2324 [==============================] - 1s 445us/step - loss: 0.0874 - matthews_correlation: 0.7328 - val_loss: 0.1063 - val_matthews_correlation: 0.5054
#
# Epoch 00050: val_matthews_correlation did not improve from 0.54532
# Beginning fold 5
# Train on 2324 samples, validate on 580 samples
# Epoch 1/50
# 2324/2324 [==============================] - 2s 908us/step - loss: 0.3623 - matthews_correlation: 0.0000e+00 - val_loss: 0.2291 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00001: val_matthews_correlation improved from -inf to 0.00000, saving model to weights_4.h5
# Epoch 2/50
# 2324/2324 [==============================] - 1s 454us/step - loss: 0.2256 - matthews_correlation: 0.0000e+00 - val_loss: 0.2197 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00002: val_matthews_correlation did not improve from 0.00000
# Epoch 3/50
# 2324/2324 [==============================] - 1s 452us/step - loss: 0.2151 - matthews_correlation: 0.0000e+00 - val_loss: 0.2153 - val_matthews_correlation: -0.0039
#
# Epoch 00003: val_matthews_correlation did not improve from 0.00000
# Epoch 4/50
# 2324/2324 [==============================] - 1s 454us/step - loss: 0.2251 - matthews_correlation: 0.0357 - val_loss: 0.2161 - val_matthews_correlation: 0.0000e+00
#
# Epoch 00004: val_matthews_correlation did not improve from 0.00000
# Epoch 5/50
# 2324/2324 [==============================] - 1s 448us/step - loss: 0.2025 - matthews_correlation: 0.1387 - val_loss: 0.2058 - val_matthews_correlation: -0.0039
#
# Epoch 00005: val_matthews_correlation did not improve from 0.00000
# Epoch 6/50
# 2324/2324 [==============================] - 1s 450us/step - loss: 0.1891 - matthews_correlation: 0.1196 - val_loss: 0.1826 - val_matthews_correlation: 0.1460
#
# Epoch 00006: val_matthews_correlation improved from 0.00000 to 0.14602, saving model to weights_4.h5
# Epoch 7/50
# 2324/2324 [==============================] - 1s 450us/step - loss: 0.1806 - matthews_correlation: 0.1987 - val_loss: 0.1721 - val_matthews_correlation: 0.1460
#
# Epoch 00007: val_matthews_correlation did not improve from 0.14602
# Epoch 8/50
# 2324/2324 [==============================] - 1s 457us/step - loss: 0.1775 - matthews_correlation: 0.1335 - val_loss: 0.1678 - val_matthews_correlation: -0.0039
#
# Epoch 00008: val_matthews_correlation did not improve from 0.14602
# Epoch 9/50
# 2324/2324 [==============================] - 1s 450us/step - loss: 0.1548 - matthews_correlation: 0.2824 - val_loss: 0.1419 - val_matthews_correlation: 0.1460
#
# Epoch 00009: val_matthews_correlation did not improve from 0.14602
# Epoch 10/50
# 2324/2324 [==============================] - 1s 454us/step - loss: 0.1503 - matthews_correlation: 0.2744 - val_loss: 0.1434 - val_matthews_correlation: 0.0633
#
# Epoch 00010: val_matthews_correlation did not improve from 0.14602
# Epoch 11/50
# 2324/2324 [==============================] - 1s 452us/step - loss: 0.1342 - matthews_correlation: 0.3230 - val_loss: 0.1092 - val_matthews_correlation: 0.5987
#
# Epoch 00011: val_matthews_correlation improved from 0.14602 to 0.59874, saving model to weights_4.h5
# Epoch 12/50
# 2324/2324 [==============================] - 1s 456us/step - loss: 0.1178 - matthews_correlation: 0.6039 - val_loss: 0.1072 - val_matthews_correlation: 0.2865
#
# Epoch 00012: val_matthews_correlation did not improve from 0.59874
# Epoch 13/50
# 2324/2324 [==============================] - 1s 450us/step - loss: 0.1199 - matthews_correlation: 0.5171 - val_loss: 0.0953 - val_matthews_correlation: 0.5910
#
# Epoch 00013: val_matthews_correlation did not improve from 0.59874
# Epoch 14/50
# 2324/2324 [==============================] - 1s 453us/step - loss: 0.1120 - matthews_correlation: 0.6317 - val_loss: 0.0947 - val_matthews_correlation: 0.5862
#
# Epoch 00014: val_matthews_correlation did not improve from 0.59874
# Epoch 15/50
# 2324/2324 [==============================] - 1s 452us/step - loss: 0.1059 - matthews_correlation: 0.6094 - val_loss: 0.1031 - val_matthews_correlation: 0.5690
#
# Epoch 00015: val_matthews_correlation did not improve from 0.59874
# Epoch 16/50
# 2324/2324 [==============================] - 1s 455us/step - loss: 0.1151 - matthews_correlation: 0.5820 - val_loss: 0.1313 - val_matthews_correlation: 0.3757
#
# Epoch 00016: val_matthews_correlation did not improve from 0.59874
# Epoch 17/50
# 2324/2324 [==============================] - 1s 457us/step - loss: 0.1190 - matthews_correlation: 0.5672 - val_loss: 0.0999 - val_matthews_correlation: 0.7149
#
# Epoch 00017: val_matthews_correlation improved from 0.59874 to 0.71489, saving model to weights_4.h5
# Epoch 18/50
# 2324/2324 [==============================] - 1s 451us/step - loss: 0.1051 - matthews_correlation: 0.6570 - val_loss: 0.0923 - val_matthews_correlation: 0.5978
#
# Epoch 00018: val_matthews_correlation did not improve from 0.71489
# Epoch 19/50
# 2324/2324 [==============================] - 1s 451us/step - loss: 0.1039 - matthews_correlation: 0.6095 - val_loss: 0.1090 - val_matthews_correlation: 0.6729
#
# Epoch 00019: val_matthews_correlation did not improve from 0.71489
# Epoch 20/50
# 2324/2324 [==============================] - 1s 457us/step - loss: 0.1036 - matthews_correlation: 0.6475 - val_loss: 0.0888 - val_matthews_correlation: 0.7103
#
# Epoch 00020: val_matthews_correlation did not improve from 0.71489
# Epoch 21/50
# 2324/2324 [==============================] - 1s 454us/step - loss: 0.1037 - matthews_correlation: 0.6026 - val_loss: 0.1040 - val_matthews_correlation: 0.4456
#
# Epoch 00021: val_matthews_correlation did not improve from 0.71489
# Epoch 22/50
# 2324/2324 [==============================] - 1s 454us/step - loss: 0.1007 - matthews_correlation: 0.5746 - val_loss: 0.0946 - val_matthews_correlation: 0.5447
#
# Epoch 00022: val_matthews_correlation did not improve from 0.71489
# Epoch 23/50
# 2324/2324 [==============================] - 1s 455us/step - loss: 0.1175 - matthews_correlation: 0.5927 - val_loss: 0.0998 - val_matthews_correlation: 0.6035
#
# Epoch 00023: val_matthews_correlation did not improve from 0.71489
# Epoch 24/50
# 2324/2324 [==============================] - 1s 457us/step - loss: 0.1080 - matthews_correlation: 0.6398 - val_loss: 0.0934 - val_matthews_correlation: 0.6120
#
# Epoch 00024: val_matthews_correlation did not improve from 0.71489
# Epoch 25/50
# 2324/2324 [==============================] - 1s 455us/step - loss: 0.1023 - matthews_correlation: 0.5529 - val_loss: 0.1040 - val_matthews_correlation: 0.5070
#
# Epoch 00025: val_matthews_correlation did not improve from 0.71489
# Epoch 26/50
# 2324/2324 [==============================] - 1s 458us/step - loss: 0.1021 - matthews_correlation: 0.6028 - val_loss: 0.0895 - val_matthews_correlation: 0.5959
#
# Epoch 00026: val_matthews_correlation did not improve from 0.71489
# Epoch 27/50
# 2324/2324 [==============================] - 1s 455us/step - loss: 0.0992 - matthews_correlation: 0.6540 - val_loss: 0.1013 - val_matthews_correlation: 0.5661
#
# Epoch 00027: val_matthews_correlation did not improve from 0.71489
# Epoch 28/50
# 2324/2324 [==============================] - 1s 451us/step - loss: 0.1112 - matthews_correlation: 0.6463 - val_loss: 0.1023 - val_matthews_correlation: 0.6379
#
# Epoch 00028: val_matthews_correlation did not improve from 0.71489
# Epoch 29/50
# 2324/2324 [==============================] - 1s 457us/step - loss: 0.0969 - matthews_correlation: 0.6290 - val_loss: 0.0894 - val_matthews_correlation: 0.5942
#
# Epoch 00029: val_matthews_correlation did not improve from 0.71489
# Epoch 30/50
# 2324/2324 [==============================] - 1s 452us/step - loss: 0.0945 - matthews_correlation: 0.6717 - val_loss: 0.0954 - val_matthews_correlation: 0.5570
#
# Epoch 00030: val_matthews_correlation did not improve from 0.71489
# Epoch 31/50
# 2324/2324 [==============================] - 1s 445us/step - loss: 0.0943 - matthews_correlation: 0.6871 - val_loss: 0.0907 - val_matthews_correlation: 0.6038
#
# Epoch 00031: val_matthews_correlation did not improve from 0.71489
# Epoch 32/50
# 2324/2324 [==============================] - 1s 445us/step - loss: 0.0958 - matthews_correlation: 0.6407 - val_loss: 0.0917 - val_matthews_correlation: 0.6491
#
# Epoch 00032: val_matthews_correlation did not improve from 0.71489
# Epoch 33/50
# 2324/2324 [==============================] - 1s 443us/step - loss: 0.0948 - matthews_correlation: 0.6482 - val_loss: 0.1108 - val_matthews_correlation: 0.4917
#
# Epoch 00033: val_matthews_correlation did not improve from 0.71489
# Epoch 34/50
# 2324/2324 [==============================] - 1s 444us/step - loss: 0.0998 - matthews_correlation: 0.6603 - val_loss: 0.0913 - val_matthews_correlation: 0.7023
#
# Epoch 00034: val_matthews_correlation did not improve from 0.71489
# Epoch 35/50
# 2324/2324 [==============================] - 1s 455us/step - loss: 0.0944 - matthews_correlation: 0.6414 - val_loss: 0.0962 - val_matthews_correlation: 0.6452
#
# Epoch 00035: val_matthews_correlation did not improve from 0.71489
# Epoch 36/50
# 2324/2324 [==============================] - 1s 455us/step - loss: 0.0935 - matthews_correlation: 0.6674 - val_loss: 0.0920 - val_matthews_correlation: 0.5899
#
# Epoch 00036: val_matthews_correlation did not improve from 0.71489
# Epoch 37/50
# 2324/2324 [==============================] - 1s 455us/step - loss: 0.0957 - matthews_correlation: 0.6559 - val_loss: 0.0929 - val_matthews_correlation: 0.5828
#
# Epoch 00037: val_matthews_correlation did not improve from 0.71489
# Epoch 38/50
# 2324/2324 [==============================] - 1s 457us/step - loss: 0.0883 - matthews_correlation: 0.6698 - val_loss: 0.0872 - val_matthews_correlation: 0.7303
#
# Epoch 00038: val_matthews_correlation improved from 0.71489 to 0.73035, saving model to weights_4.h5
# Epoch 39/50
# 2324/2324 [==============================] - 1s 455us/step - loss: 0.0903 - matthews_correlation: 0.6840 - val_loss: 0.0902 - val_matthews_correlation: 0.5828
#
# Epoch 00039: val_matthews_correlation did not improve from 0.73035
# Epoch 40/50
# 2324/2324 [==============================] - 1s 456us/step - loss: 0.0908 - matthews_correlation: 0.6610 - val_loss: 0.0867 - val_matthews_correlation: 0.6809
#
# Epoch 00040: val_matthews_correlation did not improve from 0.73035
# Epoch 41/50
# 2324/2324 [==============================] - 1s 452us/step - loss: 0.0901 - matthews_correlation: 0.6960 - val_loss: 0.0957 - val_matthews_correlation: 0.5740
#
# Epoch 00041: val_matthews_correlation did not improve from 0.73035
# Epoch 42/50
# 2324/2324 [==============================] - 1s 457us/step - loss: 0.0919 - matthews_correlation: 0.6858 - val_loss: 0.0983 - val_matthews_correlation: 0.7054
#
# Epoch 00042: val_matthews_correlation did not improve from 0.73035
# Epoch 43/50
# 2324/2324 [==============================] - 1s 457us/step - loss: 0.0882 - matthews_correlation: 0.6805 - val_loss: 0.1192 - val_matthews_correlation: 0.4917
#
# Epoch 00043: val_matthews_correlation did not improve from 0.73035
# Epoch 44/50
# 2324/2324 [==============================] - 1s 454us/step - loss: 0.0991 - matthews_correlation: 0.5952 - val_loss: 0.0956 - val_matthews_correlation: 0.5570
#
# Epoch 00044: val_matthews_correlation did not improve from 0.73035
# Epoch 45/50
# 2324/2324 [==============================] - 1s 456us/step - loss: 0.0904 - matthews_correlation: 0.7113 - val_loss: 0.0871 - val_matthews_correlation: 0.5985
#
# Epoch 00045: val_matthews_correlation did not improve from 0.73035
# Epoch 46/50
# 2324/2324 [==============================] - 1s 462us/step - loss: 0.0872 - matthews_correlation: 0.7271 - val_loss: 0.0892 - val_matthews_correlation: 0.6207
#
# Epoch 00046: val_matthews_correlation did not improve from 0.73035
# Epoch 47/50
# 2324/2324 [==============================] - 1s 456us/step - loss: 0.0926 - matthews_correlation: 0.6461 - val_loss: 0.0929 - val_matthews_correlation: 0.6415
#
# Epoch 00047: val_matthews_correlation did not improve from 0.73035
# Epoch 48/50
# 2324/2324 [==============================] - 1s 453us/step - loss: 0.0913 - matthews_correlation: 0.6957 - val_loss: 0.1045 - val_matthews_correlation: 0.6223
#
# Epoch 00048: val_matthews_correlation did not improve from 0.73035
# Epoch 49/50
# 2324/2324 [==============================] - 1s 453us/step - loss: 0.0941 - matthews_correlation: 0.6468 - val_loss: 0.0937 - val_matthews_correlation: 0.5661
#
# Epoch 00049: val_matthews_correlation did not improve from 0.73035
# Epoch 50/50
# 2324/2324 [==============================] - 1s 458us/step - loss: 0.0951 - matthews_correlation: 0.6063 - val_loss: 0.0935 - val_matthews_correlation: 0.6330
#
# Epoch 00050: val_matthews_correlation did not improve from 0.73035
# ((2904,), (2904,))

# %%
import tensorflow as tf

def threshold_search(y_true, y_proba):
    best_threshold = 0
    best_score = 0
    for threshold in tqdm([i * 0.01 for i in range(100)]):
        score = K.eval(matthews_correlation(y_true.astype(np.float64), (y_proba > threshold).astype(np.float64)))
        if score > best_score:
            best_threshold = threshold
            best_score = score
    search_result = {'threshold': best_threshold, 'matthews_correlation': best_score}
    return search_result

# %% [markdown]
# <pre><a id = 13><b>Identify the Best Threshold</b></a></pre>

# %%
best_threshold = threshold_search(y_val, preds_val)['threshold']
# Out:
# 100%|██████████| 100/100 [00:17<00:00,  3.67it/s]

# %%
best_threshold
# Out:
# 0.49

# %%
meta_test = pd.read_csv('../input/metadata_test.csv')

# %%
meta_test = meta_test.set_index(['signal_id'])
meta_test.head()
# Out:
#            id_measurement  phase
# signal_id
# 8712                 2904      0
# 8713                 2904      1
# 8714                 2904      2
# 8715                 2905      0
# 8716                 2905      1

# %%
first_sig = meta_test.index[0]
n_parts = 10
max_line = len(meta_test)
part_size = int(max_line / n_parts)
last_part = max_line % n_parts
print(first_sig, n_parts, max_line, part_size, last_part, n_parts * part_size + last_part)
# Here we create a list of lists with start index and end index for each of the 10 parts and one for the last partial part
start_end = [[x, x+part_size] for x in range(first_sig, max_line + first_sig, part_size)]
start_end = start_end[:-1] + [[start_end[-1][0], start_end[-1][0] + last_part]]
print(start_end)
X_test = []
# now, very like we did above with the train data, we convert the test data part by part
# transforming the 3 phases 800000 measurement in matrix (160,57)
for start, end in start_end:
    subset_test = pq.read_pandas('../input/test.parquet', columns=[str(i) for i in range(start, end)]).to_pandas()
    for i in tqdm(subset_test.columns):
        id_measurement, phase = meta_test.loc[int(i)]
        subset_test_col = subset_test[i]
        subset_trans = transform_ts(subset_test_col)
        X_test.append([i, id_measurement, phase, subset_trans])
# Out:
# 8712 10 20337 2033 7 20337
# [[8712, 10745], [10745, 12778], [12778, 14811], [14811, 16844], [16844, 18877], [18877, 20910], [20910, 22943], [22943, 24976], [24976, 27009], [27009, 29042], [29042, 29049]]
# 100%|██████████| 2033/2033 [02:22<00:00, 14.28it/s]
# 100%|██████████| 2033/2033 [02:22<00:00, 14.34it/s]
# 100%|██████████| 2033/2033 [02:23<00:00, 14.45it/s]
# 100%|██████████| 2033/2033 [02:23<00:00, 14.75it/s]
# 100%|██████████| 2033/2033 [02:24<00:00, 14.46it/s]
# 100%|██████████| 2033/2033 [02:23<00:00, 14.42it/s]
# 100%|██████████| 2033/2033 [02:25<00:00, 14.55it/s]
# 100%|██████████| 2033/2033 [02:23<00:00, 14.55it/s]
# 100%|██████████| 2033/2033 [02:25<00:00, 14.78it/s]
# 100%|██████████| 2033/2033 [02:24<00:00, 14.42it/s]
# 100%|██████████| 7/7 [00:00<00:00, 11.56it/s]

# %%
X_test_input = np.asarray([np.concatenate([X_test[i][3],X_test[i+1][3], X_test[i+2][3]], axis=1) for i in range(0,len(X_test), 3)])
np.save("X_test.npy",X_test_input)
X_test_input.shape
# Out:
# (6779, 160, 57)

# %% [markdown]
# <pre><a id = 14><b>Create Submission File</b></a></pre>

# %%
submission = pd.read_csv('../input/sample_submission.csv')
print(len(submission))
submission.head()
# Out:
# 20337
#    signal_id  target
# 0       8712       0
# 1       8713       0
# 2       8714       0
# 3       8715       0
# 4       8716       0

# %%
preds_test = []
for i in range(N_SPLITS):
    model.load_weights('weights_{}.h5'.format(i))
    pred = model.predict(X_test_input, batch_size=300, verbose=1)
    pred_3 = []
    for pred_scalar in pred:
        for i in range(3):
            pred_3.append(pred_scalar)
    preds_test.append(pred_3)
# Out:
# 6779/6779 [==============================] - 1s 123us/step
# 6779/6779 [==============================] - 1s 120us/step
# 6779/6779 [==============================] - 1s 121us/step
# 6779/6779 [==============================] - 1s 120us/step
# 6779/6779 [==============================] - 1s 120us/step

# %%
preds_test = (np.squeeze(np.mean(preds_test, axis=0)) > best_threshold).astype(np.int)
preds_test.shape
# Out:
# (20337,)

# %%
submission['target'] = preds_test
submission.to_csv('submission.csv', index=False)
submission.head()
# Out:
#    signal_id  target
# 0       8712       0
# 1       8713       0
# 2       8714       0
# 3       8715       0
# 4       8716       0
